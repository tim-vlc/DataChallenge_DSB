# %% [markdown]
# # Template used to test a model locally:
#
# ### Outline:
#
# - Import the Dataset using the correct function
#
# - Use the function transformers to do the feature engineering - ```Please Comment any step that you have changed versus the best submission```
#
# - Retrieve the transformed X_train and run ydata_profiling to find insights
#
# - Create pipeline
#
# - Run CV to get a baseline RMSE score
#
# - Print the most important hyperparameters & run the Optuna training
#
# - Rerun the pipeline to see the impact - ```Please share any relevant information here```
#
# - Update the script with the final model and test submission

# %% [markdown]
# ## Example with Best Score Script using the `Coco` +  ['temp', 'rhum', 'wspd', 'prcp']

# %% [markdown]
# ### Import the Dataset

# %%
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Ridge
import holidays
from lockdowndates.core import LockdownDates
import haversine as hs
from datetime import datetime
from meteostat import Point, Hourly
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import numpy as np
from pathlib import Path
from datetime import datetime
from meteostat import Point, Hourly

# %%
def _read_data():
    _target_column_name = 'log_bike_count'
    data = pd.read_parquet(Path("data") / "train.parquet")
    # Sort by date first, so that time based cross-validation would produce correct results
    data = data.sort_values(["date", "counter_name"])
    y_array = data[_target_column_name].values
    X_df = data.drop([_target_column_name, "bike_count"], axis=1)
    return X_df, y_array

# %%
X_train, y_train = _read_data()
X_final = pd.read_parquet(Path("data") / "final_test.parquet")

# %% [markdown]
# ### Function Transformers

# %%
# Encode Date with Fourrier + Covid + Holidays (To test Perf With Weekend + Holidays)

def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X.loc[:, "year"] = X["date"].dt.year
    X.loc[:, "date_ws"] = X["date"].dt.date.astype('datetime64[ns]') # To be used for merging
    X.loc[:, "month"] = X["date"].dt.month
    X.loc[:, "day"] = X["date"].dt.day
    X.loc[:, "weekday"] = X["date"].dt.weekday
    X.loc[:, "hour"] = X["date"].dt.hour
    X.loc[:, "week_of_year"] = X["date"].dt.isocalendar().week
    X.loc[:, "season"] = X["week_of_year"].apply(lambda w: (w // 13) % 4 + 1)

    # Add the column corresponding to holidays
    fr_holidays = holidays.FR(years=X["year"].unique().tolist())
    X.loc[: ,'holidays'] = X['date'].apply(lambda x: x in fr_holidays or x.weekday() >= 5).astype(int)

    # Add covid restrictions
    ld = LockdownDates("France", "2020-09-01", "2022-01-01", ("stay_at_home", "masks"))
    lockdown_dates = ld.dates()
    X = X.reset_index().merge(lockdown_dates['france_stay_at_home'], how='left', left_on='date_ws', right_index=True).set_index('index')
    
    # Month
    months_in_year = 12
    X['sin_month'] = np.sin(2*np.pi*X.month/months_in_year)
    X['cos_month'] = np.cos(2*np.pi*X.month/months_in_year)
    X.drop('month', axis=1, inplace=True)
    
    # Day
    day_in_month = 31
    X['sin_day'] = np.sin(2*np.pi*X.day/day_in_month)
    X['cos_day'] = np.cos(2*np.pi*X.day/day_in_month)
    X.drop('day', axis=1, inplace=True)
    
    # Weekday
    day_in_week = 7
    X['sin_weekday'] = np.sin(2*np.pi*X.weekday/day_in_week)
    X['cos_weekday'] = np.cos(2*np.pi*X.weekday/day_in_week)
    X.drop('weekday', axis=1, inplace=True)
    
    # Hour
    hours_in_day = 24
    X['sin_hour'] = np.sin(2*np.pi*X.hour/hours_in_day)
    X['cos_hour'] = np.cos(2*np.pi*X.hour/hours_in_day)
    X.drop('hour', axis=1, inplace=True)
    
    # Week of year
    weeks_in_year = 52
    X['sin_weekyear'] = np.sin(2*np.pi*X.week_of_year/weeks_in_year)
    X['cos_weekyear'] = np.cos(2*np.pi*X.week_of_year/weeks_in_year)
    X.drop('week_of_year', axis=1, inplace=True)
    
    # Season
    seasons_in_year = 4
    X['sin_season'] = np.sin(2*np.pi*X.season/seasons_in_year)
    X['cos_season'] = np.cos(2*np.pi*X.season/seasons_in_year)
    X.drop('season', axis=1, inplace=True)

    return X

# %%
# Retrieve the closest transport station // Test with number of stations in a radius (Categorical)

def _closest_transport(X): 
    column_names = ['longitude', 'latitude', 'station_name']  # Replace with your actual column names
    idf_stations = pd.read_csv(Path("data") / "Stations_IDF.csv", delimiter=';', header=None, names=column_names)

    X = X.copy()
    # Create an empty DataFrame to store the results
    result_df = pd.DataFrame(columns=['counter_id', 'closest_metro_distance'])

    # Iterate over unique counter_ids in X
    for counter_id in X['counter_id'].unique():
        coordinates_counter = (X.loc[X['counter_id'] == counter_id, 'latitude'].values[0],
                               X.loc[X['counter_id'] == counter_id, 'longitude'].values[0])

        # Calculate distances to all metro stations
        distances = []
        for _, station_row in idf_stations.iterrows():
            coordinates_station = (station_row['latitude'], station_row['longitude'])
            distance = hs.haversine(coordinates_counter, coordinates_station)
            distances.append(distance)

        # Get the k closest distances
        closest_distance = sorted(distances)[0]

        # Append to the result DataFrame
        result_df = pd.concat([result_df, pd.DataFrame({'counter_id': [counter_id], 'closest_metro_distance': [closest_distance]})])
    
    result_df = result_df.set_index('counter_id')
    X = X.reset_index().merge(result_df['closest_metro_distance'], how='left', left_on='counter_id', right_index=True).set_index('index')
        
    return X

# %%
# Add Weather Data //  'Coco' column + All Weather this time

def _add_weather_data(X):
    X = X.copy()
    dfs = []

    for counter_id in X['counter_id'].unique():
        # Get the coordinates of the counter
        coordinates_counter = (
            X.loc[X['counter_id'] == counter_id, 'latitude'].values[0],
            X.loc[X['counter_id'] == counter_id, 'longitude'].values[0]
        )

        # Create a Point object with the counter's coordinates
        counter_point = Point(*coordinates_counter)

        # Define the time range (start and end dates)
        start = datetime(2020, 8, 1)
        end = datetime(2022, 1, 1)

        # Create a Hourly object and fetch the weather data
        weather_data = Hourly(counter_point, start, end).interpolate().fetch()
        selected_columns = ['temp', 'rhum', 'wspd', 'prcp', 'coco']
        weather_data = weather_data[selected_columns].shift(-1)

        # Append counter_id to the weather_data DataFrame
        weather_data['counter_id'] = counter_id

        # Append the DataFrame to the list
        dfs.append(weather_data)

    # Concatenate all DataFrames into a single result_df
    result_df = pd.concat(dfs)
    
    # Convert 'time' index to 'date' column for merging
    result_df['date'] = result_df.index
    result_df['date'] = pd.to_datetime(result_df['date'])
    
    # Merge the result DataFrame with the original DataFrame on 'counter_id' and 'date'
    X = X.reset_index().merge(result_df, how='left', on=['counter_id', 'date']).set_index('index')

    return X.drop(columns=["date", "counter_name", "site_id", "site_name", 
                           "counter_installation_date", "coordinates", "counter_technical_id",
                           "longitude", "latitude", "date_ws"])

# %% [markdown]
# ### Call all functions on X train, concatenate with y_train and run ydata_profiling

# %%
# Please don't change the X_train_encode to not overwrite the initial dataset that will be used later for the modelling

X_train_encoded = _encode_dates(X_train)
X_train_encoded = _closest_transport(X_train_encoded)
X_train_encoded = _add_weather_data(X_train_encoded)
# Out:
# Fetching lockdown dates...
# Fetched lockdown dates for: France

# %%
# Do the necessary changes to proceed to ydata_profiling

y_train_transformed = pd.Series(y_train).reset_index(drop=True)

concatenated_df = pd.concat([X_train_encoded.reset_index(drop=True), y_train_transformed], axis=1)

# %%
concatenated_df.head()
# Out:
#             counter_id  year  holidays france_stay_at_home  sin_month  \
# 0  100049407-353255860  2020         0                 0.0       -1.0
# 1  100049407-353255859  2020         0                 0.0       -1.0
# 2  100036719-104036719  2020         0                 0.0       -1.0
# 3  100036719-103036719  2020         0                 0.0       -1.0
# 4  100063175-353277233  2020         0                 0.0       -1.0
#
#       cos_month   sin_day  cos_day  sin_weekday  cos_weekday  ...  \
# 0 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  ...
# 1 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  ...
# 2 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  ...
# 3 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  ...
# 4 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  ...
#
#    cos_weekyear  sin_season    cos_season  closest_metro_distance  temp  rhum  \
# 0     -0.354605        -1.0 -1.836970e-16                0.268640  13.0  79.0
# 1     -0.354605        -1.0 -1.836970e-16                0.268640  13.0  79.0
# 2     -0.354605        -1.0 -1.836970e-16                0.016574  13.0  79.0
# 3     -0.354605        -1.0 -1.836970e-16                0.016574  13.0  79.0
# 4     -0.354605        -1.0 -1.836970e-16                0.197986  13.0  79.0
#
#    wspd  prcp  coco         0
# 0   3.6   0.0   1.0  1.609438
# 1   3.6   0.0   1.0  1.386294
# 2   3.6   0.0   1.0  0.000000
# 3   3.6   0.0   1.0  0.693147
# 4   3.6   0.0   5.0  2.079442
#
# [5 rows x 23 columns]

# %%
#import ydata_profiling

#concatenated_df.profile_report()

# %% [markdown]
# **Note on the correlation matrix that some of the cos/sin features that we derive are correlated between each other. Try to keep only certain of them and keep the other as categories**

# %% [markdown]
# ### Create Pipeline and CV

# %%
def get_estimator():
    date_encoder = FunctionTransformer(_encode_dates)
    transport_encoder = FunctionTransformer(_closest_transport)
    weather_encoder = FunctionTransformer(_add_weather_data)
    
    date_cols = ["sin_month", "sin_day", "sin_hour", "sin_weekyear", "sin_weekday",
                 "cos_month", "cos_day", "cos_hour", "cos_weekyear", "cos_weekday"]

    categorical_cols = ["counter_id", "closest_metro_distance", "holidays", "france_stay_at_home", "year", "coco"]
    numerical_cols = ['temp', 'rhum', 'wspd', 'prcp']

    preprocessor = ColumnTransformer(
        [
            ("date", 'passthrough', date_cols),
            ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
            ("num", StandardScaler(), numerical_cols)
        ]
    )
    regressor = CatBoostRegressor()

    pipe = make_pipeline(date_encoder, transport_encoder, weather_encoder, preprocessor, regressor)

    return pipe

# %%
pipe = get_estimator()

pipe.fit(X_train, y_train)

cv = TimeSeriesSplit(n_splits=6)

# When using a scorer in scikit-learn it always needs to be better when smaller, hence the minus sign.
scores = cross_val_score(
    pipe, X_train, y_train, cv=cv, scoring="neg_root_mean_squared_error"
)
print("RMSE: ", scores)
print(f"RMSE (all folds): {-scores.mean():.3} ± {(-scores).std():.3}")
# Out:
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Learning rate set to 0.109189
# 0:	learn: 1.5455387	total: 78.4ms	remaining: 1m 18s
# 1:	learn: 1.4470398	total: 97ms	remaining: 48.4s
# 2:	learn: 1.3624128	total: 114ms	remaining: 38s
# 3:	learn: 1.2911092	total: 134ms	remaining: 33.4s
# 4:	learn: 1.2278214	total: 153ms	remaining: 30.4s
# 5:	learn: 1.1719356	total: 173ms	remaining: 28.6s
# 6:	learn: 1.1243903	total: 191ms	remaining: 27s
# 7:	learn: 1.0833677	total: 209ms	remaining: 25.9s
# 8:	learn: 1.0495571	total: 227ms	remaining: 25s
# 9:	learn: 1.0190622	total: 246ms	remaining: 24.4s
# 10:	learn: 0.9941027	total: 262ms	remaining: 23.6s
# 11:	learn: 0.9719429	total: 279ms	remaining: 23s
# 12:	learn: 0.9526136	total: 296ms	remaining: 22.4s
# 13:	learn: 0.9356389	total: 311ms	remaining: 21.9s
# 14:	learn: 0.9206048	total: 327ms	remaining: 21.4s
# 15:	learn: 0.9047137	total: 345ms	remaining: 21.2s
# 16:	learn: 0.8925117	total: 362ms	remaining: 20.9s
# 17:	learn: 0.8823640	total: 379ms	remaining: 20.7s
# 18:	learn: 0.8646340	total: 397ms	remaining: 20.5s
# 19:	learn: 0.8556438	total: 414ms	remaining: 20.3s
# 20:	learn: 0.8474314	total: 430ms	remaining: 20.1s
# 21:	learn: 0.8382394	total: 451ms	remaining: 20s
# 22:	learn: 0.8304757	total: 467ms	remaining: 19.9s
# 23:	learn: 0.8232464	total: 483ms	remaining: 19.7s
# 24:	learn: 0.8168965	total: 498ms	remaining: 19.4s
# 25:	learn: 0.8033398	total: 516ms	remaining: 19.3s
# 26:	learn: 0.7971332	total: 530ms	remaining: 19.1s
# 27:	learn: 0.7918897	total: 545ms	remaining: 18.9s
# 28:	learn: 0.7802815	total: 563ms	remaining: 18.8s
# 29:	learn: 0.7751850	total: 577ms	remaining: 18.7s
# 30:	learn: 0.7699779	total: 593ms	remaining: 18.5s
# 31:	learn: 0.7645621	total: 610ms	remaining: 18.5s
# 32:	learn: 0.7605434	total: 625ms	remaining: 18.3s
# 33:	learn: 0.7565681	total: 639ms	remaining: 18.1s
# 34:	learn: 0.7527796	total: 654ms	remaining: 18s
# 35:	learn: 0.7490843	total: 668ms	remaining: 17.9s
# 36:	learn: 0.7432979	total: 685ms	remaining: 17.8s
# 37:	learn: 0.7396625	total: 704ms	remaining: 17.8s
# 38:	learn: 0.7353973	total: 720ms	remaining: 17.7s
# 39:	learn: 0.7322812	total: 735ms	remaining: 17.6s
# 40:	learn: 0.7292901	total: 748ms	remaining: 17.5s
# 41:	learn: 0.7259329	total: 765ms	remaining: 17.4s
# 42:	learn: 0.7231404	total: 780ms	remaining: 17.4s
# 43:	learn: 0.7184197	total: 798ms	remaining: 17.3s
# 44:	learn: 0.7161404	total: 812ms	remaining: 17.2s
# 45:	learn: 0.7138047	total: 825ms	remaining: 17.1s
# 46:	learn: 0.7114079	total: 840ms	remaining: 17s
# 47:	learn: 0.7021474	total: 858ms	remaining: 17s
# 48:	learn: 0.6979641	total: 875ms	remaining: 17s
# 49:	learn: 0.6953710	total: 892ms	remaining: 17s
# 50:	learn: 0.6931151	total: 906ms	remaining: 16.9s
# 51:	learn: 0.6909916	total: 920ms	remaining: 16.8s
# 52:	learn: 0.6885428	total: 936ms	remaining: 16.7s
# 53:	learn: 0.6865248	total: 949ms	remaining: 16.6s
# 54:	learn: 0.6789704	total: 966ms	remaining: 16.6s
# 55:	learn: 0.6771066	total: 980ms	remaining: 16.5s
# 56:	learn: 0.6752484	total: 995ms	remaining: 16.5s
# 57:	learn: 0.6692927	total: 1.01s	remaining: 16.4s
# 58:	learn: 0.6662304	total: 1.03s	remaining: 16.4s
# 59:	learn: 0.6616963	total: 1.04s	remaining: 16.4s
# 60:	learn: 0.6594711	total: 1.06s	remaining: 16.3s
# 61:	learn: 0.6547336	total: 1.08s	remaining: 16.3s
# 62:	learn: 0.6531212	total: 1.09s	remaining: 16.2s
# 63:	learn: 0.6495864	total: 1.11s	remaining: 16.2s
# 64:	learn: 0.6478936	total: 1.13s	remaining: 16.2s
# 65:	learn: 0.6464156	total: 1.14s	remaining: 16.1s
# 66:	learn: 0.6449720	total: 1.15s	remaining: 16.1s
# 67:	learn: 0.6427870	total: 1.17s	remaining: 16s
# 68:	learn: 0.6389769	total: 1.19s	remaining: 16s
# 69:	learn: 0.6345217	total: 1.2s	remaining: 16s
# 70:	learn: 0.6331549	total: 1.22s	remaining: 15.9s
# 71:	learn: 0.6299025	total: 1.23s	remaining: 15.9s
# 72:	learn: 0.6280623	total: 1.25s	remaining: 15.9s
# 73:	learn: 0.6258390	total: 1.28s	remaining: 16s
# 74:	learn: 0.6240881	total: 1.29s	remaining: 15.9s
# 75:	learn: 0.6221282	total: 1.31s	remaining: 15.9s
# 76:	learn: 0.6204038	total: 1.33s	remaining: 15.9s
# 77:	learn: 0.6186513	total: 1.34s	remaining: 15.9s
# 78:	learn: 0.6177078	total: 1.36s	remaining: 15.8s
# 79:	learn: 0.6164512	total: 1.37s	remaining: 15.8s
# 80:	learn: 0.6153922	total: 1.38s	remaining: 15.7s
# 81:	learn: 0.6116165	total: 1.4s	remaining: 15.7s
# 82:	learn: 0.6095448	total: 1.42s	remaining: 15.7s
# 83:	learn: 0.6085668	total: 1.43s	remaining: 15.6s
# 84:	learn: 0.6073954	total: 1.45s	remaining: 15.6s
# 85:	learn: 0.6041935	total: 1.47s	remaining: 15.6s
# 86:	learn: 0.6032914	total: 1.48s	remaining: 15.6s
# 87:	learn: 0.6013121	total: 1.5s	remaining: 15.5s
# 88:	learn: 0.5997719	total: 1.51s	remaining: 15.5s
# 89:	learn: 0.5975270	total: 1.53s	remaining: 15.5s
# 90:	learn: 0.5957599	total: 1.55s	remaining: 15.5s
# 91:	learn: 0.5943607	total: 1.56s	remaining: 15.4s
# 92:	learn: 0.5930652	total: 1.58s	remaining: 15.4s
# 93:	learn: 0.5919486	total: 1.59s	remaining: 15.4s
# 94:	learn: 0.5901118	total: 1.61s	remaining: 15.3s
# 95:	learn: 0.5884111	total: 1.63s	remaining: 15.3s
# 96:	learn: 0.5876530	total: 1.64s	remaining: 15.3s
# 97:	learn: 0.5855776	total: 1.66s	remaining: 15.3s
# 98:	learn: 0.5823080	total: 1.68s	remaining: 15.3s
# 99:	learn: 0.5804374	total: 1.69s	remaining: 15.3s
# 100:	learn: 0.5787588	total: 1.71s	remaining: 15.2s
# 101:	learn: 0.5774091	total: 1.73s	remaining: 15.2s
# 102:	learn: 0.5757908	total: 1.75s	remaining: 15.2s
# 103:	learn: 0.5749467	total: 1.76s	remaining: 15.2s
# 104:	learn: 0.5739044	total: 1.77s	remaining: 15.1s
# 105:	learn: 0.5729613	total: 1.79s	remaining: 15.1s
# 106:	learn: 0.5719412	total: 1.81s	remaining: 15.1s
# 107:	learn: 0.5709349	total: 1.82s	remaining: 15.1s
# 108:	learn: 0.5699806	total: 1.84s	remaining: 15s
# 109:	learn: 0.5693918	total: 1.85s	remaining: 15s
# 110:	learn: 0.5682266	total: 1.87s	remaining: 15s
# 111:	learn: 0.5670873	total: 1.88s	remaining: 14.9s
# 112:	learn: 0.5659771	total: 1.9s	remaining: 14.9s
# 113:	learn: 0.5648519	total: 1.92s	remaining: 14.9s
# 114:	learn: 0.5641964	total: 1.93s	remaining: 14.9s
# 115:	learn: 0.5631233	total: 1.95s	remaining: 14.8s
# 116:	learn: 0.5621394	total: 1.96s	remaining: 14.8s
# 117:	learn: 0.5610991	total: 1.98s	remaining: 14.8s
# 118:	learn: 0.5603078	total: 1.99s	remaining: 14.8s
# 119:	learn: 0.5580557	total: 2.01s	remaining: 14.7s
# 120:	learn: 0.5575230	total: 2.02s	remaining: 14.7s
# 121:	learn: 0.5561920	total: 2.04s	remaining: 14.7s
# 122:	learn: 0.5554035	total: 2.06s	remaining: 14.7s
# 123:	learn: 0.5541913	total: 2.07s	remaining: 14.6s
# 124:	learn: 0.5532414	total: 2.09s	remaining: 14.6s
# 125:	learn: 0.5527699	total: 2.1s	remaining: 14.6s
# 126:	learn: 0.5518568	total: 2.12s	remaining: 14.6s
# 127:	learn: 0.5509040	total: 2.13s	remaining: 14.5s
# 128:	learn: 0.5501509	total: 2.15s	remaining: 14.5s
# 129:	learn: 0.5492030	total: 2.16s	remaining: 14.5s
# 130:	learn: 0.5484043	total: 2.18s	remaining: 14.5s
# 131:	learn: 0.5475479	total: 2.19s	remaining: 14.4s
# 132:	learn: 0.5463893	total: 2.21s	remaining: 14.4s
# 133:	learn: 0.5455761	total: 2.23s	remaining: 14.4s
# 134:	learn: 0.5446692	total: 2.24s	remaining: 14.4s
# 135:	learn: 0.5435066	total: 2.26s	remaining: 14.4s
# 136:	learn: 0.5423452	total: 2.28s	remaining: 14.3s
# 137:	learn: 0.5416127	total: 2.29s	remaining: 14.3s
# 138:	learn: 0.5405908	total: 2.31s	remaining: 14.3s
# 139:	learn: 0.5396986	total: 2.33s	remaining: 14.3s
# 140:	learn: 0.5391165	total: 2.34s	remaining: 14.3s
# 141:	learn: 0.5387390	total: 2.36s	remaining: 14.2s
# 142:	learn: 0.5375374	total: 2.37s	remaining: 14.2s
# 143:	learn: 0.5367278	total: 2.39s	remaining: 14.2s
# 144:	learn: 0.5349904	total: 2.41s	remaining: 14.2s
# 145:	learn: 0.5342457	total: 2.42s	remaining: 14.2s
# 146:	learn: 0.5333779	total: 2.44s	remaining: 14.2s
# 147:	learn: 0.5325464	total: 2.46s	remaining: 14.2s
# 148:	learn: 0.5319705	total: 2.47s	remaining: 14.1s
# 149:	learn: 0.5313974	total: 2.49s	remaining: 14.1s
# 150:	learn: 0.5305974	total: 2.5s	remaining: 14.1s
# 151:	learn: 0.5299476	total: 2.52s	remaining: 14.1s
# 152:	learn: 0.5292704	total: 2.54s	remaining: 14s
# 153:	learn: 0.5284681	total: 2.55s	remaining: 14s
# 154:	learn: 0.5278053	total: 2.57s	remaining: 14s
# 155:	learn: 0.5271822	total: 2.58s	remaining: 14s
# 156:	learn: 0.5265598	total: 2.6s	remaining: 13.9s
# 157:	learn: 0.5258297	total: 2.61s	remaining: 13.9s
# 158:	learn: 0.5250287	total: 2.63s	remaining: 13.9s
# 159:	learn: 0.5241531	total: 2.65s	remaining: 13.9s
# 160:	learn: 0.5235211	total: 2.66s	remaining: 13.9s
# 161:	learn: 0.5222507	total: 2.69s	remaining: 13.9s
# 162:	learn: 0.5218585	total: 2.7s	remaining: 13.9s
# 163:	learn: 0.5212609	total: 2.72s	remaining: 13.9s
# 164:	learn: 0.5207190	total: 2.73s	remaining: 13.8s
# 165:	learn: 0.5193656	total: 2.75s	remaining: 13.8s
# 166:	learn: 0.5188284	total: 2.77s	remaining: 13.8s
# 167:	learn: 0.5185609	total: 2.78s	remaining: 13.8s
# 168:	learn: 0.5173456	total: 2.8s	remaining: 13.8s
# 169:	learn: 0.5166883	total: 2.81s	remaining: 13.7s
# 170:	learn: 0.5161349	total: 2.83s	remaining: 13.7s
# 171:	learn: 0.5153703	total: 2.85s	remaining: 13.7s
# 172:	learn: 0.5146159	total: 2.87s	remaining: 13.7s
# 173:	learn: 0.5137630	total: 2.88s	remaining: 13.7s
# 174:	learn: 0.5128257	total: 2.9s	remaining: 13.7s
# 175:	learn: 0.5120477	total: 2.92s	remaining: 13.6s
# 176:	learn: 0.5115249	total: 2.93s	remaining: 13.6s
# 177:	learn: 0.5110206	total: 2.95s	remaining: 13.6s
# 178:	learn: 0.5105877	total: 2.96s	remaining: 13.6s
# 179:	learn: 0.5100126	total: 2.98s	remaining: 13.6s
# 180:	learn: 0.5092157	total: 3s	remaining: 13.6s
# 181:	learn: 0.5087363	total: 3.02s	remaining: 13.6s
# 182:	learn: 0.5079888	total: 3.03s	remaining: 13.5s
# 183:	learn: 0.5072685	total: 3.05s	remaining: 13.5s
# 184:	learn: 0.5064683	total: 3.07s	remaining: 13.5s
# 185:	learn: 0.5052825	total: 3.08s	remaining: 13.5s
# 186:	learn: 0.5046605	total: 3.1s	remaining: 13.5s
# 187:	learn: 0.5039638	total: 3.12s	remaining: 13.5s
# 188:	learn: 0.5034725	total: 3.13s	remaining: 13.4s
# 189:	learn: 0.5029369	total: 3.15s	remaining: 13.4s
# 190:	learn: 0.5025256	total: 3.16s	remaining: 13.4s
# 191:	learn: 0.5019943	total: 3.18s	remaining: 13.4s
# 192:	learn: 0.5013237	total: 3.2s	remaining: 13.4s
# 193:	learn: 0.5007947	total: 3.21s	remaining: 13.4s
# 194:	learn: 0.5004602	total: 3.23s	remaining: 13.3s
# 195:	learn: 0.4998011	total: 3.25s	remaining: 13.3s
# 196:	learn: 0.4994255	total: 3.26s	remaining: 13.3s
# 197:	learn: 0.4985089	total: 3.28s	remaining: 13.3s
# 198:	learn: 0.4978219	total: 3.3s	remaining: 13.3s
# 199:	learn: 0.4971227	total: 3.31s	remaining: 13.3s
# 200:	learn: 0.4966738	total: 3.33s	remaining: 13.2s
# 201:	learn: 0.4960688	total: 3.35s	remaining: 13.2s
# 202:	learn: 0.4956029	total: 3.37s	remaining: 13.2s
# 203:	learn: 0.4952246	total: 3.38s	remaining: 13.2s
# 204:	learn: 0.4947831	total: 3.4s	remaining: 13.2s
# 205:	learn: 0.4942168	total: 3.42s	remaining: 13.2s
# 206:	learn: 0.4938563	total: 3.43s	remaining: 13.1s
# 207:	learn: 0.4930561	total: 3.45s	remaining: 13.1s
# 208:	learn: 0.4925948	total: 3.47s	remaining: 13.1s
# 209:	learn: 0.4917873	total: 3.48s	remaining: 13.1s
# 210:	learn: 0.4912936	total: 3.5s	remaining: 13.1s
# 211:	learn: 0.4907969	total: 3.52s	remaining: 13.1s
# 212:	learn: 0.4903550	total: 3.53s	remaining: 13.1s
# 213:	learn: 0.4899841	total: 3.55s	remaining: 13s
# 214:	learn: 0.4895240	total: 3.57s	remaining: 13s
# 215:	learn: 0.4891372	total: 3.58s	remaining: 13s
# 216:	learn: 0.4886219	total: 3.6s	remaining: 13s
# 217:	learn: 0.4881896	total: 3.61s	remaining: 13s
# 218:	learn: 0.4876089	total: 3.63s	remaining: 12.9s
# 219:	learn: 0.4872584	total: 3.65s	remaining: 12.9s
# 220:	learn: 0.4867393	total: 3.66s	remaining: 12.9s
# 221:	learn: 0.4861938	total: 3.68s	remaining: 12.9s
# 222:	learn: 0.4856809	total: 3.7s	remaining: 12.9s
# 223:	learn: 0.4852906	total: 3.72s	remaining: 12.9s
# 224:	learn: 0.4848257	total: 3.73s	remaining: 12.9s
# 225:	learn: 0.4838590	total: 3.75s	remaining: 12.9s
# 226:	learn: 0.4834754	total: 3.77s	remaining: 12.8s
# 227:	learn: 0.4831116	total: 3.78s	remaining: 12.8s
# 228:	learn: 0.4827354	total: 3.8s	remaining: 12.8s
# 229:	learn: 0.4824404	total: 3.82s	remaining: 12.8s
# 230:	learn: 0.4821735	total: 3.83s	remaining: 12.8s
# 231:	learn: 0.4816802	total: 3.85s	remaining: 12.7s
# 232:	learn: 0.4811383	total: 3.87s	remaining: 12.7s
# 233:	learn: 0.4807228	total: 3.88s	remaining: 12.7s
# 234:	learn: 0.4804394	total: 3.9s	remaining: 12.7s
# 235:	learn: 0.4799622	total: 3.91s	remaining: 12.7s
# 236:	learn: 0.4795263	total: 3.93s	remaining: 12.7s
# 237:	learn: 0.4790870	total: 3.95s	remaining: 12.6s
# 238:	learn: 0.4787024	total: 3.97s	remaining: 12.6s
# 239:	learn: 0.4782823	total: 3.98s	remaining: 12.6s
# 240:	learn: 0.4779721	total: 4s	remaining: 12.6s
# 241:	learn: 0.4776751	total: 4.01s	remaining: 12.6s
# 242:	learn: 0.4774363	total: 4.03s	remaining: 12.6s
# 243:	learn: 0.4769543	total: 4.04s	remaining: 12.5s
# 244:	learn: 0.4764811	total: 4.06s	remaining: 12.5s
# 245:	learn: 0.4760973	total: 4.08s	remaining: 12.5s
# 246:	learn: 0.4757098	total: 4.09s	remaining: 12.5s
# 247:	learn: 0.4754702	total: 4.11s	remaining: 12.5s
# 248:	learn: 0.4749183	total: 4.12s	remaining: 12.4s
# 249:	learn: 0.4744414	total: 4.14s	remaining: 12.4s
# 250:	learn: 0.4736610	total: 4.16s	remaining: 12.4s
# 251:	learn: 0.4733103	total: 4.17s	remaining: 12.4s
# 252:	learn: 0.4729514	total: 4.19s	remaining: 12.4s
# 253:	learn: 0.4724779	total: 4.21s	remaining: 12.4s
# 254:	learn: 0.4721271	total: 4.22s	remaining: 12.3s
# 255:	learn: 0.4717141	total: 4.24s	remaining: 12.3s
# 256:	learn: 0.4712271	total: 4.26s	remaining: 12.3s
# 257:	learn: 0.4708995	total: 4.28s	remaining: 12.3s
# 258:	learn: 0.4706876	total: 4.29s	remaining: 12.3s
# 259:	learn: 0.4703420	total: 4.31s	remaining: 12.3s
# 260:	learn: 0.4700158	total: 4.33s	remaining: 12.2s
# 261:	learn: 0.4696038	total: 4.34s	remaining: 12.2s
# 262:	learn: 0.4692443	total: 4.36s	remaining: 12.2s
# 263:	learn: 0.4689672	total: 4.38s	remaining: 12.2s
# 264:	learn: 0.4686152	total: 4.39s	remaining: 12.2s
# 265:	learn: 0.4683405	total: 4.41s	remaining: 12.2s
# 266:	learn: 0.4679161	total: 4.42s	remaining: 12.1s
# 267:	learn: 0.4675406	total: 4.44s	remaining: 12.1s
# 268:	learn: 0.4672902	total: 4.46s	remaining: 12.1s
# 269:	learn: 0.4670864	total: 4.47s	remaining: 12.1s
# 270:	learn: 0.4668635	total: 4.49s	remaining: 12.1s
# 271:	learn: 0.4665803	total: 4.5s	remaining: 12s
# 272:	learn: 0.4662340	total: 4.52s	remaining: 12s
# 273:	learn: 0.4659415	total: 4.53s	remaining: 12s
# 274:	learn: 0.4655655	total: 4.55s	remaining: 12s
# 275:	learn: 0.4651650	total: 4.57s	remaining: 12s
# 276:	learn: 0.4649314	total: 4.58s	remaining: 12s
# 277:	learn: 0.4646291	total: 4.6s	remaining: 11.9s
# 278:	learn: 0.4643130	total: 4.62s	remaining: 11.9s
# 279:	learn: 0.4638596	total: 4.63s	remaining: 11.9s
# 280:	learn: 0.4633403	total: 4.65s	remaining: 11.9s
# 281:	learn: 0.4630406	total: 4.67s	remaining: 11.9s
# 282:	learn: 0.4627941	total: 4.68s	remaining: 11.9s
# 283:	learn: 0.4625084	total: 4.7s	remaining: 11.8s
# 284:	learn: 0.4623379	total: 4.72s	remaining: 11.8s
# 285:	learn: 0.4620144	total: 4.73s	remaining: 11.8s
# 286:	learn: 0.4617755	total: 4.75s	remaining: 11.8s
# 287:	learn: 0.4613749	total: 4.77s	remaining: 11.8s
# 288:	learn: 0.4610608	total: 4.79s	remaining: 11.8s
# 289:	learn: 0.4607669	total: 4.8s	remaining: 11.8s
# 290:	learn: 0.4604938	total: 4.82s	remaining: 11.7s
# 291:	learn: 0.4601909	total: 4.84s	remaining: 11.7s
# 292:	learn: 0.4597733	total: 4.86s	remaining: 11.7s
# 293:	learn: 0.4594999	total: 4.87s	remaining: 11.7s
# 294:	learn: 0.4592470	total: 4.89s	remaining: 11.7s
# 295:	learn: 0.4589296	total: 4.91s	remaining: 11.7s
# 296:	learn: 0.4586616	total: 4.92s	remaining: 11.7s
# 297:	learn: 0.4583383	total: 4.94s	remaining: 11.6s
# 298:	learn: 0.4580602	total: 4.96s	remaining: 11.6s
# 299:	learn: 0.4578032	total: 4.97s	remaining: 11.6s
# 300:	learn: 0.4575971	total: 4.99s	remaining: 11.6s
# 301:	learn: 0.4573283	total: 5.01s	remaining: 11.6s
# 302:	learn: 0.4569969	total: 5.02s	remaining: 11.6s
# 303:	learn: 0.4568472	total: 5.04s	remaining: 11.5s
# 304:	learn: 0.4566831	total: 5.05s	remaining: 11.5s
# 305:	learn: 0.4564207	total: 5.07s	remaining: 11.5s
# 306:	learn: 0.4560608	total: 5.09s	remaining: 11.5s
# 307:	learn: 0.4557039	total: 5.11s	remaining: 11.5s
# 308:	learn: 0.4554404	total: 5.12s	remaining: 11.5s
# 309:	learn: 0.4552389	total: 5.14s	remaining: 11.4s
# 310:	learn: 0.4549387	total: 5.16s	remaining: 11.4s
# 311:	learn: 0.4547264	total: 5.17s	remaining: 11.4s
# 312:	learn: 0.4541927	total: 5.19s	remaining: 11.4s
# 313:	learn: 0.4538811	total: 5.21s	remaining: 11.4s
# 314:	learn: 0.4536620	total: 5.22s	remaining: 11.4s
# 315:	learn: 0.4533365	total: 5.24s	remaining: 11.3s
# 316:	learn: 0.4529836	total: 5.26s	remaining: 11.3s
# 317:	learn: 0.4526331	total: 5.27s	remaining: 11.3s
# 318:	learn: 0.4524217	total: 5.29s	remaining: 11.3s
# 319:	learn: 0.4522124	total: 5.31s	remaining: 11.3s
# 320:	learn: 0.4518128	total: 5.32s	remaining: 11.3s
# 321:	learn: 0.4515854	total: 5.34s	remaining: 11.2s
# 322:	learn: 0.4513457	total: 5.36s	remaining: 11.2s
# 323:	learn: 0.4511625	total: 5.4s	remaining: 11.3s
# 324:	learn: 0.4509086	total: 5.42s	remaining: 11.3s
# 325:	learn: 0.4506833	total: 5.44s	remaining: 11.3s
# 326:	learn: 0.4504314	total: 5.46s	remaining: 11.2s
# 327:	learn: 0.4499834	total: 5.47s	remaining: 11.2s
# 328:	learn: 0.4498015	total: 5.49s	remaining: 11.2s
# 329:	learn: 0.4495689	total: 5.5s	remaining: 11.2s
# 330:	learn: 0.4493628	total: 5.52s	remaining: 11.2s
# 331:	learn: 0.4492054	total: 5.54s	remaining: 11.1s
# 332:	learn: 0.4489679	total: 5.55s	remaining: 11.1s
# 333:	learn: 0.4486921	total: 5.57s	remaining: 11.1s
# 334:	learn: 0.4484285	total: 5.59s	remaining: 11.1s
# 335:	learn: 0.4482329	total: 5.6s	remaining: 11.1s
# 336:	learn: 0.4474735	total: 5.62s	remaining: 11.1s
# 337:	learn: 0.4471129	total: 5.64s	remaining: 11s
# 338:	learn: 0.4468129	total: 5.65s	remaining: 11s
# 339:	learn: 0.4465249	total: 5.67s	remaining: 11s
# 340:	learn: 0.4462765	total: 5.69s	remaining: 11s
# 341:	learn: 0.4460169	total: 5.71s	remaining: 11s
# 342:	learn: 0.4458287	total: 5.72s	remaining: 11s
# 343:	learn: 0.4456512	total: 5.74s	remaining: 10.9s
# 344:	learn: 0.4454388	total: 5.75s	remaining: 10.9s
# 345:	learn: 0.4452798	total: 5.77s	remaining: 10.9s
# 346:	learn: 0.4450794	total: 5.79s	remaining: 10.9s
# 347:	learn: 0.4448557	total: 5.81s	remaining: 10.9s
# 348:	learn: 0.4446659	total: 5.82s	remaining: 10.9s
# 349:	learn: 0.4443694	total: 5.84s	remaining: 10.8s
# 350:	learn: 0.4441760	total: 5.86s	remaining: 10.8s
# 351:	learn: 0.4439736	total: 5.87s	remaining: 10.8s
# 352:	learn: 0.4438124	total: 5.89s	remaining: 10.8s
# 353:	learn: 0.4435215	total: 5.9s	remaining: 10.8s
# 354:	learn: 0.4433195	total: 5.92s	remaining: 10.8s
# 355:	learn: 0.4431586	total: 5.94s	remaining: 10.7s
# 356:	learn: 0.4430079	total: 5.95s	remaining: 10.7s
# 357:	learn: 0.4427946	total: 5.97s	remaining: 10.7s
# 358:	learn: 0.4425581	total: 5.99s	remaining: 10.7s
# 359:	learn: 0.4423558	total: 6s	remaining: 10.7s
# 360:	learn: 0.4417890	total: 6.02s	remaining: 10.7s
# 361:	learn: 0.4414952	total: 6.04s	remaining: 10.6s
# 362:	learn: 0.4413300	total: 6.05s	remaining: 10.6s
# 363:	learn: 0.4411573	total: 6.07s	remaining: 10.6s
# 364:	learn: 0.4409041	total: 6.09s	remaining: 10.6s
# 365:	learn: 0.4406265	total: 6.1s	remaining: 10.6s
# 366:	learn: 0.4403917	total: 6.12s	remaining: 10.6s
# 367:	learn: 0.4402060	total: 6.14s	remaining: 10.5s
# 368:	learn: 0.4399769	total: 6.16s	remaining: 10.5s
# 369:	learn: 0.4398657	total: 6.17s	remaining: 10.5s
# 370:	learn: 0.4396290	total: 6.19s	remaining: 10.5s
# 371:	learn: 0.4392808	total: 6.21s	remaining: 10.5s
# 372:	learn: 0.4390952	total: 6.22s	remaining: 10.5s
# 373:	learn: 0.4389383	total: 6.24s	remaining: 10.4s
# 374:	learn: 0.4387927	total: 6.25s	remaining: 10.4s
# 375:	learn: 0.4386378	total: 6.27s	remaining: 10.4s
# 376:	learn: 0.4384430	total: 6.28s	remaining: 10.4s
# 377:	learn: 0.4382650	total: 6.3s	remaining: 10.4s
# 378:	learn: 0.4381063	total: 6.32s	remaining: 10.4s
# 379:	learn: 0.4379237	total: 6.33s	remaining: 10.3s
# 380:	learn: 0.4377974	total: 6.35s	remaining: 10.3s
# 381:	learn: 0.4376583	total: 6.37s	remaining: 10.3s
# 382:	learn: 0.4374807	total: 6.38s	remaining: 10.3s
# 383:	learn: 0.4372920	total: 6.4s	remaining: 10.3s
# 384:	learn: 0.4370418	total: 6.42s	remaining: 10.2s
# 385:	learn: 0.4368661	total: 6.43s	remaining: 10.2s
# 386:	learn: 0.4366779	total: 6.45s	remaining: 10.2s
# 387:	learn: 0.4363541	total: 6.46s	remaining: 10.2s
# 388:	learn: 0.4359304	total: 6.48s	remaining: 10.2s
# 389:	learn: 0.4357223	total: 6.5s	remaining: 10.2s
# 390:	learn: 0.4355984	total: 6.51s	remaining: 10.1s
# 391:	learn: 0.4354790	total: 6.53s	remaining: 10.1s
# 392:	learn: 0.4353110	total: 6.55s	remaining: 10.1s
# 393:	learn: 0.4350890	total: 6.57s	remaining: 10.1s
# 394:	learn: 0.4349635	total: 6.58s	remaining: 10.1s
# 395:	learn: 0.4347854	total: 6.6s	remaining: 10.1s
# 396:	learn: 0.4345232	total: 6.61s	remaining: 10s
# 397:	learn: 0.4343700	total: 6.63s	remaining: 10s
# 398:	learn: 0.4342135	total: 6.64s	remaining: 10s
# 399:	learn: 0.4340388	total: 6.66s	remaining: 9.99s
# 400:	learn: 0.4338392	total: 6.68s	remaining: 9.97s
# 401:	learn: 0.4336741	total: 6.69s	remaining: 9.96s
# 402:	learn: 0.4334961	total: 6.71s	remaining: 9.94s
# 403:	learn: 0.4333518	total: 6.72s	remaining: 9.92s
# 404:	learn: 0.4331280	total: 6.74s	remaining: 9.9s
# 405:	learn: 0.4329963	total: 6.75s	remaining: 9.88s
# 406:	learn: 0.4327735	total: 6.77s	remaining: 9.87s
# 407:	learn: 0.4326346	total: 6.79s	remaining: 9.85s
# 408:	learn: 0.4324284	total: 6.8s	remaining: 9.83s
# 409:	learn: 0.4322397	total: 6.82s	remaining: 9.82s
# 410:	learn: 0.4320722	total: 6.84s	remaining: 9.8s
# 411:	learn: 0.4319599	total: 6.86s	remaining: 9.79s
# 412:	learn: 0.4317477	total: 6.88s	remaining: 9.77s
# 413:	learn: 0.4315924	total: 6.89s	remaining: 9.76s
# 414:	learn: 0.4314197	total: 6.91s	remaining: 9.74s
# 415:	learn: 0.4312079	total: 6.93s	remaining: 9.73s
# 416:	learn: 0.4310610	total: 6.95s	remaining: 9.71s
# 417:	learn: 0.4308937	total: 6.96s	remaining: 9.7s
# 418:	learn: 0.4306469	total: 6.98s	remaining: 9.68s
# 419:	learn: 0.4304554	total: 7s	remaining: 9.67s
# 420:	learn: 0.4303424	total: 7.02s	remaining: 9.65s
# 421:	learn: 0.4301468	total: 7.04s	remaining: 9.64s
# 422:	learn: 0.4300115	total: 7.06s	remaining: 9.63s
# 423:	learn: 0.4298818	total: 7.07s	remaining: 9.61s
# 424:	learn: 0.4297499	total: 7.09s	remaining: 9.59s
# 425:	learn: 0.4294991	total: 7.11s	remaining: 9.57s
# 426:	learn: 0.4294048	total: 7.12s	remaining: 9.55s
# 427:	learn: 0.4292149	total: 7.14s	remaining: 9.54s
# 428:	learn: 0.4290859	total: 7.15s	remaining: 9.52s
# 429:	learn: 0.4286995	total: 7.17s	remaining: 9.5s
# 430:	learn: 0.4285472	total: 7.18s	remaining: 9.48s
# 431:	learn: 0.4283758	total: 7.2s	remaining: 9.47s
# 432:	learn: 0.4282359	total: 7.22s	remaining: 9.45s
# 433:	learn: 0.4279999	total: 7.24s	remaining: 9.44s
# 434:	learn: 0.4277687	total: 7.25s	remaining: 9.42s
# 435:	learn: 0.4276155	total: 7.27s	remaining: 9.4s
# 436:	learn: 0.4274848	total: 7.28s	remaining: 9.38s
# 437:	learn: 0.4273665	total: 7.3s	remaining: 9.37s
# 438:	learn: 0.4270285	total: 7.32s	remaining: 9.35s
# 439:	learn: 0.4268876	total: 7.33s	remaining: 9.33s
# 440:	learn: 0.4262408	total: 7.35s	remaining: 9.32s
# 441:	learn: 0.4258548	total: 7.37s	remaining: 9.3s
# 442:	learn: 0.4257355	total: 7.38s	remaining: 9.29s
# 443:	learn: 0.4256177	total: 7.4s	remaining: 9.27s
# 444:	learn: 0.4254938	total: 7.42s	remaining: 9.25s
# 445:	learn: 0.4253209	total: 7.43s	remaining: 9.23s
# 446:	learn: 0.4250145	total: 7.45s	remaining: 9.22s
# 447:	learn: 0.4247949	total: 7.47s	remaining: 9.2s
# 448:	learn: 0.4246436	total: 7.48s	remaining: 9.19s
# 449:	learn: 0.4245172	total: 7.5s	remaining: 9.17s
# 450:	learn: 0.4243676	total: 7.52s	remaining: 9.15s
# 451:	learn: 0.4242095	total: 7.54s	remaining: 9.14s
# 452:	learn: 0.4241083	total: 7.55s	remaining: 9.12s
# 453:	learn: 0.4239378	total: 7.57s	remaining: 9.1s
# 454:	learn: 0.4237707	total: 7.58s	remaining: 9.09s
# 455:	learn: 0.4236437	total: 7.6s	remaining: 9.07s
# 456:	learn: 0.4234463	total: 7.62s	remaining: 9.05s
# 457:	learn: 0.4233094	total: 7.64s	remaining: 9.04s
# 458:	learn: 0.4231538	total: 7.65s	remaining: 9.02s
# 459:	learn: 0.4230175	total: 7.67s	remaining: 9.01s
# 460:	learn: 0.4228326	total: 7.69s	remaining: 8.99s
# 461:	learn: 0.4227319	total: 7.71s	remaining: 8.97s
# 462:	learn: 0.4225514	total: 7.72s	remaining: 8.96s
# 463:	learn: 0.4223966	total: 7.74s	remaining: 8.94s
# 464:	learn: 0.4222420	total: 7.76s	remaining: 8.92s
# 465:	learn: 0.4219769	total: 7.77s	remaining: 8.91s
# 466:	learn: 0.4218521	total: 7.79s	remaining: 8.89s
# 467:	learn: 0.4217253	total: 7.81s	remaining: 8.88s
# 468:	learn: 0.4216252	total: 7.82s	remaining: 8.86s
# 469:	learn: 0.4214658	total: 7.84s	remaining: 8.84s
# 470:	learn: 0.4213597	total: 7.86s	remaining: 8.82s
# 471:	learn: 0.4212609	total: 7.87s	remaining: 8.81s
# 472:	learn: 0.4211209	total: 7.89s	remaining: 8.79s
# 473:	learn: 0.4210090	total: 7.91s	remaining: 8.77s
# 474:	learn: 0.4208682	total: 7.92s	remaining: 8.76s
# 475:	learn: 0.4207463	total: 7.94s	remaining: 8.74s
# 476:	learn: 0.4206357	total: 7.96s	remaining: 8.72s
# 477:	learn: 0.4204588	total: 7.97s	remaining: 8.71s
# 478:	learn: 0.4203064	total: 7.99s	remaining: 8.69s
# 479:	learn: 0.4201674	total: 8.01s	remaining: 8.67s
# 480:	learn: 0.4200613	total: 8.02s	remaining: 8.65s
# 481:	learn: 0.4197181	total: 8.04s	remaining: 8.64s
# 482:	learn: 0.4196242	total: 8.05s	remaining: 8.62s
# 483:	learn: 0.4194869	total: 8.07s	remaining: 8.61s
# 484:	learn: 0.4192226	total: 8.09s	remaining: 8.59s
# 485:	learn: 0.4190645	total: 8.11s	remaining: 8.57s
# 486:	learn: 0.4189381	total: 8.12s	remaining: 8.56s
# 487:	learn: 0.4187379	total: 8.14s	remaining: 8.54s
# 488:	learn: 0.4183342	total: 8.16s	remaining: 8.52s
# 489:	learn: 0.4182204	total: 8.17s	remaining: 8.51s
# 490:	learn: 0.4180918	total: 8.19s	remaining: 8.49s
# 491:	learn: 0.4179738	total: 8.21s	remaining: 8.47s
# 492:	learn: 0.4177961	total: 8.22s	remaining: 8.46s
# 493:	learn: 0.4176759	total: 8.24s	remaining: 8.44s
# 494:	learn: 0.4175021	total: 8.26s	remaining: 8.42s
# 495:	learn: 0.4172953	total: 8.27s	remaining: 8.41s
# 496:	learn: 0.4171755	total: 8.29s	remaining: 8.39s
# 497:	learn: 0.4170291	total: 8.31s	remaining: 8.37s
# 498:	learn: 0.4169597	total: 8.32s	remaining: 8.35s
# 499:	learn: 0.4168191	total: 8.34s	remaining: 8.34s
# 500:	learn: 0.4166535	total: 8.36s	remaining: 8.32s
# 501:	learn: 0.4164932	total: 8.37s	remaining: 8.31s
# 502:	learn: 0.4163362	total: 8.39s	remaining: 8.29s
# 503:	learn: 0.4162286	total: 8.41s	remaining: 8.27s
# 504:	learn: 0.4160635	total: 8.42s	remaining: 8.26s
# 505:	learn: 0.4158358	total: 8.44s	remaining: 8.24s
# 506:	learn: 0.4157119	total: 8.46s	remaining: 8.22s
# 507:	learn: 0.4155956	total: 8.47s	remaining: 8.21s
# 508:	learn: 0.4154642	total: 8.49s	remaining: 8.19s
# 509:	learn: 0.4153737	total: 8.5s	remaining: 8.17s
# 510:	learn: 0.4152028	total: 8.52s	remaining: 8.15s
# 511:	learn: 0.4148932	total: 8.54s	remaining: 8.14s
# 512:	learn: 0.4147911	total: 8.56s	remaining: 8.12s
# 513:	learn: 0.4145893	total: 8.57s	remaining: 8.11s
# 514:	learn: 0.4144641	total: 8.59s	remaining: 8.09s
# 515:	learn: 0.4143421	total: 8.61s	remaining: 8.07s
# 516:	learn: 0.4142177	total: 8.62s	remaining: 8.06s
# 517:	learn: 0.4140238	total: 8.64s	remaining: 8.04s
# 518:	learn: 0.4139192	total: 8.66s	remaining: 8.02s
# 519:	learn: 0.4138058	total: 8.67s	remaining: 8.01s
# 520:	learn: 0.4137123	total: 8.69s	remaining: 7.99s
# 521:	learn: 0.4136069	total: 8.71s	remaining: 7.97s
# 522:	learn: 0.4134722	total: 8.72s	remaining: 7.96s
# 523:	learn: 0.4133763	total: 8.74s	remaining: 7.94s
# 524:	learn: 0.4131998	total: 8.76s	remaining: 7.92s
# 525:	learn: 0.4130805	total: 8.77s	remaining: 7.91s
# 526:	learn: 0.4127783	total: 8.79s	remaining: 7.89s
# 527:	learn: 0.4126894	total: 8.81s	remaining: 7.87s
# 528:	learn: 0.4125890	total: 8.82s	remaining: 7.85s
# 529:	learn: 0.4124998	total: 8.84s	remaining: 7.84s
# 530:	learn: 0.4123002	total: 8.85s	remaining: 7.82s
# 531:	learn: 0.4122083	total: 8.87s	remaining: 7.8s
# 532:	learn: 0.4121019	total: 8.88s	remaining: 7.78s
# 533:	learn: 0.4119487	total: 8.9s	remaining: 7.77s
# 534:	learn: 0.4118413	total: 8.91s	remaining: 7.75s
# 535:	learn: 0.4117367	total: 8.93s	remaining: 7.73s
# 536:	learn: 0.4116262	total: 8.95s	remaining: 7.72s
# 537:	learn: 0.4115604	total: 8.97s	remaining: 7.7s
# 538:	learn: 0.4113980	total: 8.98s	remaining: 7.68s
# 539:	learn: 0.4113001	total: 9s	remaining: 7.67s
# 540:	learn: 0.4111850	total: 9.02s	remaining: 7.65s
# 541:	learn: 0.4110408	total: 9.03s	remaining: 7.63s
# 542:	learn: 0.4109122	total: 9.05s	remaining: 7.62s
# 543:	learn: 0.4108090	total: 9.07s	remaining: 7.6s
# 544:	learn: 0.4107118	total: 9.08s	remaining: 7.58s
# 545:	learn: 0.4106474	total: 9.1s	remaining: 7.57s
# 546:	learn: 0.4104687	total: 9.12s	remaining: 7.55s
# 547:	learn: 0.4103399	total: 9.13s	remaining: 7.53s
# 548:	learn: 0.4102634	total: 9.15s	remaining: 7.51s
# 549:	learn: 0.4101452	total: 9.17s	remaining: 7.5s
# 550:	learn: 0.4100496	total: 9.18s	remaining: 7.48s
# 551:	learn: 0.4099046	total: 9.2s	remaining: 7.46s
# 552:	learn: 0.4098249	total: 9.21s	remaining: 7.45s
# 553:	learn: 0.4097123	total: 9.23s	remaining: 7.43s
# 554:	learn: 0.4096334	total: 9.25s	remaining: 7.42s
# 555:	learn: 0.4093829	total: 9.27s	remaining: 7.4s
# 556:	learn: 0.4091971	total: 9.28s	remaining: 7.38s
# 557:	learn: 0.4091239	total: 9.3s	remaining: 7.37s
# 558:	learn: 0.4089984	total: 9.32s	remaining: 7.35s
# 559:	learn: 0.4089065	total: 9.34s	remaining: 7.34s
# 560:	learn: 0.4087966	total: 9.36s	remaining: 7.32s
# 561:	learn: 0.4086968	total: 9.37s	remaining: 7.3s
# 562:	learn: 0.4085269	total: 9.39s	remaining: 7.29s
# 563:	learn: 0.4084130	total: 9.41s	remaining: 7.27s
# 564:	learn: 0.4083042	total: 9.43s	remaining: 7.26s
# 565:	learn: 0.4082173	total: 9.45s	remaining: 7.24s
# 566:	learn: 0.4080915	total: 9.46s	remaining: 7.23s
# 567:	learn: 0.4079781	total: 9.48s	remaining: 7.21s
# 568:	learn: 0.4078557	total: 9.5s	remaining: 7.19s
# 569:	learn: 0.4077719	total: 9.51s	remaining: 7.18s
# 570:	learn: 0.4077106	total: 9.53s	remaining: 7.16s
# 571:	learn: 0.4075964	total: 9.54s	remaining: 7.14s
# 572:	learn: 0.4074965	total: 9.56s	remaining: 7.13s
# 573:	learn: 0.4073245	total: 9.58s	remaining: 7.11s
# 574:	learn: 0.4072100	total: 9.6s	remaining: 7.09s
# 575:	learn: 0.4070680	total: 9.62s	remaining: 7.08s
# 576:	learn: 0.4069949	total: 9.63s	remaining: 7.06s
# 577:	learn: 0.4068939	total: 9.65s	remaining: 7.04s
# 578:	learn: 0.4068059	total: 9.66s	remaining: 7.03s
# 579:	learn: 0.4067151	total: 9.68s	remaining: 7.01s
# 580:	learn: 0.4066134	total: 9.7s	remaining: 6.99s
# 581:	learn: 0.4064442	total: 9.71s	remaining: 6.97s
# 582:	learn: 0.4063893	total: 9.73s	remaining: 6.96s
# 583:	learn: 0.4062907	total: 9.74s	remaining: 6.94s
# 584:	learn: 0.4062020	total: 9.76s	remaining: 6.92s
# 585:	learn: 0.4059957	total: 9.78s	remaining: 6.91s
# 586:	learn: 0.4058792	total: 9.8s	remaining: 6.89s
# 587:	learn: 0.4058052	total: 9.81s	remaining: 6.88s
# 588:	learn: 0.4057041	total: 9.83s	remaining: 6.86s
# 589:	learn: 0.4055838	total: 9.85s	remaining: 6.84s
# 590:	learn: 0.4055128	total: 9.86s	remaining: 6.83s
# 591:	learn: 0.4054300	total: 9.88s	remaining: 6.81s
# 592:	learn: 0.4053481	total: 9.9s	remaining: 6.79s
# 593:	learn: 0.4052789	total: 9.91s	remaining: 6.78s
# 594:	learn: 0.4051878	total: 9.93s	remaining: 6.76s
# 595:	learn: 0.4049894	total: 9.95s	remaining: 6.74s
# 596:	learn: 0.4048446	total: 9.96s	remaining: 6.73s
# 597:	learn: 0.4047494	total: 9.98s	remaining: 6.71s
# 598:	learn: 0.4046531	total: 10s	remaining: 6.7s
# 599:	learn: 0.4045563	total: 10s	remaining: 6.68s
# 600:	learn: 0.4044658	total: 10s	remaining: 6.66s
# 601:	learn: 0.4043712	total: 10.1s	remaining: 6.64s
# 602:	learn: 0.4043062	total: 10.1s	remaining: 6.63s
# 603:	learn: 0.4041847	total: 10.1s	remaining: 6.61s
# 604:	learn: 0.4040777	total: 10.1s	remaining: 6.59s
# 605:	learn: 0.4039749	total: 10.1s	remaining: 6.58s
# 606:	learn: 0.4039011	total: 10.1s	remaining: 6.56s
# 607:	learn: 0.4038139	total: 10.1s	remaining: 6.54s
# 608:	learn: 0.4037337	total: 10.2s	remaining: 6.53s
# 609:	learn: 0.4036623	total: 10.2s	remaining: 6.51s
# 610:	learn: 0.4035409	total: 10.2s	remaining: 6.49s
# 611:	learn: 0.4034622	total: 10.2s	remaining: 6.48s
# 612:	learn: 0.4033257	total: 10.2s	remaining: 6.46s
# 613:	learn: 0.4032353	total: 10.2s	remaining: 6.44s
# 614:	learn: 0.4030999	total: 10.3s	remaining: 6.43s
# 615:	learn: 0.4030034	total: 10.3s	remaining: 6.41s
# 616:	learn: 0.4028802	total: 10.3s	remaining: 6.39s
# 617:	learn: 0.4028023	total: 10.3s	remaining: 6.38s
# 618:	learn: 0.4026969	total: 10.3s	remaining: 6.36s
# 619:	learn: 0.4025309	total: 10.4s	remaining: 6.34s
# 620:	learn: 0.4024270	total: 10.4s	remaining: 6.33s
# 621:	learn: 0.4023373	total: 10.4s	remaining: 6.31s
# 622:	learn: 0.4021957	total: 10.4s	remaining: 6.29s
# 623:	learn: 0.4021222	total: 10.4s	remaining: 6.28s
# 624:	learn: 0.4020521	total: 10.4s	remaining: 6.26s
# 625:	learn: 0.4019835	total: 10.4s	remaining: 6.24s
# 626:	learn: 0.4017863	total: 10.5s	remaining: 6.23s
# 627:	learn: 0.4017113	total: 10.5s	remaining: 6.21s
# 628:	learn: 0.4015324	total: 10.5s	remaining: 6.19s
# 629:	learn: 0.4012161	total: 10.5s	remaining: 6.18s
# 630:	learn: 0.4011102	total: 10.5s	remaining: 6.16s
# 631:	learn: 0.4009165	total: 10.6s	remaining: 6.15s
# 632:	learn: 0.4008420	total: 10.6s	remaining: 6.13s
# 633:	learn: 0.4007555	total: 10.6s	remaining: 6.11s
# 634:	learn: 0.4006911	total: 10.6s	remaining: 6.09s
# 635:	learn: 0.4006184	total: 10.6s	remaining: 6.08s
# 636:	learn: 0.4005333	total: 10.6s	remaining: 6.06s
# 637:	learn: 0.4004634	total: 10.7s	remaining: 6.04s
# 638:	learn: 0.4003963	total: 10.7s	remaining: 6.03s
# 639:	learn: 0.4003072	total: 10.7s	remaining: 6.01s
# 640:	learn: 0.4002175	total: 10.7s	remaining: 5.99s
# 641:	learn: 0.4001421	total: 10.7s	remaining: 5.97s
# 642:	learn: 0.4000511	total: 10.7s	remaining: 5.96s
# 643:	learn: 0.3999350	total: 10.8s	remaining: 5.94s
# 644:	learn: 0.3998595	total: 10.8s	remaining: 5.92s
# 645:	learn: 0.3997715	total: 10.8s	remaining: 5.91s
# 646:	learn: 0.3997312	total: 10.8s	remaining: 5.89s
# 647:	learn: 0.3996347	total: 10.8s	remaining: 5.87s
# 648:	learn: 0.3996013	total: 10.8s	remaining: 5.86s
# 649:	learn: 0.3995369	total: 10.8s	remaining: 5.84s
# 650:	learn: 0.3994958	total: 10.9s	remaining: 5.82s
# 651:	learn: 0.3994063	total: 10.9s	remaining: 5.8s
# 652:	learn: 0.3993202	total: 10.9s	remaining: 5.79s
# 653:	learn: 0.3992465	total: 10.9s	remaining: 5.77s
# 654:	learn: 0.3991435	total: 10.9s	remaining: 5.75s
# 655:	learn: 0.3990499	total: 10.9s	remaining: 5.74s
# 656:	learn: 0.3989833	total: 11s	remaining: 5.72s
# 657:	learn: 0.3988692	total: 11s	remaining: 5.71s
# 658:	learn: 0.3987474	total: 11s	remaining: 5.69s
# 659:	learn: 0.3986430	total: 11s	remaining: 5.67s
# 660:	learn: 0.3985518	total: 11s	remaining: 5.66s
# 661:	learn: 0.3984847	total: 11s	remaining: 5.64s
# 662:	learn: 0.3982697	total: 11.1s	remaining: 5.62s
# 663:	learn: 0.3981432	total: 11.1s	remaining: 5.61s
# 664:	learn: 0.3980129	total: 11.1s	remaining: 5.59s
# 665:	learn: 0.3978261	total: 11.1s	remaining: 5.57s
# 666:	learn: 0.3977197	total: 11.1s	remaining: 5.56s
# 667:	learn: 0.3976601	total: 11.1s	remaining: 5.54s
# 668:	learn: 0.3975388	total: 11.2s	remaining: 5.52s
# 669:	learn: 0.3974682	total: 11.2s	remaining: 5.51s
# 670:	learn: 0.3974144	total: 11.2s	remaining: 5.49s
# 671:	learn: 0.3973610	total: 11.2s	remaining: 5.47s
# 672:	learn: 0.3972781	total: 11.2s	remaining: 5.46s
# 673:	learn: 0.3971544	total: 11.2s	remaining: 5.44s
# 674:	learn: 0.3970485	total: 11.3s	remaining: 5.42s
# 675:	learn: 0.3969714	total: 11.3s	remaining: 5.41s
# 676:	learn: 0.3967796	total: 11.3s	remaining: 5.39s
# 677:	learn: 0.3967124	total: 11.3s	remaining: 5.37s
# 678:	learn: 0.3966369	total: 11.3s	remaining: 5.36s
# 679:	learn: 0.3965400	total: 11.3s	remaining: 5.34s
# 680:	learn: 0.3964651	total: 11.4s	remaining: 5.32s
# 681:	learn: 0.3963489	total: 11.4s	remaining: 5.31s
# 682:	learn: 0.3962729	total: 11.4s	remaining: 5.29s
# 683:	learn: 0.3961767	total: 11.4s	remaining: 5.27s
# 684:	learn: 0.3961212	total: 11.4s	remaining: 5.26s
# 685:	learn: 0.3960085	total: 11.4s	remaining: 5.24s
# 686:	learn: 0.3959230	total: 11.5s	remaining: 5.22s
# 687:	learn: 0.3958483	total: 11.5s	remaining: 5.21s
# 688:	learn: 0.3957242	total: 11.5s	remaining: 5.19s
# 689:	learn: 0.3955879	total: 11.5s	remaining: 5.17s
# 690:	learn: 0.3955425	total: 11.5s	remaining: 5.16s
# 691:	learn: 0.3954661	total: 11.6s	remaining: 5.14s
# 692:	learn: 0.3952253	total: 11.6s	remaining: 5.12s
# 693:	learn: 0.3951504	total: 11.6s	remaining: 5.11s
# 694:	learn: 0.3950574	total: 11.6s	remaining: 5.09s
# 695:	learn: 0.3949987	total: 11.6s	remaining: 5.07s
# 696:	learn: 0.3947772	total: 11.6s	remaining: 5.06s
# 697:	learn: 0.3947193	total: 11.7s	remaining: 5.04s
# 698:	learn: 0.3946841	total: 11.7s	remaining: 5.02s
# 699:	learn: 0.3946292	total: 11.7s	remaining: 5.01s
# 700:	learn: 0.3945590	total: 11.7s	remaining: 4.99s
# 701:	learn: 0.3944789	total: 11.7s	remaining: 4.97s
# 702:	learn: 0.3944186	total: 11.7s	remaining: 4.96s
# 703:	learn: 0.3943747	total: 11.7s	remaining: 4.94s
# 704:	learn: 0.3942551	total: 11.8s	remaining: 4.92s
# 705:	learn: 0.3941967	total: 11.8s	remaining: 4.91s
# 706:	learn: 0.3941229	total: 11.8s	remaining: 4.89s
# 707:	learn: 0.3940431	total: 11.8s	remaining: 4.87s
# 708:	learn: 0.3939596	total: 11.8s	remaining: 4.86s
# 709:	learn: 0.3938425	total: 11.8s	remaining: 4.84s
# 710:	learn: 0.3937858	total: 11.9s	remaining: 4.82s
# 711:	learn: 0.3936999	total: 11.9s	remaining: 4.81s
# 712:	learn: 0.3936152	total: 11.9s	remaining: 4.79s
# 713:	learn: 0.3935404	total: 11.9s	remaining: 4.77s
# 714:	learn: 0.3934252	total: 11.9s	remaining: 4.75s
# 715:	learn: 0.3933123	total: 11.9s	remaining: 4.74s
# 716:	learn: 0.3932320	total: 12s	remaining: 4.72s
# 717:	learn: 0.3931663	total: 12s	remaining: 4.71s
# 718:	learn: 0.3930044	total: 12s	remaining: 4.69s
# 719:	learn: 0.3929311	total: 12s	remaining: 4.67s
# 720:	learn: 0.3928622	total: 12s	remaining: 4.66s
# 721:	learn: 0.3927964	total: 12s	remaining: 4.64s
# 722:	learn: 0.3927543	total: 12.1s	remaining: 4.62s
# 723:	learn: 0.3927125	total: 12.1s	remaining: 4.6s
# 724:	learn: 0.3926607	total: 12.1s	remaining: 4.59s
# 725:	learn: 0.3925690	total: 12.1s	remaining: 4.57s
# 726:	learn: 0.3925214	total: 12.1s	remaining: 4.55s
# 727:	learn: 0.3923777	total: 12.1s	remaining: 4.54s
# 728:	learn: 0.3922544	total: 12.2s	remaining: 4.52s
# 729:	learn: 0.3922136	total: 12.2s	remaining: 4.5s
# 730:	learn: 0.3921181	total: 12.2s	remaining: 4.49s
# 731:	learn: 0.3920248	total: 12.2s	remaining: 4.47s
# 732:	learn: 0.3919852	total: 12.2s	remaining: 4.45s
# 733:	learn: 0.3919092	total: 12.2s	remaining: 4.44s
# 734:	learn: 0.3918468	total: 12.3s	remaining: 4.42s
# 735:	learn: 0.3917602	total: 12.3s	remaining: 4.4s
# 736:	learn: 0.3917209	total: 12.3s	remaining: 4.39s
# 737:	learn: 0.3915527	total: 12.3s	remaining: 4.37s
# 738:	learn: 0.3914838	total: 12.3s	remaining: 4.35s
# 739:	learn: 0.3913799	total: 12.3s	remaining: 4.34s
# 740:	learn: 0.3913115	total: 12.4s	remaining: 4.32s
# 741:	learn: 0.3912340	total: 12.4s	remaining: 4.3s
# 742:	learn: 0.3911838	total: 12.4s	remaining: 4.29s
# 743:	learn: 0.3911067	total: 12.4s	remaining: 4.27s
# 744:	learn: 0.3910243	total: 12.4s	remaining: 4.25s
# 745:	learn: 0.3909533	total: 12.4s	remaining: 4.24s
# 746:	learn: 0.3908517	total: 12.5s	remaining: 4.22s
# 747:	learn: 0.3907655	total: 12.5s	remaining: 4.2s
# 748:	learn: 0.3907010	total: 12.5s	remaining: 4.19s
# 749:	learn: 0.3905855	total: 12.5s	remaining: 4.17s
# 750:	learn: 0.3903772	total: 12.5s	remaining: 4.15s
# 751:	learn: 0.3903119	total: 12.5s	remaining: 4.14s
# 752:	learn: 0.3902524	total: 12.6s	remaining: 4.12s
# 753:	learn: 0.3901552	total: 12.6s	remaining: 4.1s
# 754:	learn: 0.3900891	total: 12.6s	remaining: 4.09s
# 755:	learn: 0.3900067	total: 12.6s	remaining: 4.07s
# 756:	learn: 0.3899233	total: 12.6s	remaining: 4.05s
# 757:	learn: 0.3898639	total: 12.7s	remaining: 4.04s
# 758:	learn: 0.3898203	total: 12.7s	remaining: 4.02s
# 759:	learn: 0.3897268	total: 12.7s	remaining: 4s
# 760:	learn: 0.3896549	total: 12.7s	remaining: 3.99s
# 761:	learn: 0.3895974	total: 12.7s	remaining: 3.97s
# 762:	learn: 0.3895247	total: 12.7s	remaining: 3.96s
# 763:	learn: 0.3894252	total: 12.8s	remaining: 3.94s
# 764:	learn: 0.3893573	total: 12.8s	remaining: 3.92s
# 765:	learn: 0.3893016	total: 12.8s	remaining: 3.9s
# 766:	learn: 0.3892354	total: 12.8s	remaining: 3.89s
# 767:	learn: 0.3891656	total: 12.8s	remaining: 3.87s
# 768:	learn: 0.3891245	total: 12.8s	remaining: 3.85s
# 769:	learn: 0.3890231	total: 12.9s	remaining: 3.84s
# 770:	learn: 0.3889636	total: 12.9s	remaining: 3.82s
# 771:	learn: 0.3889185	total: 12.9s	remaining: 3.81s
# 772:	learn: 0.3888422	total: 12.9s	remaining: 3.79s
# 773:	learn: 0.3887508	total: 12.9s	remaining: 3.77s
# 774:	learn: 0.3886820	total: 12.9s	remaining: 3.75s
# 775:	learn: 0.3886148	total: 13s	remaining: 3.74s
# 776:	learn: 0.3885585	total: 13s	remaining: 3.72s
# 777:	learn: 0.3885282	total: 13s	remaining: 3.7s
# 778:	learn: 0.3884101	total: 13s	remaining: 3.69s
# 779:	learn: 0.3883334	total: 13s	remaining: 3.67s
# 780:	learn: 0.3882677	total: 13s	remaining: 3.65s
# 781:	learn: 0.3882180	total: 13.1s	remaining: 3.64s
# 782:	learn: 0.3880951	total: 13.1s	remaining: 3.62s
# 783:	learn: 0.3880607	total: 13.1s	remaining: 3.6s
# 784:	learn: 0.3879963	total: 13.1s	remaining: 3.59s
# 785:	learn: 0.3879207	total: 13.1s	remaining: 3.57s
# 786:	learn: 0.3878756	total: 13.1s	remaining: 3.55s
# 787:	learn: 0.3877850	total: 13.2s	remaining: 3.54s
# 788:	learn: 0.3877056	total: 13.2s	remaining: 3.52s
# 789:	learn: 0.3876496	total: 13.2s	remaining: 3.5s
# 790:	learn: 0.3875863	total: 13.2s	remaining: 3.49s
# 791:	learn: 0.3874756	total: 13.2s	remaining: 3.47s
# 792:	learn: 0.3874430	total: 13.2s	remaining: 3.46s
# 793:	learn: 0.3873674	total: 13.3s	remaining: 3.44s
# 794:	learn: 0.3872638	total: 13.3s	remaining: 3.42s
# 795:	learn: 0.3871872	total: 13.3s	remaining: 3.4s
# 796:	learn: 0.3870983	total: 13.3s	remaining: 3.39s
# 797:	learn: 0.3870313	total: 13.3s	remaining: 3.37s
# 798:	learn: 0.3869951	total: 13.3s	remaining: 3.35s
# 799:	learn: 0.3869296	total: 13.4s	remaining: 3.34s
# 800:	learn: 0.3868610	total: 13.4s	remaining: 3.32s
# 801:	learn: 0.3868125	total: 13.4s	remaining: 3.3s
# 802:	learn: 0.3867536	total: 13.4s	remaining: 3.29s
# 803:	learn: 0.3866956	total: 13.4s	remaining: 3.27s
# 804:	learn: 0.3866364	total: 13.4s	remaining: 3.25s
# 805:	learn: 0.3865408	total: 13.4s	remaining: 3.24s
# 806:	learn: 0.3864842	total: 13.5s	remaining: 3.22s
# 807:	learn: 0.3864402	total: 13.5s	remaining: 3.2s
# 808:	learn: 0.3864016	total: 13.5s	remaining: 3.19s
# 809:	learn: 0.3863323	total: 13.5s	remaining: 3.17s
# 810:	learn: 0.3862787	total: 13.5s	remaining: 3.15s
# 811:	learn: 0.3860911	total: 13.5s	remaining: 3.14s
# 812:	learn: 0.3859983	total: 13.6s	remaining: 3.12s
# 813:	learn: 0.3859586	total: 13.6s	remaining: 3.1s
# 814:	learn: 0.3858537	total: 13.6s	remaining: 3.09s
# 815:	learn: 0.3857957	total: 13.6s	remaining: 3.07s
# 816:	learn: 0.3857375	total: 13.6s	remaining: 3.05s
# 817:	learn: 0.3856523	total: 13.6s	remaining: 3.04s
# 818:	learn: 0.3856178	total: 13.7s	remaining: 3.02s
# 819:	learn: 0.3855783	total: 13.7s	remaining: 3s
# 820:	learn: 0.3855118	total: 13.7s	remaining: 2.99s
# 821:	learn: 0.3854034	total: 13.7s	remaining: 2.97s
# 822:	learn: 0.3853355	total: 13.7s	remaining: 2.95s
# 823:	learn: 0.3852851	total: 13.8s	remaining: 2.94s
# 824:	learn: 0.3852176	total: 13.8s	remaining: 2.92s
# 825:	learn: 0.3851589	total: 13.8s	remaining: 2.9s
# 826:	learn: 0.3849956	total: 13.8s	remaining: 2.89s
# 827:	learn: 0.3849428	total: 13.8s	remaining: 2.87s
# 828:	learn: 0.3848859	total: 13.8s	remaining: 2.85s
# 829:	learn: 0.3848297	total: 13.9s	remaining: 2.84s
# 830:	learn: 0.3848004	total: 13.9s	remaining: 2.82s
# 831:	learn: 0.3847443	total: 13.9s	remaining: 2.8s
# 832:	learn: 0.3846800	total: 13.9s	remaining: 2.79s
# 833:	learn: 0.3845973	total: 13.9s	remaining: 2.77s
# 834:	learn: 0.3845202	total: 13.9s	remaining: 2.75s
# 835:	learn: 0.3844668	total: 13.9s	remaining: 2.74s
# 836:	learn: 0.3844029	total: 14s	remaining: 2.72s
# 837:	learn: 0.3843547	total: 14s	remaining: 2.7s
# 838:	learn: 0.3843316	total: 14s	remaining: 2.69s
# 839:	learn: 0.3842652	total: 14s	remaining: 2.67s
# 840:	learn: 0.3841672	total: 14s	remaining: 2.65s
# 841:	learn: 0.3840961	total: 14.1s	remaining: 2.64s
# 842:	learn: 0.3840400	total: 14.1s	remaining: 2.62s
# 843:	learn: 0.3839938	total: 14.1s	remaining: 2.6s
# 844:	learn: 0.3839431	total: 14.1s	remaining: 2.58s
# 845:	learn: 0.3839029	total: 14.1s	remaining: 2.57s
# 846:	learn: 0.3838486	total: 14.1s	remaining: 2.55s
# 847:	learn: 0.3837779	total: 14.1s	remaining: 2.54s
# 848:	learn: 0.3837345	total: 14.2s	remaining: 2.52s
# 849:	learn: 0.3836709	total: 14.2s	remaining: 2.5s
# 850:	learn: 0.3836240	total: 14.2s	remaining: 2.48s
# 851:	learn: 0.3835233	total: 14.2s	remaining: 2.47s
# 852:	learn: 0.3834730	total: 14.2s	remaining: 2.45s
# 853:	learn: 0.3834104	total: 14.2s	remaining: 2.44s
# 854:	learn: 0.3833751	total: 14.3s	remaining: 2.42s
# 855:	learn: 0.3832567	total: 14.3s	remaining: 2.4s
# 856:	learn: 0.3832235	total: 14.3s	remaining: 2.38s
# 857:	learn: 0.3831718	total: 14.3s	remaining: 2.37s
# 858:	learn: 0.3831225	total: 14.3s	remaining: 2.35s
# 859:	learn: 0.3830742	total: 14.3s	remaining: 2.33s
# 860:	learn: 0.3830319	total: 14.4s	remaining: 2.32s
# 861:	learn: 0.3829911	total: 14.4s	remaining: 2.3s
# 862:	learn: 0.3829361	total: 14.4s	remaining: 2.28s
# 863:	learn: 0.3828941	total: 14.4s	remaining: 2.27s
# 864:	learn: 0.3828358	total: 14.4s	remaining: 2.25s
# 865:	learn: 0.3828059	total: 14.4s	remaining: 2.23s
# 866:	learn: 0.3827554	total: 14.5s	remaining: 2.22s
# 867:	learn: 0.3826965	total: 14.5s	remaining: 2.2s
# 868:	learn: 0.3826601	total: 14.5s	remaining: 2.18s
# 869:	learn: 0.3826144	total: 14.5s	remaining: 2.17s
# 870:	learn: 0.3825592	total: 14.5s	remaining: 2.15s
# 871:	learn: 0.3825101	total: 14.5s	remaining: 2.13s
# 872:	learn: 0.3824527	total: 14.5s	remaining: 2.12s
# 873:	learn: 0.3823942	total: 14.6s	remaining: 2.1s
# 874:	learn: 0.3823384	total: 14.6s	remaining: 2.08s
# 875:	learn: 0.3822966	total: 14.6s	remaining: 2.07s
# 876:	learn: 0.3822609	total: 14.6s	remaining: 2.05s
# 877:	learn: 0.3821744	total: 14.6s	remaining: 2.03s
# 878:	learn: 0.3820985	total: 14.6s	remaining: 2.02s
# 879:	learn: 0.3820512	total: 14.7s	remaining: 2s
# 880:	learn: 0.3819224	total: 14.7s	remaining: 1.98s
# 881:	learn: 0.3818264	total: 14.7s	remaining: 1.97s
# 882:	learn: 0.3817617	total: 14.7s	remaining: 1.95s
# 883:	learn: 0.3817225	total: 14.7s	remaining: 1.93s
# 884:	learn: 0.3816727	total: 14.7s	remaining: 1.92s
# 885:	learn: 0.3816057	total: 14.8s	remaining: 1.9s
# 886:	learn: 0.3815579	total: 14.8s	remaining: 1.88s
# 887:	learn: 0.3815174	total: 14.8s	remaining: 1.87s
# 888:	learn: 0.3814779	total: 14.8s	remaining: 1.85s
# 889:	learn: 0.3814246	total: 14.8s	remaining: 1.83s
# 890:	learn: 0.3813311	total: 14.8s	remaining: 1.82s
# 891:	learn: 0.3812841	total: 14.9s	remaining: 1.8s
# 892:	learn: 0.3812435	total: 14.9s	remaining: 1.78s
# 893:	learn: 0.3811842	total: 14.9s	remaining: 1.77s
# 894:	learn: 0.3811409	total: 14.9s	remaining: 1.75s
# 895:	learn: 0.3810763	total: 14.9s	remaining: 1.73s
# 896:	learn: 0.3809934	total: 14.9s	remaining: 1.72s
# 897:	learn: 0.3809453	total: 15s	remaining: 1.7s
# 898:	learn: 0.3809003	total: 15s	remaining: 1.68s
# 899:	learn: 0.3808512	total: 15s	remaining: 1.67s
# 900:	learn: 0.3808222	total: 15s	remaining: 1.65s
# 901:	learn: 0.3807720	total: 15s	remaining: 1.63s
# 902:	learn: 0.3806967	total: 15s	remaining: 1.62s
# 903:	learn: 0.3806456	total: 15.1s	remaining: 1.6s
# 904:	learn: 0.3805963	total: 15.1s	remaining: 1.58s
# 905:	learn: 0.3805527	total: 15.1s	remaining: 1.57s
# 906:	learn: 0.3805208	total: 15.1s	remaining: 1.55s
# 907:	learn: 0.3804736	total: 15.1s	remaining: 1.53s
# 908:	learn: 0.3804240	total: 15.1s	remaining: 1.52s
# 909:	learn: 0.3803816	total: 15.2s	remaining: 1.5s
# 910:	learn: 0.3803225	total: 15.2s	remaining: 1.48s
# 911:	learn: 0.3802851	total: 15.2s	remaining: 1.47s
# 912:	learn: 0.3802517	total: 15.2s	remaining: 1.45s
# 913:	learn: 0.3801816	total: 15.2s	remaining: 1.43s
# 914:	learn: 0.3801304	total: 15.2s	remaining: 1.42s
# 915:	learn: 0.3800992	total: 15.3s	remaining: 1.4s
# 916:	learn: 0.3799949	total: 15.3s	remaining: 1.38s
# 917:	learn: 0.3799555	total: 15.3s	remaining: 1.37s
# 918:	learn: 0.3798977	total: 15.3s	remaining: 1.35s
# 919:	learn: 0.3798279	total: 15.3s	remaining: 1.33s
# 920:	learn: 0.3797947	total: 15.3s	remaining: 1.32s
# 921:	learn: 0.3797562	total: 15.4s	remaining: 1.3s
# 922:	learn: 0.3796842	total: 15.4s	remaining: 1.28s
# 923:	learn: 0.3795685	total: 15.4s	remaining: 1.27s
# 924:	learn: 0.3795048	total: 15.4s	remaining: 1.25s
# 925:	learn: 0.3794662	total: 15.4s	remaining: 1.23s
# 926:	learn: 0.3794167	total: 15.4s	remaining: 1.22s
# 927:	learn: 0.3793759	total: 15.5s	remaining: 1.2s
# ...
# 695:	learn: 0.3957428	total: 10.3s	remaining: 4.48s
# 696:	learn: 0.3956791	total: 10.3s	remaining: 4.47s
# 697:	learn: 0.3955663	total: 10.3s	remaining: 4.45s
# 698:	learn: 0.3955280	total: 10.3s	remaining: 4.44s
# 699:	learn: 0.3954300	total: 10.3s	remaining: 4.42s
# 700:	learn: 0.3953568	total: 10.3s	remaining: 4.41s
# 701:	learn: 0.3952630	total: 10.4s	remaining: 4.39s
# 702:	learn: 0.3951650	total: 10.4s	remaining: 4.38s
# 703:	learn: 0.3950750	total: 10.4s	remaining: 4.37s
# 704:	learn: 0.3949849	total: 10.4s	remaining: 4.35s
# 705:	learn: 0.3948427	total: 10.4s	remaining: 4.33s
# 706:	learn: 0.3946844	total: 10.4s	remaining: 4.32s
# 707:	learn: 0.3946243	total: 10.4s	remaining: 4.3s
# 708:	learn: 0.3945555	total: 10.5s	remaining: 4.29s
# 709:	learn: 0.3945073	total: 10.5s	remaining: 4.27s
# 710:	learn: 0.3944412	total: 10.5s	remaining: 4.26s
# 711:	learn: 0.3944001	total: 10.5s	remaining: 4.25s
# 712:	learn: 0.3943150	total: 10.5s	remaining: 4.23s
# 713:	learn: 0.3941703	total: 10.5s	remaining: 4.22s
# 714:	learn: 0.3941163	total: 10.5s	remaining: 4.2s
# 715:	learn: 0.3939371	total: 10.6s	remaining: 4.19s
# 716:	learn: 0.3938510	total: 10.6s	remaining: 4.17s
# 717:	learn: 0.3937680	total: 10.6s	remaining: 4.16s
# 718:	learn: 0.3936832	total: 10.6s	remaining: 4.14s
# 719:	learn: 0.3936071	total: 10.6s	remaining: 4.13s
# 720:	learn: 0.3935339	total: 10.6s	remaining: 4.11s
# 721:	learn: 0.3934832	total: 10.6s	remaining: 4.1s
# 722:	learn: 0.3934124	total: 10.7s	remaining: 4.08s
# 723:	learn: 0.3933288	total: 10.7s	remaining: 4.07s
# 724:	learn: 0.3932753	total: 10.7s	remaining: 4.05s
# 725:	learn: 0.3932267	total: 10.7s	remaining: 4.04s
# 726:	learn: 0.3931731	total: 10.7s	remaining: 4.02s
# 727:	learn: 0.3930827	total: 10.7s	remaining: 4.01s
# 728:	learn: 0.3929487	total: 10.7s	remaining: 3.99s
# 729:	learn: 0.3928481	total: 10.8s	remaining: 3.98s
# 730:	learn: 0.3928039	total: 10.8s	remaining: 3.96s
# 731:	learn: 0.3927734	total: 10.8s	remaining: 3.95s
# 732:	learn: 0.3927345	total: 10.8s	remaining: 3.93s
# 733:	learn: 0.3926614	total: 10.8s	remaining: 3.92s
# 734:	learn: 0.3926211	total: 10.8s	remaining: 3.9s
# 735:	learn: 0.3925709	total: 10.8s	remaining: 3.89s
# 736:	learn: 0.3924844	total: 10.9s	remaining: 3.87s
# 737:	learn: 0.3924130	total: 10.9s	remaining: 3.86s
# 738:	learn: 0.3922350	total: 10.9s	remaining: 3.85s
# 739:	learn: 0.3921772	total: 10.9s	remaining: 3.83s
# 740:	learn: 0.3921061	total: 10.9s	remaining: 3.82s
# 741:	learn: 0.3920544	total: 10.9s	remaining: 3.8s
# 742:	learn: 0.3920068	total: 10.9s	remaining: 3.79s
# 743:	learn: 0.3919295	total: 11s	remaining: 3.77s
# 744:	learn: 0.3918404	total: 11s	remaining: 3.76s
# 745:	learn: 0.3917458	total: 11s	remaining: 3.74s
# 746:	learn: 0.3917004	total: 11s	remaining: 3.73s
# 747:	learn: 0.3915944	total: 11s	remaining: 3.71s
# 748:	learn: 0.3915448	total: 11s	remaining: 3.7s
# 749:	learn: 0.3914955	total: 11.1s	remaining: 3.68s
# 750:	learn: 0.3914082	total: 11.1s	remaining: 3.67s
# 751:	learn: 0.3913484	total: 11.1s	remaining: 3.65s
# 752:	learn: 0.3912736	total: 11.1s	remaining: 3.64s
# 753:	learn: 0.3911503	total: 11.1s	remaining: 3.62s
# 754:	learn: 0.3911113	total: 11.1s	remaining: 3.61s
# 755:	learn: 0.3910328	total: 11.1s	remaining: 3.6s
# 756:	learn: 0.3909880	total: 11.2s	remaining: 3.58s
# 757:	learn: 0.3909099	total: 11.2s	remaining: 3.56s
# 758:	learn: 0.3908319	total: 11.2s	remaining: 3.55s
# 759:	learn: 0.3907859	total: 11.2s	remaining: 3.54s
# 760:	learn: 0.3907292	total: 11.2s	remaining: 3.52s
# 761:	learn: 0.3906140	total: 11.2s	remaining: 3.51s
# 762:	learn: 0.3905639	total: 11.2s	remaining: 3.49s
# 763:	learn: 0.3905058	total: 11.3s	remaining: 3.48s
# 764:	learn: 0.3904555	total: 11.3s	remaining: 3.46s
# 765:	learn: 0.3903137	total: 11.3s	remaining: 3.45s
# 766:	learn: 0.3902425	total: 11.3s	remaining: 3.43s
# 767:	learn: 0.3901842	total: 11.3s	remaining: 3.42s
# 768:	learn: 0.3901114	total: 11.3s	remaining: 3.4s
# 769:	learn: 0.3900351	total: 11.3s	remaining: 3.39s
# 770:	learn: 0.3899980	total: 11.4s	remaining: 3.38s
# 771:	learn: 0.3899325	total: 11.4s	remaining: 3.36s
# 772:	learn: 0.3898579	total: 11.4s	remaining: 3.34s
# 773:	learn: 0.3897744	total: 11.4s	remaining: 3.33s
# 774:	learn: 0.3896393	total: 11.4s	remaining: 3.31s
# 775:	learn: 0.3895943	total: 11.4s	remaining: 3.3s
# 776:	learn: 0.3895405	total: 11.4s	remaining: 3.29s
# 777:	learn: 0.3894762	total: 11.5s	remaining: 3.27s
# 778:	learn: 0.3893951	total: 11.5s	remaining: 3.26s
# 779:	learn: 0.3893424	total: 11.5s	remaining: 3.24s
# 780:	learn: 0.3892830	total: 11.5s	remaining: 3.23s
# 781:	learn: 0.3892098	total: 11.5s	remaining: 3.21s
# 782:	learn: 0.3891484	total: 11.5s	remaining: 3.2s
# 783:	learn: 0.3890852	total: 11.6s	remaining: 3.18s
# 784:	learn: 0.3890214	total: 11.6s	remaining: 3.17s
# 785:	learn: 0.3889858	total: 11.6s	remaining: 3.15s
# 786:	learn: 0.3889542	total: 11.6s	remaining: 3.14s
# 787:	learn: 0.3887946	total: 11.6s	remaining: 3.12s
# 788:	learn: 0.3887584	total: 11.6s	remaining: 3.11s
# 789:	learn: 0.3886551	total: 11.6s	remaining: 3.09s
# 790:	learn: 0.3885908	total: 11.7s	remaining: 3.08s
# 791:	learn: 0.3885315	total: 11.7s	remaining: 3.06s
# 792:	learn: 0.3883842	total: 11.7s	remaining: 3.05s
# 793:	learn: 0.3883508	total: 11.7s	remaining: 3.03s
# 794:	learn: 0.3882876	total: 11.7s	remaining: 3.02s
# 795:	learn: 0.3881959	total: 11.7s	remaining: 3s
# 796:	learn: 0.3881424	total: 11.7s	remaining: 2.99s
# 797:	learn: 0.3880852	total: 11.8s	remaining: 2.98s
# 798:	learn: 0.3880046	total: 11.8s	remaining: 2.96s
# 799:	learn: 0.3879295	total: 11.8s	remaining: 2.95s
# 800:	learn: 0.3878644	total: 11.8s	remaining: 2.93s
# 801:	learn: 0.3878189	total: 11.8s	remaining: 2.92s
# 802:	learn: 0.3877649	total: 11.8s	remaining: 2.9s
# 803:	learn: 0.3877125	total: 11.8s	remaining: 2.89s
# 804:	learn: 0.3876764	total: 11.9s	remaining: 2.87s
# 805:	learn: 0.3876055	total: 11.9s	remaining: 2.86s
# 806:	learn: 0.3875623	total: 11.9s	remaining: 2.84s
# 807:	learn: 0.3874652	total: 11.9s	remaining: 2.83s
# 808:	learn: 0.3873988	total: 11.9s	remaining: 2.81s
# 809:	learn: 0.3873384	total: 11.9s	remaining: 2.8s
# 810:	learn: 0.3872903	total: 11.9s	remaining: 2.78s
# 811:	learn: 0.3872249	total: 12s	remaining: 2.77s
# 812:	learn: 0.3871268	total: 12s	remaining: 2.75s
# 813:	learn: 0.3870604	total: 12s	remaining: 2.74s
# 814:	learn: 0.3869848	total: 12s	remaining: 2.73s
# 815:	learn: 0.3869339	total: 12s	remaining: 2.71s
# 816:	learn: 0.3868620	total: 12s	remaining: 2.7s
# 817:	learn: 0.3867955	total: 12.1s	remaining: 2.68s
# 818:	learn: 0.3867476	total: 12.1s	remaining: 2.67s
# 819:	learn: 0.3866965	total: 12.1s	remaining: 2.65s
# 820:	learn: 0.3865974	total: 12.1s	remaining: 2.64s
# 821:	learn: 0.3865419	total: 12.1s	remaining: 2.62s
# 822:	learn: 0.3864981	total: 12.1s	remaining: 2.61s
# 823:	learn: 0.3864675	total: 12.1s	remaining: 2.59s
# 824:	learn: 0.3864113	total: 12.2s	remaining: 2.58s
# 825:	learn: 0.3863590	total: 12.2s	remaining: 2.56s
# 826:	learn: 0.3862862	total: 12.2s	remaining: 2.55s
# 827:	learn: 0.3861024	total: 12.2s	remaining: 2.53s
# 828:	learn: 0.3860311	total: 12.2s	remaining: 2.52s
# 829:	learn: 0.3859766	total: 12.2s	remaining: 2.5s
# 830:	learn: 0.3859071	total: 12.2s	remaining: 2.49s
# 831:	learn: 0.3858397	total: 12.3s	remaining: 2.48s
# 832:	learn: 0.3857810	total: 12.3s	remaining: 2.46s
# 833:	learn: 0.3857220	total: 12.3s	remaining: 2.44s
# 834:	learn: 0.3856561	total: 12.3s	remaining: 2.43s
# 835:	learn: 0.3855781	total: 12.3s	remaining: 2.42s
# 836:	learn: 0.3855224	total: 12.3s	remaining: 2.4s
# 837:	learn: 0.3854714	total: 12.3s	remaining: 2.39s
# 838:	learn: 0.3854206	total: 12.4s	remaining: 2.37s
# 839:	learn: 0.3853823	total: 12.4s	remaining: 2.36s
# 840:	learn: 0.3853290	total: 12.4s	remaining: 2.34s
# 841:	learn: 0.3852959	total: 12.4s	remaining: 2.33s
# 842:	learn: 0.3852317	total: 12.4s	remaining: 2.31s
# 843:	learn: 0.3851702	total: 12.4s	remaining: 2.3s
# 844:	learn: 0.3851328	total: 12.4s	remaining: 2.28s
# 845:	learn: 0.3850362	total: 12.5s	remaining: 2.27s
# 846:	learn: 0.3849791	total: 12.5s	remaining: 2.25s
# 847:	learn: 0.3849134	total: 12.5s	remaining: 2.24s
# 848:	learn: 0.3848690	total: 12.5s	remaining: 2.22s
# 849:	learn: 0.3848151	total: 12.5s	remaining: 2.21s
# 850:	learn: 0.3847691	total: 12.5s	remaining: 2.19s
# 851:	learn: 0.3846863	total: 12.5s	remaining: 2.18s
# 852:	learn: 0.3846215	total: 12.6s	remaining: 2.16s
# 853:	learn: 0.3845467	total: 12.6s	remaining: 2.15s
# 854:	learn: 0.3845083	total: 12.6s	remaining: 2.13s
# 855:	learn: 0.3843822	total: 12.6s	remaining: 2.12s
# 856:	learn: 0.3842621	total: 12.6s	remaining: 2.1s
# 857:	learn: 0.3842076	total: 12.6s	remaining: 2.09s
# 858:	learn: 0.3841268	total: 12.6s	remaining: 2.08s
# 859:	learn: 0.3840745	total: 12.7s	remaining: 2.06s
# 860:	learn: 0.3840247	total: 12.7s	remaining: 2.05s
# 861:	learn: 0.3839847	total: 12.7s	remaining: 2.03s
# 862:	learn: 0.3839476	total: 12.7s	remaining: 2.02s
# 863:	learn: 0.3839140	total: 12.7s	remaining: 2s
# 864:	learn: 0.3838582	total: 12.7s	remaining: 1.99s
# 865:	learn: 0.3838136	total: 12.7s	remaining: 1.97s
# 866:	learn: 0.3837601	total: 12.8s	remaining: 1.96s
# 867:	learn: 0.3836910	total: 12.8s	remaining: 1.94s
# 868:	learn: 0.3836385	total: 12.8s	remaining: 1.93s
# 869:	learn: 0.3835793	total: 12.8s	remaining: 1.91s
# 870:	learn: 0.3835334	total: 12.8s	remaining: 1.9s
# 871:	learn: 0.3834864	total: 12.8s	remaining: 1.88s
# 872:	learn: 0.3834234	total: 12.8s	remaining: 1.87s
# 873:	learn: 0.3833420	total: 12.9s	remaining: 1.85s
# 874:	learn: 0.3832841	total: 12.9s	remaining: 1.84s
# 875:	learn: 0.3832328	total: 12.9s	remaining: 1.82s
# 876:	learn: 0.3831794	total: 12.9s	remaining: 1.81s
# 877:	learn: 0.3831276	total: 12.9s	remaining: 1.79s
# 878:	learn: 0.3830842	total: 12.9s	remaining: 1.78s
# 879:	learn: 0.3829879	total: 13s	remaining: 1.77s
# 880:	learn: 0.3829385	total: 13s	remaining: 1.75s
# 881:	learn: 0.3828885	total: 13s	remaining: 1.74s
# 882:	learn: 0.3828491	total: 13s	remaining: 1.72s
# 883:	learn: 0.3827853	total: 13s	remaining: 1.71s
# 884:	learn: 0.3827285	total: 13s	remaining: 1.69s
# 885:	learn: 0.3826798	total: 13s	remaining: 1.68s
# 886:	learn: 0.3826285	total: 13.1s	remaining: 1.66s
# 887:	learn: 0.3825872	total: 13.1s	remaining: 1.65s
# 888:	learn: 0.3825391	total: 13.1s	remaining: 1.63s
# 889:	learn: 0.3824901	total: 13.1s	remaining: 1.62s
# 890:	learn: 0.3824468	total: 13.1s	remaining: 1.6s
# 891:	learn: 0.3823768	total: 13.1s	remaining: 1.59s
# 892:	learn: 0.3823292	total: 13.1s	remaining: 1.57s
# 893:	learn: 0.3822983	total: 13.2s	remaining: 1.56s
# 894:	learn: 0.3822497	total: 13.2s	remaining: 1.54s
# 895:	learn: 0.3821958	total: 13.2s	remaining: 1.53s
# 896:	learn: 0.3820886	total: 13.2s	remaining: 1.51s
# 897:	learn: 0.3820254	total: 13.2s	remaining: 1.5s
# 898:	learn: 0.3819851	total: 13.2s	remaining: 1.49s
# 899:	learn: 0.3819310	total: 13.2s	remaining: 1.47s
# 900:	learn: 0.3818589	total: 13.3s	remaining: 1.46s
# 901:	learn: 0.3817903	total: 13.3s	remaining: 1.44s
# 902:	learn: 0.3817424	total: 13.3s	remaining: 1.43s
# 903:	learn: 0.3816778	total: 13.3s	remaining: 1.41s
# 904:	learn: 0.3816087	total: 13.3s	remaining: 1.4s
# 905:	learn: 0.3815577	total: 13.3s	remaining: 1.38s
# 906:	learn: 0.3815057	total: 13.3s	remaining: 1.37s
# 907:	learn: 0.3814464	total: 13.4s	remaining: 1.35s
# 908:	learn: 0.3814119	total: 13.4s	remaining: 1.34s
# 909:	learn: 0.3813524	total: 13.4s	remaining: 1.33s
# 910:	learn: 0.3813227	total: 13.4s	remaining: 1.31s
# 911:	learn: 0.3812637	total: 13.5s	remaining: 1.3s
# 912:	learn: 0.3812052	total: 13.5s	remaining: 1.28s
# 913:	learn: 0.3811588	total: 13.5s	remaining: 1.27s
# 914:	learn: 0.3810837	total: 13.5s	remaining: 1.25s
# 915:	learn: 0.3810533	total: 13.5s	remaining: 1.24s
# 916:	learn: 0.3810011	total: 13.5s	remaining: 1.22s
# 917:	learn: 0.3809643	total: 13.5s	remaining: 1.21s
# 918:	learn: 0.3809090	total: 13.6s	remaining: 1.19s
# 919:	learn: 0.3808664	total: 13.6s	remaining: 1.18s
# 920:	learn: 0.3808054	total: 13.6s	remaining: 1.17s
# 921:	learn: 0.3807443	total: 13.6s	remaining: 1.15s
# 922:	learn: 0.3806986	total: 13.6s	remaining: 1.14s
# 923:	learn: 0.3806488	total: 13.6s	remaining: 1.12s
# 924:	learn: 0.3806132	total: 13.6s	remaining: 1.11s
# 925:	learn: 0.3805692	total: 13.7s	remaining: 1.09s
# 926:	learn: 0.3805293	total: 13.7s	remaining: 1.08s
# 927:	learn: 0.3804949	total: 13.7s	remaining: 1.06s
# 928:	learn: 0.3804676	total: 13.7s	remaining: 1.05s
# 929:	learn: 0.3804182	total: 13.7s	remaining: 1.03s
# 930:	learn: 0.3803693	total: 13.7s	remaining: 1.02s
# 931:	learn: 0.3803305	total: 13.7s	remaining: 1s
# 932:	learn: 0.3802892	total: 13.8s	remaining: 988ms
# 933:	learn: 0.3802491	total: 13.8s	remaining: 974ms
# 934:	learn: 0.3801454	total: 13.8s	remaining: 959ms
# 935:	learn: 0.3801109	total: 13.8s	remaining: 944ms
# 936:	learn: 0.3800705	total: 13.8s	remaining: 929ms
# 937:	learn: 0.3800365	total: 13.8s	remaining: 914ms
# 938:	learn: 0.3799335	total: 13.8s	remaining: 900ms
# 939:	learn: 0.3799121	total: 13.9s	remaining: 885ms
# 940:	learn: 0.3798691	total: 13.9s	remaining: 870ms
# 941:	learn: 0.3798145	total: 13.9s	remaining: 855ms
# 942:	learn: 0.3797837	total: 13.9s	remaining: 840ms
# 943:	learn: 0.3797250	total: 13.9s	remaining: 826ms
# 944:	learn: 0.3796421	total: 13.9s	remaining: 811ms
# 945:	learn: 0.3795972	total: 13.9s	remaining: 796ms
# 946:	learn: 0.3795608	total: 14s	remaining: 782ms
# 947:	learn: 0.3795255	total: 14s	remaining: 767ms
# 948:	learn: 0.3794570	total: 14s	remaining: 752ms
# 949:	learn: 0.3794294	total: 14s	remaining: 737ms
# 950:	learn: 0.3793826	total: 14s	remaining: 723ms
# 951:	learn: 0.3793413	total: 14s	remaining: 708ms
# 952:	learn: 0.3793008	total: 14.1s	remaining: 693ms
# 953:	learn: 0.3792619	total: 14.1s	remaining: 678ms
# 954:	learn: 0.3792022	total: 14.1s	remaining: 663ms
# 955:	learn: 0.3791619	total: 14.1s	remaining: 649ms
# 956:	learn: 0.3790974	total: 14.1s	remaining: 634ms
# 957:	learn: 0.3790638	total: 14.1s	remaining: 619ms
# 958:	learn: 0.3790269	total: 14.1s	remaining: 605ms
# 959:	learn: 0.3789899	total: 14.2s	remaining: 590ms
# 960:	learn: 0.3789386	total: 14.2s	remaining: 575ms
# 961:	learn: 0.3788997	total: 14.2s	remaining: 560ms
# 962:	learn: 0.3788532	total: 14.2s	remaining: 546ms
# 963:	learn: 0.3788239	total: 14.2s	remaining: 531ms
# 964:	learn: 0.3787840	total: 14.2s	remaining: 516ms
# 965:	learn: 0.3787397	total: 14.2s	remaining: 501ms
# 966:	learn: 0.3787029	total: 14.3s	remaining: 487ms
# 967:	learn: 0.3785974	total: 14.3s	remaining: 472ms
# 968:	learn: 0.3785538	total: 14.3s	remaining: 457ms
# 969:	learn: 0.3785062	total: 14.3s	remaining: 442ms
# 970:	learn: 0.3784456	total: 14.3s	remaining: 428ms
# 971:	learn: 0.3784197	total: 14.3s	remaining: 413ms
# 972:	learn: 0.3783683	total: 14.3s	remaining: 398ms
# 973:	learn: 0.3783388	total: 14.4s	remaining: 383ms
# 974:	learn: 0.3783062	total: 14.4s	remaining: 369ms
# 975:	learn: 0.3782664	total: 14.4s	remaining: 354ms
# 976:	learn: 0.3782041	total: 14.4s	remaining: 339ms
# 977:	learn: 0.3781729	total: 14.4s	remaining: 324ms
# 978:	learn: 0.3780990	total: 14.4s	remaining: 310ms
# 979:	learn: 0.3779921	total: 14.4s	remaining: 295ms
# 980:	learn: 0.3779426	total: 14.5s	remaining: 280ms
# 981:	learn: 0.3779000	total: 14.5s	remaining: 265ms
# 982:	learn: 0.3778601	total: 14.5s	remaining: 251ms
# 983:	learn: 0.3778200	total: 14.5s	remaining: 236ms
# 984:	learn: 0.3777696	total: 14.5s	remaining: 221ms
# 985:	learn: 0.3776810	total: 14.5s	remaining: 206ms
# 986:	learn: 0.3776483	total: 14.5s	remaining: 192ms
# 987:	learn: 0.3776179	total: 14.6s	remaining: 177ms
# 988:	learn: 0.3775492	total: 14.6s	remaining: 162ms
# 989:	learn: 0.3775134	total: 14.6s	remaining: 147ms
# 990:	learn: 0.3774635	total: 14.6s	remaining: 133ms
# 991:	learn: 0.3773458	total: 14.6s	remaining: 118ms
# 992:	learn: 0.3773229	total: 14.6s	remaining: 103ms
# 993:	learn: 0.3772862	total: 14.7s	remaining: 88.4ms
# 994:	learn: 0.3772327	total: 14.7s	remaining: 73.7ms
# 995:	learn: 0.3771906	total: 14.7s	remaining: 59ms
# 996:	learn: 0.3771649	total: 14.7s	remaining: 44.2ms
# 997:	learn: 0.3771288	total: 14.7s	remaining: 29.5ms
# 998:	learn: 0.3770894	total: 14.7s	remaining: 14.7ms
# 999:	learn: 0.3770530	total: 14.7s	remaining: 0us
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# RMSE:  [-0.75939784 -0.73775132 -0.76142277 -0.84853022 -0.59305663 -0.73701244]
# RMSE (all folds): 0.74 ± 0.0755

# %%
pipe
# Out:
# Pipeline(steps=[('functiontransformer-1',
#                  FunctionTransformer(func=<function _encode_dates at 0x1298f65c0>)),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function _closest_transport at 0x1298f6700>)),
#                 ('functiontransformer-3',
#                  FunctionTransformer(func=<function _add_weather_data at 0x1298f6980>)),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('dat...
#                                                    'sin_hour', 'sin_weekyear',
#                                                    'sin_weekday', 'cos_month',
#                                                    'cos_day', 'cos_hour',
#                                                    'cos_weekyear',
#                                                    'cos_weekday']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['counter_id',
#                                                    'closest_metro_distance',
#                                                    'holidays',
#                                                    'france_stay_at_home',
#                                                    'year', 'coco']),
#                                                  ('num', StandardScaler(),
#                                                   ['temp', 'rhum', 'wspd',
#                                                    'prcp'])])),
#                 ('catboostregressor',
#                  <catboost.core.CatBoostRegressor object at 0x14aca7b90>)])

# %% [markdown]
# ### Hyperparameter Tuning with Optuna

# %%
import optuna
from sklearn.metrics import mean_squared_error

date_encoder = FunctionTransformer(_encode_dates)
transport_encoder = FunctionTransformer(_closest_transport)
weather_encoder = FunctionTransformer(_add_weather_data)
    
date_cols = ["sin_month", "sin_day", "sin_hour", "sin_weekyear", "sin_weekday",
                 "cos_month", "cos_day", "cos_hour", "cos_weekyear", "cos_weekday"]

categorical_cols = ["counter_id", "closest_metro_distance", "holidays", "france_stay_at_home", "year", "coco"]
numerical_cols = ['temp', 'rhum', 'wspd', 'prcp']

preprocessor = ColumnTransformer(
        [
            ("date", 'passthrough', date_cols),
            ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
            ("num", StandardScaler(), numerical_cols)
        ]
)

def objective(trial):
    params = {
        "iterations": 1000,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.05, 1.0),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
    }

    model = make_pipeline(date_encoder, transport_encoder, weather_encoder, preprocessor, CatBoostRegressor(**params, silent=True))
    model.fit(X_train, y_train)
    predictions = model.predict(X_train)
    rmse = mean_squared_error(y_train, predictions, squared=False)
    return rmse

# %%
study = optuna.create_study(direction='minimize') 
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-12-06 21:12:40,865] A new study created in memory with name: no-name-ba213ea3-f3b9-4fb4-9ec8-ae508cbbf092
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:13:04,441] Trial 0 finished with value: 0.5435038461978766 and parameters: {'learning_rate': 0.06730637646320073, 'depth': 3, 'subsample': 0.6152568018709638, 'colsample_bylevel': 0.6943768607716672, 'min_data_in_leaf': 66}. Best is trial 0 with value: 0.5435038461978766.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:13:35,032] Trial 1 finished with value: 0.6616268804817701 and parameters: {'learning_rate': 0.004449863784605369, 'depth': 8, 'subsample': 0.46574269571862603, 'colsample_bylevel': 0.9231612180228402, 'min_data_in_leaf': 82}. Best is trial 0 with value: 0.5435038461978766.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:14:07,811] Trial 2 finished with value: 0.5771113848503127 and parameters: {'learning_rate': 0.012797768105777074, 'depth': 6, 'subsample': 0.8378478873577272, 'colsample_bylevel': 0.4403667748474213, 'min_data_in_leaf': 71}. Best is trial 0 with value: 0.5435038461978766.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:14:35,527] Trial 3 finished with value: 0.37772580673231515 and parameters: {'learning_rate': 0.040892501992474586, 'depth': 9, 'subsample': 0.2444805464081118, 'colsample_bylevel': 0.5025794328439444, 'min_data_in_leaf': 26}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:15:10,813] Trial 4 finished with value: 0.5829373980741882 and parameters: {'learning_rate': 0.00599883706508035, 'depth': 9, 'subsample': 0.6489936328712163, 'colsample_bylevel': 0.9688723122441241, 'min_data_in_leaf': 75}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:15:38,723] Trial 5 finished with value: 0.4437807896202989 and parameters: {'learning_rate': 0.02360727254026145, 'depth': 8, 'subsample': 0.3118662269880482, 'colsample_bylevel': 0.4538893508071354, 'min_data_in_leaf': 95}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:16:10,859] Trial 6 finished with value: 0.3895388228484279 and parameters: {'learning_rate': 0.06954299312373818, 'depth': 7, 'subsample': 0.6932235011357959, 'colsample_bylevel': 0.32636975602904666, 'min_data_in_leaf': 2}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:16:32,223] Trial 7 finished with value: 0.4044942008961103 and parameters: {'learning_rate': 0.07637047902079623, 'depth': 6, 'subsample': 0.1108537170545075, 'colsample_bylevel': 0.6794995043257073, 'min_data_in_leaf': 5}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:16:58,144] Trial 8 finished with value: 0.40786821309617016 and parameters: {'learning_rate': 0.04453328769914575, 'depth': 7, 'subsample': 0.2991864735164913, 'colsample_bylevel': 0.8538345416431975, 'min_data_in_leaf': 32}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:17:20,852] Trial 9 finished with value: 0.5399169373531322 and parameters: {'learning_rate': 0.07351514806602351, 'depth': 3, 'subsample': 0.5592988470103494, 'colsample_bylevel': 0.5508731267324551, 'min_data_in_leaf': 77}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:17:44,641] Trial 10 finished with value: 1.1466120111490443 and parameters: {'learning_rate': 0.0010335965621350687, 'depth': 10, 'subsample': 0.06711377667950416, 'colsample_bylevel': 0.0735335501998558, 'min_data_in_leaf': 35}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:18:04,122] Trial 11 finished with value: 0.8493532029690362 and parameters: {'learning_rate': 0.030669221059840584, 'depth': 1, 'subsample': 0.9482346568368679, 'colsample_bylevel': 0.2611438756195565, 'min_data_in_leaf': 1}. Best is trial 3 with value: 0.37772580673231515.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:18:47,203] Trial 12 finished with value: 0.32331358636195207 and parameters: {'learning_rate': 0.09598946340975474, 'depth': 10, 'subsample': 0.7771849617556571, 'colsample_bylevel': 0.30040958652995786, 'min_data_in_leaf': 21}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:19:29,417] Trial 13 finished with value: 0.3889332272602319 and parameters: {'learning_rate': 0.03096956373665865, 'depth': 10, 'subsample': 0.8063333286995364, 'colsample_bylevel': 0.24612679689913505, 'min_data_in_leaf': 27}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:20:08,524] Trial 14 finished with value: 0.37212640356339377 and parameters: {'learning_rate': 0.09171031467288204, 'depth': 10, 'subsample': 0.9971530378731234, 'colsample_bylevel': 0.05037934253270532, 'min_data_in_leaf': 19}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:20:34,070] Trial 15 finished with value: 0.5304366211504161 and parameters: {'learning_rate': 0.09239957588836849, 'depth': 4, 'subsample': 0.9997171934440946, 'colsample_bylevel': 0.060437319782552706, 'min_data_in_leaf': 48}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:21:14,964] Trial 16 finished with value: 0.4478959197302367 and parameters: {'learning_rate': 0.018514567543082033, 'depth': 10, 'subsample': 0.8671063835512745, 'colsample_bylevel': 0.15148438856134905, 'min_data_in_leaf': 16}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:21:48,795] Trial 17 finished with value: 0.36486124219022664 and parameters: {'learning_rate': 0.0979644578078054, 'depth': 8, 'subsample': 0.762352313910656, 'colsample_bylevel': 0.1502411131181498, 'min_data_in_leaf': 47}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:22:24,637] Trial 18 finished with value: 0.39911235973409637 and parameters: {'learning_rate': 0.04241906599750503, 'depth': 8, 'subsample': 0.7361209803192267, 'colsample_bylevel': 0.338254243729309, 'min_data_in_leaf': 48}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:22:51,751] Trial 19 finished with value: 0.44196128054809575 and parameters: {'learning_rate': 0.09902500757887696, 'depth': 5, 'subsample': 0.7344000868545146, 'colsample_bylevel': 0.1753746932242465, 'min_data_in_leaf': 62}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:23:30,512] Trial 20 finished with value: 0.3808351918159266 and parameters: {'learning_rate': 0.050292412079205775, 'depth': 9, 'subsample': 0.88193021210747, 'colsample_bylevel': 0.16796685056817182, 'min_data_in_leaf': 40}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:24:11,096] Trial 21 finished with value: 0.3592095379737275 and parameters: {'learning_rate': 0.09686200454215603, 'depth': 10, 'subsample': 0.9845300441291527, 'colsample_bylevel': 0.06313776757105145, 'min_data_in_leaf': 20}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:24:47,385] Trial 22 finished with value: 0.3801203541700188 and parameters: {'learning_rate': 0.053329249256001056, 'depth': 9, 'subsample': 0.7649467106730788, 'colsample_bylevel': 0.14269771858701683, 'min_data_in_leaf': 15}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:25:24,122] Trial 23 finished with value: 0.35417785315434336 and parameters: {'learning_rate': 0.09957714682624862, 'depth': 8, 'subsample': 0.8764468648145668, 'colsample_bylevel': 0.2503338181231783, 'min_data_in_leaf': 41}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:25:59,574] Trial 24 finished with value: 0.41210933617295725 and parameters: {'learning_rate': 0.0512881363902248, 'depth': 7, 'subsample': 0.9125801628368851, 'colsample_bylevel': 0.2630430466991757, 'min_data_in_leaf': 57}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:26:45,950] Trial 25 finished with value: 0.3409398343372778 and parameters: {'learning_rate': 0.062120411625928414, 'depth': 10, 'subsample': 0.846164086708666, 'colsample_bylevel': 0.34244644945907166, 'min_data_in_leaf': 11}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:27:26,096] Trial 26 finished with value: 0.3603916628177582 and parameters: {'learning_rate': 0.05735623442485782, 'depth': 9, 'subsample': 0.8250745386035739, 'colsample_bylevel': 0.3315231940249053, 'min_data_in_leaf': 39}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:28:07,683] Trial 27 finished with value: 0.39452786435932546 and parameters: {'learning_rate': 0.033688749827961134, 'depth': 9, 'subsample': 0.9175888648399666, 'colsample_bylevel': 0.33070980233357655, 'min_data_in_leaf': 11}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:28:55,932] Trial 28 finished with value: 0.34027615453588905 and parameters: {'learning_rate': 0.06105885597582281, 'depth': 10, 'subsample': 0.816242790999513, 'colsample_bylevel': 0.39707381590676394, 'min_data_in_leaf': 26}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:29:15,410] Trial 29 finished with value: 0.8075874718510795 and parameters: {'learning_rate': 0.06263655593209323, 'depth': 1, 'subsample': 0.614850950958451, 'colsample_bylevel': 0.39316634592340105, 'min_data_in_leaf': 9}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:30:03,194] Trial 30 finished with value: 0.3367853827698094 and parameters: {'learning_rate': 0.06550741545866583, 'depth': 10, 'subsample': 0.7956531420891686, 'colsample_bylevel': 0.3834393087096636, 'min_data_in_leaf': 26}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:30:51,057] Trial 31 finished with value: 0.3376868191546287 and parameters: {'learning_rate': 0.06468846156881515, 'depth': 10, 'subsample': 0.8130703994577623, 'colsample_bylevel': 0.40627268091153146, 'min_data_in_leaf': 25}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:31:39,666] Trial 32 finished with value: 0.3643929404691381 and parameters: {'learning_rate': 0.03854318906544161, 'depth': 10, 'subsample': 0.7975350261706974, 'colsample_bylevel': 0.4290283613666614, 'min_data_in_leaf': 26}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:32:18,226] Trial 33 finished with value: 0.3492907982236418 and parameters: {'learning_rate': 0.06585320250911848, 'depth': 9, 'subsample': 0.6835100615585192, 'colsample_bylevel': 0.5449732474675885, 'min_data_in_leaf': 32}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:33:05,088] Trial 34 finished with value: 0.39500659673914895 and parameters: {'learning_rate': 0.024975532280629393, 'depth': 10, 'subsample': 0.7007656325180379, 'colsample_bylevel': 0.501082527167587, 'min_data_in_leaf': 24}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:33:42,203] Trial 35 finished with value: 0.3999864183763585 and parameters: {'learning_rate': 0.03996108517442378, 'depth': 8, 'subsample': 0.7847680347381678, 'colsample_bylevel': 0.40785194093419985, 'min_data_in_leaf': 22}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:34:18,888] Trial 36 finished with value: 0.34639573144248537 and parameters: {'learning_rate': 0.07207379183081447, 'depth': 9, 'subsample': 0.6300593639218613, 'colsample_bylevel': 0.47678803750979637, 'min_data_in_leaf': 29}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:34:59,318] Trial 37 finished with value: 0.44658354631337627 and parameters: {'learning_rate': 0.018326751089604885, 'depth': 9, 'subsample': 0.8248623506874296, 'colsample_bylevel': 0.38380290065082373, 'min_data_in_leaf': 55}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:35:30,261] Trial 38 finished with value: 0.3996356773019205 and parameters: {'learning_rate': 0.052329052768674965, 'depth': 7, 'subsample': 0.5542232285679806, 'colsample_bylevel': 0.5782037106536353, 'min_data_in_leaf': 36}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:35:59,358] Trial 39 finished with value: 0.43573511099736545 and parameters: {'learning_rate': 0.07579081529945156, 'depth': 5, 'subsample': 0.7189286738560114, 'colsample_bylevel': 0.46716532238180875, 'min_data_in_leaf': 93}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:36:36,700] Trial 40 finished with value: 0.3570257717696232 and parameters: {'learning_rate': 0.04468344872470866, 'depth': 10, 'subsample': 0.4534986069121389, 'colsample_bylevel': 0.4097256945321601, 'min_data_in_leaf': 43}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:37:24,164] Trial 41 finished with value: 0.3413645159888762 and parameters: {'learning_rate': 0.06085092676604181, 'depth': 10, 'subsample': 0.8511669309192973, 'colsample_bylevel': 0.3625049305769924, 'min_data_in_leaf': 10}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:38:08,048] Trial 42 finished with value: 0.3466003793850451 and parameters: {'learning_rate': 0.07228088205515594, 'depth': 9, 'subsample': 0.9215718954204127, 'colsample_bylevel': 0.4272556482158346, 'min_data_in_leaf': 15}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:38:52,922] Trial 43 finished with value: 0.3447701539986798 and parameters: {'learning_rate': 0.058275395816810585, 'depth': 10, 'subsample': 0.8337962382499446, 'colsample_bylevel': 0.30102863650656636, 'min_data_in_leaf': 6}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:39:36,097] Trial 44 finished with value: 0.3307807303413826 and parameters: {'learning_rate': 0.07731044072424613, 'depth': 10, 'subsample': 0.6758192165973221, 'colsample_bylevel': 0.3709622178333996, 'min_data_in_leaf': 31}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:40:12,202] Trial 45 finished with value: 0.35794094947089866 and parameters: {'learning_rate': 0.08322324585942727, 'depth': 8, 'subsample': 0.7606535448221445, 'colsample_bylevel': 0.3725962912348478, 'min_data_in_leaf': 31}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:40:33,234] Trial 46 finished with value: 0.6561918280273993 and parameters: {'learning_rate': 0.07747675143481772, 'depth': 2, 'subsample': 0.6823673223838363, 'colsample_bylevel': 0.29312227886652803, 'min_data_in_leaf': 35}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:41:13,339] Trial 47 finished with value: 0.38641108493245224 and parameters: {'learning_rate': 0.0363039413550533, 'depth': 9, 'subsample': 0.7699888759090626, 'colsample_bylevel': 0.4411667541311272, 'min_data_in_leaf': 23}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:42:00,301] Trial 48 finished with value: 0.3520773974443592 and parameters: {'learning_rate': 0.0471558579237265, 'depth': 10, 'subsample': 0.6531916934506677, 'colsample_bylevel': 0.5056034583743076, 'min_data_in_leaf': 17}. Best is trial 12 with value: 0.32331358636195207.
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# [I 2023-12-06 21:42:31,224] Trial 49 finished with value: 0.40182715185271817 and parameters: {'learning_rate': 0.08257578412187312, 'depth': 6, 'subsample': 0.734705956881153, 'colsample_bylevel': 0.3748345095737612, 'min_data_in_leaf': 27}. Best is trial 12 with value: 0.32331358636195207.

# %%
print('Best hyperparameters:', study.best_params)
print('Best RMSE:', study.best_value)
# Out:
# Best hyperparameters: {'learning_rate': 0.09598946340975474, 'depth': 10, 'subsample': 0.7771849617556571, 'colsample_bylevel': 0.30040958652995786, 'min_data_in_leaf': 21}
# Best RMSE: 0.32331358636195207

# %% [markdown]
# ### Cross Validation using best_params

# %%
tuned_pipe = make_pipeline(date_encoder, transport_encoder, weather_encoder, preprocessor, CatBoostRegressor(**study.best_params, silent=True))
tuned_pipe.fit(X_train, y_train)

cv = TimeSeriesSplit(n_splits=6)

# When using a scorer in scikit-learn it always needs to be better when smaller, hence the minus sign.
scores_tuned = cross_val_score(
    tuned_pipe, X_train, y_train, cv=cv, scoring="neg_root_mean_squared_error"
)
print("RMSE: ", scores_tuned)
print(f"RMSE (all folds): {-scores_tuned.mean():.3} ± {(-scores_tuned).std():.3}")
# Out:
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# RMSE:  [-0.74694763 -0.73901564 -0.74645606 -0.79295119 -0.6283122  -0.70128943]
# RMSE (all folds): 0.726 ± 0.0511
