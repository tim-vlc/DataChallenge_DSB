# %% [markdown]
# # Template used to test a model locally:
#
# ### Outline:
#
# - Import the Dataset using the correct function
#
# - Use the function transformers to do the feature engineering - ```Please Comment any step that you have changed versus the best submission```
#
# - Retrieve the transformed X_train and run ydata_profiling to find insights
#
# - Create pipeline
#
# - Run CV to get a baseline RMSE score
#
# - Print the most important hyperparameters & run the Optuna training
#
# - Rerun the pipeline to see the impact - ```Please share any relevant information here```
#
# - Update the script with the final model and test submission

# %% [markdown]
# ## Example with Best Score Script using the `Coco` features instead of ['temp', 'rhum', 'wspd', 'prcp']

# %% [markdown]
# ### Import the Dataset

# %%
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Ridge
import holidays
from lockdowndates.core import LockdownDates
import haversine as hs
from datetime import datetime
from meteostat import Point, Hourly
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import numpy as np
from pathlib import Path
from datetime import datetime
from meteostat import Point, Hourly

# %%
def _read_data():
    _target_column_name = 'log_bike_count'
    data = pd.read_parquet('/Users/ghalichraibi/Desktop/DATA Challenge/Data_Challenge/data/train.parquet')
    # Sort by date first, so that time based cross-validation would produce correct results
    data = data.sort_values(["date", "counter_name"])
    y_array = data[_target_column_name].values
    X_df = data.drop([_target_column_name, "bike_count"], axis=1)
    return X_df, y_array

# %%
X_train, y_train = _read_data()
X_final = pd.read_parquet('/Users/ghalichraibi/Desktop/DATA Challenge/Data_Challenge/data/final_test.parquet')

# %% [markdown]
# ### Function Transformers

# %%
# Encode Date with Fourrier + Covid + Holidays (To test Perf With Weekend + Holidays)

def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X.loc[:, "year"] = X["date"].dt.year
    X.loc[:, "date_ws"] = X["date"].dt.date.astype('datetime64[ns]') # To be used for merging
    X.loc[:, "month"] = X["date"].dt.month
    X.loc[:, "day"] = X["date"].dt.day
    X.loc[:, "weekday"] = X["date"].dt.weekday
    X.loc[:, "hour"] = X["date"].dt.hour
    X.loc[:, "week_of_year"] = X["date"].dt.isocalendar().week
    X.loc[:, "season"] = X["week_of_year"].apply(lambda w: (w // 13) % 4 + 1)

    # Add the column corresponding to holidays
    fr_holidays = holidays.FR(years=X["year"].unique().tolist())
    X.loc[: ,'holidays'] = X['date'].apply(lambda x: x in fr_holidays or x.weekday() >= 5).astype(int)

    # Add covid restrictions
    ld = LockdownDates("France", "2020-09-01", "2022-01-01", ("stay_at_home", "masks"))
    lockdown_dates = ld.dates()
    X = X.reset_index().merge(lockdown_dates['france_stay_at_home'], how='left', left_on='date_ws', right_index=True).set_index('index')
    
    # Month
    months_in_year = 12
    X['sin_month'] = np.sin(2*np.pi*X.month/months_in_year)
    X['cos_month'] = np.cos(2*np.pi*X.month/months_in_year)
    X.drop('month', axis=1, inplace=True)
    
    # Day
    day_in_month = 31
    X['sin_day'] = np.sin(2*np.pi*X.day/day_in_month)
    X['cos_day'] = np.cos(2*np.pi*X.day/day_in_month)
    X.drop('day', axis=1, inplace=True)
    
    # Weekday
    day_in_week = 7
    X['sin_weekday'] = np.sin(2*np.pi*X.weekday/day_in_week)
    X['cos_weekday'] = np.cos(2*np.pi*X.weekday/day_in_week)
    X.drop('weekday', axis=1, inplace=True)
    
    # Hour
    hours_in_day = 24
    X['sin_hour'] = np.sin(2*np.pi*X.hour/hours_in_day)
    X['cos_hour'] = np.cos(2*np.pi*X.hour/hours_in_day)
    X.drop('hour', axis=1, inplace=True)
    
    # Week of year
    weeks_in_year = 52
    X['sin_weekyear'] = np.sin(2*np.pi*X.week_of_year/weeks_in_year)
    X['cos_weekyear'] = np.cos(2*np.pi*X.week_of_year/weeks_in_year)
    X.drop('week_of_year', axis=1, inplace=True)
    
    # Season
    seasons_in_year = 4
    X['sin_season'] = np.sin(2*np.pi*X.season/seasons_in_year)
    X['cos_season'] = np.cos(2*np.pi*X.season/seasons_in_year)
    X.drop('season', axis=1, inplace=True)

    return X

# %%
# Retrieve the closest transport station // Test with number of stations in a radius (Categorical)

def _closest_transport(X): 
    column_names = ['longitude', 'latitude', 'station_name']  # Replace with your actual column names
    idf_stations = pd.read_csv('/Users/ghalichraibi/Desktop/DATA Challenge/Data_Challenge/data/Stations_IDF.csv', delimiter=';', header=None, names=column_names)

    X = X.copy()
    # Create an empty DataFrame to store the results
    result_df = pd.DataFrame(columns=['counter_id', 'closest_metro_distance'])

    # Iterate over unique counter_ids in X
    for counter_id in X['counter_id'].unique():
        coordinates_counter = (X.loc[X['counter_id'] == counter_id, 'latitude'].values[0],
                               X.loc[X['counter_id'] == counter_id, 'longitude'].values[0])

        # Calculate distances to all metro stations
        distances = []
        for _, station_row in idf_stations.iterrows():
            coordinates_station = (station_row['latitude'], station_row['longitude'])
            distance = hs.haversine(coordinates_counter, coordinates_station)
            distances.append(distance)

        # Get the k closest distances
        closest_distance = sorted(distances)[0]

        # Append to the result DataFrame
        result_df = pd.concat([result_df, pd.DataFrame({'counter_id': [counter_id], 'closest_metro_distance': [closest_distance]})])
    
    result_df = result_df.set_index('counter_id')
    X = X.reset_index().merge(result_df['closest_metro_distance'], how='left', left_on='counter_id', right_index=True).set_index('index')
        
    return X

# %%
# Add Weather Data // Only the 'Coco' column this time

def _add_weather_data(X):
    X = X.copy()
    dfs = []

    for counter_id in X['counter_id'].unique():
        # Get the coordinates of the counter
        coordinates_counter = (
            X.loc[X['counter_id'] == counter_id, 'latitude'].values[0],
            X.loc[X['counter_id'] == counter_id, 'longitude'].values[0]
        )

        # Create a Point object with the counter's coordinates
        counter_point = Point(*coordinates_counter)

        # Define the time range (start and end dates)
        start = datetime(2020, 8, 1)
        end = datetime(2022, 1, 1)

        # Create a Hourly object and fetch the weather data
        weather_data = Hourly(counter_point, start, end).fetch()
        selected_columns = ['coco']
        weather_data = weather_data[selected_columns].astype('int').shift(-1)

        # Append counter_id to the weather_data DataFrame
        weather_data['counter_id'] = counter_id

        # Append the DataFrame to the list
        dfs.append(weather_data)

    # Concatenate all DataFrames into a single result_df
    result_df = pd.concat(dfs)
    
    # Convert 'time' index to 'date' column for merging
    result_df['date'] = result_df.index
    result_df['date'] = pd.to_datetime(result_df['date'])
    
    # Merge the result DataFrame with the original DataFrame on 'counter_id' and 'date'
    X = X.reset_index().merge(result_df, how='left', on=['counter_id', 'date']).set_index('index')

    return X.drop(columns=["date", "counter_name", "site_id", "site_name", 
                           "counter_installation_date", "coordinates", "counter_technical_id",
                           "longitude", "latitude", "date_ws"])

# %% [markdown]
# ### Call all functions on X train, concatenate with y_train and run ydata_profiling

# %%
# Please don't change the X_train_encode to not overwrite the initial dataset that will be used later for the modelling

X_train_encoded = _encode_dates(X_train)
X_train_encoded = _closest_transport(X_train_encoded)
X_train_encoded = _add_weather_data(X_train_encoded)
# Out:
# Fetching lockdown dates...
# Fetched lockdown dates for: France

# %%
# Do the necessary changes to proceed to ydata_profiling

y_train_transformed = pd.Series(y_train).reset_index(drop=True)

concatenated_df = pd.concat([X_train_encoded.reset_index(drop=True), y_train_transformed], axis=1)

# %%
concatenated_df.head()
# Out:
#             counter_id  year  holidays france_stay_at_home  sin_month  \
# 0  100049407-353255860  2020         0                 0.0       -1.0
# 1  100049407-353255859  2020         0                 0.0       -1.0
# 2  100036719-104036719  2020         0                 0.0       -1.0
# 3  100036719-103036719  2020         0                 0.0       -1.0
# 4  100063175-353277233  2020         0                 0.0       -1.0
#
#       cos_month   sin_day  cos_day  sin_weekday  cos_weekday  sin_hour  \
# 0 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  0.258819
# 1 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  0.258819
# 2 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  0.258819
# 3 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  0.258819
# 4 -1.836970e-16  0.201299  0.97953     0.781831      0.62349  0.258819
#
#    cos_hour  sin_weekyear  cos_weekyear  sin_season    cos_season  \
# 0  0.965926     -0.935016     -0.354605        -1.0 -1.836970e-16
# 1  0.965926     -0.935016     -0.354605        -1.0 -1.836970e-16
# 2  0.965926     -0.935016     -0.354605        -1.0 -1.836970e-16
# 3  0.965926     -0.935016     -0.354605        -1.0 -1.836970e-16
# 4  0.965926     -0.935016     -0.354605        -1.0 -1.836970e-16
#
#    closest_metro_distance  coco         0
# 0                0.268640   1.0  1.609438
# 1                0.268640   1.0  1.386294
# 2                0.016574   1.0  0.000000
# 3                0.016574   1.0  0.693147
# 4                0.197986   5.0  2.079442

# %%
#import ydata_profiling

#concatenated_df.profile_report()

# %% [markdown]
# **Note on the correlation matrix that some of the cos/sin features that we derive are correlated between each other. Try to keep only certain of them and keep the other as categories**

# %% [markdown]
# ### Create Pipeline and CV

# %%
def get_estimator():
    date_encoder = FunctionTransformer(_encode_dates)
    transport_encoder = FunctionTransformer(_closest_transport)
    weather_encoder = FunctionTransformer(_add_weather_data)
    
    date_cols = ["sin_month", "sin_day", "sin_hour", "sin_weekyear", "sin_weekday",
                 "cos_month", "cos_day", "cos_hour", "cos_weekyear", "cos_weekday"]

    categorical_cols = ["counter_id", "closest_metro_distance", "holidays", "france_stay_at_home", "year", "coco"]
    #numerical_cols = ['temp', 'rhum', 'wspd', 'prcp']

    preprocessor = ColumnTransformer(
        [
            ("date", 'passthrough', date_cols),
            ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
            #("num", StandardScaler(), numerical_cols)
        ]
    )
    regressor = XGBRegressor()

    pipe = make_pipeline(date_encoder, transport_encoder, weather_encoder, preprocessor, regressor)

    return pipe

# %%
pipe = get_estimator()

pipe.fit(X_train, y_train)

cv = TimeSeriesSplit(n_splits=6)

# When using a scorer in scikit-learn it always needs to be better when smaller, hence the minus sign.
scores = cross_val_score(
    pipe, X_train, y_train, cv=cv, scoring="neg_root_mean_squared_error"
)
print("RMSE: ", scores)
print(f"RMSE (all folds): {-scores.mean():.3} ± {(-scores).std():.3}")
# Out:
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# Learning rate set to 0.109189
# 0:	learn: 1.5447028	total: 76.8ms	remaining: 1m 16s
# 1:	learn: 1.4469341	total: 92.6ms	remaining: 46.2s
# 2:	learn: 1.3627290	total: 109ms	remaining: 36.2s
# 3:	learn: 1.2915703	total: 124ms	remaining: 31s
# 4:	learn: 1.2306188	total: 139ms	remaining: 27.7s
# 5:	learn: 1.1744404	total: 157ms	remaining: 26s
# 6:	learn: 1.1264022	total: 174ms	remaining: 24.7s
# 7:	learn: 1.0860563	total: 190ms	remaining: 23.6s
# 8:	learn: 1.0496096	total: 208ms	remaining: 22.9s
# 9:	learn: 1.0205137	total: 223ms	remaining: 22.1s
# 10:	learn: 0.9945802	total: 237ms	remaining: 21.3s
# 11:	learn: 0.9714565	total: 253ms	remaining: 20.8s
# 12:	learn: 0.9522651	total: 266ms	remaining: 20.2s
# 13:	learn: 0.9320198	total: 282ms	remaining: 19.9s
# 14:	learn: 0.9174434	total: 299ms	remaining: 19.6s
# 15:	learn: 0.9037098	total: 312ms	remaining: 19.2s
# 16:	learn: 0.8879186	total: 329ms	remaining: 19s
# 17:	learn: 0.8710332	total: 344ms	remaining: 18.8s
# 18:	learn: 0.8609989	total: 360ms	remaining: 18.6s
# 19:	learn: 0.8513425	total: 374ms	remaining: 18.3s
# 20:	learn: 0.8373836	total: 389ms	remaining: 18.1s
# 21:	learn: 0.8295186	total: 404ms	remaining: 18s
# 22:	learn: 0.8221823	total: 417ms	remaining: 17.7s
# 23:	learn: 0.8156750	total: 432ms	remaining: 17.6s
# 24:	learn: 0.8074668	total: 447ms	remaining: 17.4s
# 25:	learn: 0.7996699	total: 462ms	remaining: 17.3s
# 26:	learn: 0.7933480	total: 475ms	remaining: 17.1s
# 27:	learn: 0.7866714	total: 488ms	remaining: 17s
# 28:	learn: 0.7815673	total: 502ms	remaining: 16.8s
# 29:	learn: 0.7769627	total: 514ms	remaining: 16.6s
# 30:	learn: 0.7720639	total: 527ms	remaining: 16.5s
# 31:	learn: 0.7631792	total: 541ms	remaining: 16.4s
# 32:	learn: 0.7549336	total: 556ms	remaining: 16.3s
# 33:	learn: 0.7501931	total: 571ms	remaining: 16.2s
# 34:	learn: 0.7456992	total: 584ms	remaining: 16.1s
# 35:	learn: 0.7410424	total: 600ms	remaining: 16.1s
# 36:	learn: 0.7372129	total: 613ms	remaining: 16s
# 37:	learn: 0.7336746	total: 625ms	remaining: 15.8s
# 38:	learn: 0.7304299	total: 638ms	remaining: 15.7s
# 39:	learn: 0.7274904	total: 651ms	remaining: 15.6s
# 40:	learn: 0.7243920	total: 663ms	remaining: 15.5s
# 41:	learn: 0.7203825	total: 678ms	remaining: 15.5s
# 42:	learn: 0.7175444	total: 692ms	remaining: 15.4s
# 43:	learn: 0.7149491	total: 704ms	remaining: 15.3s
# 44:	learn: 0.7085830	total: 720ms	remaining: 15.3s
# 45:	learn: 0.7038157	total: 735ms	remaining: 15.2s
# 46:	learn: 0.7013108	total: 748ms	remaining: 15.2s
# 47:	learn: 0.6990003	total: 760ms	remaining: 15.1s
# 48:	learn: 0.6962235	total: 776ms	remaining: 15.1s
# 49:	learn: 0.6938153	total: 789ms	remaining: 15s
# 50:	learn: 0.6916182	total: 801ms	remaining: 14.9s
# 51:	learn: 0.6868231	total: 816ms	remaining: 14.9s
# 52:	learn: 0.6821890	total: 831ms	remaining: 14.8s
# 53:	learn: 0.6797331	total: 846ms	remaining: 14.8s
# 54:	learn: 0.6762779	total: 859ms	remaining: 14.8s
# 55:	learn: 0.6742783	total: 872ms	remaining: 14.7s
# 56:	learn: 0.6724670	total: 885ms	remaining: 14.6s
# 57:	learn: 0.6691612	total: 897ms	remaining: 14.6s
# 58:	learn: 0.6674149	total: 909ms	remaining: 14.5s
# 59:	learn: 0.6636633	total: 923ms	remaining: 14.5s
# 60:	learn: 0.6613749	total: 937ms	remaining: 14.4s
# 61:	learn: 0.6599432	total: 951ms	remaining: 14.4s
# 62:	learn: 0.6552803	total: 965ms	remaining: 14.4s
# 63:	learn: 0.6530889	total: 979ms	remaining: 14.3s
# 64:	learn: 0.6516005	total: 991ms	remaining: 14.3s
# 65:	learn: 0.6492740	total: 1s	remaining: 14.2s
# 66:	learn: 0.6446509	total: 1.02s	remaining: 14.2s
# 67:	learn: 0.6432575	total: 1.03s	remaining: 14.2s
# 68:	learn: 0.6418856	total: 1.05s	remaining: 14.2s
# 69:	learn: 0.6405989	total: 1.06s	remaining: 14.1s
# 70:	learn: 0.6369021	total: 1.08s	remaining: 14.1s
# 71:	learn: 0.6321653	total: 1.09s	remaining: 14.1s
# 72:	learn: 0.6298646	total: 1.11s	remaining: 14s
# 73:	learn: 0.6284169	total: 1.12s	remaining: 14s
# 74:	learn: 0.6256341	total: 1.13s	remaining: 14s
# 75:	learn: 0.6242370	total: 1.15s	remaining: 14s
# 76:	learn: 0.6228574	total: 1.16s	remaining: 13.9s
# 77:	learn: 0.6191405	total: 1.18s	remaining: 13.9s
# 78:	learn: 0.6172594	total: 1.19s	remaining: 13.9s
# 79:	learn: 0.6162105	total: 1.21s	remaining: 13.9s
# 80:	learn: 0.6133568	total: 1.23s	remaining: 13.9s
# 81:	learn: 0.6114665	total: 1.24s	remaining: 13.9s
# 82:	learn: 0.6105236	total: 1.25s	remaining: 13.9s
# 83:	learn: 0.6095265	total: 1.27s	remaining: 13.8s
# 84:	learn: 0.6085873	total: 1.28s	remaining: 13.8s
# 85:	learn: 0.6075550	total: 1.29s	remaining: 13.8s
# 86:	learn: 0.6050833	total: 1.31s	remaining: 13.8s
# 87:	learn: 0.6030921	total: 1.32s	remaining: 13.7s
# 88:	learn: 0.6014983	total: 1.34s	remaining: 13.7s
# 89:	learn: 0.6005389	total: 1.35s	remaining: 13.7s
# 90:	learn: 0.5996353	total: 1.37s	remaining: 13.7s
# 91:	learn: 0.5986671	total: 1.38s	remaining: 13.6s
# 92:	learn: 0.5974136	total: 1.39s	remaining: 13.6s
# 93:	learn: 0.5959102	total: 1.41s	remaining: 13.6s
# 94:	learn: 0.5943951	total: 1.43s	remaining: 13.6s
# 95:	learn: 0.5925838	total: 1.44s	remaining: 13.6s
# 96:	learn: 0.5917672	total: 1.45s	remaining: 13.5s
# 97:	learn: 0.5910605	total: 1.46s	remaining: 13.5s
# 98:	learn: 0.5896377	total: 1.48s	remaining: 13.4s
# 99:	learn: 0.5889339	total: 1.49s	remaining: 13.4s
# 100:	learn: 0.5876998	total: 1.5s	remaining: 13.4s
# 101:	learn: 0.5866722	total: 1.52s	remaining: 13.4s
# 102:	learn: 0.5848120	total: 1.53s	remaining: 13.4s
# 103:	learn: 0.5830786	total: 1.55s	remaining: 13.3s
# 104:	learn: 0.5810471	total: 1.56s	remaining: 13.3s
# 105:	learn: 0.5796208	total: 1.58s	remaining: 13.3s
# 106:	learn: 0.5787590	total: 1.59s	remaining: 13.3s
# 107:	learn: 0.5766448	total: 1.61s	remaining: 13.3s
# 108:	learn: 0.5757117	total: 1.62s	remaining: 13.3s
# 109:	learn: 0.5745678	total: 1.64s	remaining: 13.3s
# 110:	learn: 0.5733191	total: 1.65s	remaining: 13.2s
# 111:	learn: 0.5722897	total: 1.66s	remaining: 13.2s
# 112:	learn: 0.5711837	total: 1.68s	remaining: 13.2s
# 113:	learn: 0.5705434	total: 1.69s	remaining: 13.1s
# 114:	learn: 0.5698494	total: 1.7s	remaining: 13.1s
# 115:	learn: 0.5684942	total: 1.72s	remaining: 13.1s
# 116:	learn: 0.5676176	total: 1.73s	remaining: 13.1s
# 117:	learn: 0.5669348	total: 1.75s	remaining: 13.1s
# 118:	learn: 0.5655129	total: 1.76s	remaining: 13s
# 119:	learn: 0.5645977	total: 1.77s	remaining: 13s
# 120:	learn: 0.5620977	total: 1.79s	remaining: 13s
# 121:	learn: 0.5613234	total: 1.81s	remaining: 13s
# 122:	learn: 0.5599915	total: 1.82s	remaining: 13s
# 123:	learn: 0.5595157	total: 1.83s	remaining: 13s
# 124:	learn: 0.5580344	total: 1.85s	remaining: 13s
# 125:	learn: 0.5569621	total: 1.86s	remaining: 12.9s
# 126:	learn: 0.5560854	total: 1.88s	remaining: 12.9s
# 127:	learn: 0.5551800	total: 1.89s	remaining: 12.9s
# 128:	learn: 0.5546588	total: 1.91s	remaining: 12.9s
# 129:	learn: 0.5536464	total: 1.92s	remaining: 12.8s
# 130:	learn: 0.5528274	total: 1.94s	remaining: 12.8s
# 131:	learn: 0.5516970	total: 1.95s	remaining: 12.8s
# 132:	learn: 0.5506974	total: 1.96s	remaining: 12.8s
# 133:	learn: 0.5499302	total: 1.98s	remaining: 12.8s
# 134:	learn: 0.5492289	total: 1.99s	remaining: 12.8s
# 135:	learn: 0.5484736	total: 2s	remaining: 12.7s
# 136:	learn: 0.5476797	total: 2.02s	remaining: 12.7s
# 137:	learn: 0.5469652	total: 2.03s	remaining: 12.7s
# 138:	learn: 0.5461214	total: 2.04s	remaining: 12.7s
# 139:	learn: 0.5447738	total: 2.06s	remaining: 12.7s
# 140:	learn: 0.5439310	total: 2.07s	remaining: 12.6s
# 141:	learn: 0.5421751	total: 2.09s	remaining: 12.6s
# 142:	learn: 0.5407556	total: 2.1s	remaining: 12.6s
# 143:	learn: 0.5400974	total: 2.12s	remaining: 12.6s
# 144:	learn: 0.5394148	total: 2.13s	remaining: 12.6s
# 145:	learn: 0.5384970	total: 2.15s	remaining: 12.6s
# 146:	learn: 0.5378203	total: 2.16s	remaining: 12.6s
# 147:	learn: 0.5364924	total: 2.18s	remaining: 12.5s
# 148:	learn: 0.5356242	total: 2.19s	remaining: 12.5s
# 149:	learn: 0.5351928	total: 2.21s	remaining: 12.5s
# 150:	learn: 0.5345651	total: 2.22s	remaining: 12.5s
# 151:	learn: 0.5338559	total: 2.23s	remaining: 12.5s
# 152:	learn: 0.5332317	total: 2.25s	remaining: 12.4s
# 153:	learn: 0.5325780	total: 2.26s	remaining: 12.4s
# 154:	learn: 0.5316833	total: 2.27s	remaining: 12.4s
# 155:	learn: 0.5306849	total: 2.29s	remaining: 12.4s
# 156:	learn: 0.5299802	total: 2.31s	remaining: 12.4s
# 157:	learn: 0.5292975	total: 2.32s	remaining: 12.4s
# 158:	learn: 0.5288889	total: 2.33s	remaining: 12.3s
# 159:	learn: 0.5279189	total: 2.35s	remaining: 12.3s
# 160:	learn: 0.5274854	total: 2.36s	remaining: 12.3s
# 161:	learn: 0.5267952	total: 2.38s	remaining: 12.3s
# 162:	learn: 0.5257248	total: 2.39s	remaining: 12.3s
# 163:	learn: 0.5253065	total: 2.4s	remaining: 12.3s
# 164:	learn: 0.5238390	total: 2.42s	remaining: 12.2s
# 165:	learn: 0.5233304	total: 2.43s	remaining: 12.2s
# 166:	learn: 0.5228814	total: 2.45s	remaining: 12.2s
# 167:	learn: 0.5221258	total: 2.46s	remaining: 12.2s
# 168:	learn: 0.5215776	total: 2.47s	remaining: 12.2s
# 169:	learn: 0.5210500	total: 2.49s	remaining: 12.2s
# 170:	learn: 0.5201436	total: 2.5s	remaining: 12.1s
# 171:	learn: 0.5194309	total: 2.52s	remaining: 12.1s
# 172:	learn: 0.5185074	total: 2.53s	remaining: 12.1s
# 173:	learn: 0.5177401	total: 2.55s	remaining: 12.1s
# 174:	learn: 0.5171421	total: 2.56s	remaining: 12.1s
# 175:	learn: 0.5168074	total: 2.58s	remaining: 12.1s
# 176:	learn: 0.5161639	total: 2.59s	remaining: 12s
# 177:	learn: 0.5152423	total: 2.6s	remaining: 12s
# 178:	learn: 0.5142832	total: 2.62s	remaining: 12s
# 179:	learn: 0.5138042	total: 2.63s	remaining: 12s
# 180:	learn: 0.5129191	total: 2.65s	remaining: 12s
# 181:	learn: 0.5118703	total: 2.66s	remaining: 12s
# 182:	learn: 0.5110471	total: 2.68s	remaining: 12s
# 183:	learn: 0.5104569	total: 2.69s	remaining: 11.9s
# 184:	learn: 0.5100369	total: 2.71s	remaining: 11.9s
# 185:	learn: 0.5093147	total: 2.72s	remaining: 11.9s
# 186:	learn: 0.5086830	total: 2.74s	remaining: 11.9s
# 187:	learn: 0.5082231	total: 2.75s	remaining: 11.9s
# 188:	learn: 0.5075423	total: 2.77s	remaining: 11.9s
# 189:	learn: 0.5070306	total: 2.78s	remaining: 11.8s
# 190:	learn: 0.5064685	total: 2.79s	remaining: 11.8s
# 191:	learn: 0.5060297	total: 2.81s	remaining: 11.8s
# 192:	learn: 0.5056057	total: 2.82s	remaining: 11.8s
# 193:	learn: 0.5050582	total: 2.83s	remaining: 11.8s
# 194:	learn: 0.5044356	total: 2.85s	remaining: 11.8s
# 195:	learn: 0.5040537	total: 2.86s	remaining: 11.7s
# 196:	learn: 0.5038265	total: 2.88s	remaining: 11.7s
# 197:	learn: 0.5034504	total: 2.89s	remaining: 11.7s
# 198:	learn: 0.5025991	total: 2.91s	remaining: 11.7s
# 199:	learn: 0.5019205	total: 2.92s	remaining: 11.7s
# 200:	learn: 0.5013932	total: 2.94s	remaining: 11.7s
# 201:	learn: 0.5009767	total: 2.95s	remaining: 11.7s
# 202:	learn: 0.5005611	total: 2.97s	remaining: 11.6s
# 203:	learn: 0.5001343	total: 2.98s	remaining: 11.6s
# 204:	learn: 0.4996367	total: 2.99s	remaining: 11.6s
# 205:	learn: 0.4992395	total: 3.01s	remaining: 11.6s
# 206:	learn: 0.4988022	total: 3.02s	remaining: 11.6s
# 207:	learn: 0.4978114	total: 3.04s	remaining: 11.6s
# 208:	learn: 0.4972427	total: 3.05s	remaining: 11.6s
# 209:	learn: 0.4968380	total: 3.06s	remaining: 11.5s
# 210:	learn: 0.4964003	total: 3.08s	remaining: 11.5s
# 211:	learn: 0.4958125	total: 3.09s	remaining: 11.5s
# 212:	learn: 0.4954513	total: 3.11s	remaining: 11.5s
# 213:	learn: 0.4948780	total: 3.13s	remaining: 11.5s
# 214:	learn: 0.4938573	total: 3.14s	remaining: 11.5s
# 215:	learn: 0.4934148	total: 3.15s	remaining: 11.4s
# 216:	learn: 0.4930678	total: 3.17s	remaining: 11.4s
# 217:	learn: 0.4928026	total: 3.18s	remaining: 11.4s
# 218:	learn: 0.4921554	total: 3.2s	remaining: 11.4s
# 219:	learn: 0.4914770	total: 3.21s	remaining: 11.4s
# 220:	learn: 0.4909794	total: 3.22s	remaining: 11.4s
# 221:	learn: 0.4904148	total: 3.24s	remaining: 11.4s
# 222:	learn: 0.4897074	total: 3.25s	remaining: 11.3s
# 223:	learn: 0.4891595	total: 3.27s	remaining: 11.3s
# 224:	learn: 0.4886662	total: 3.29s	remaining: 11.3s
# 225:	learn: 0.4882790	total: 3.3s	remaining: 11.3s
# 226:	learn: 0.4879596	total: 3.33s	remaining: 11.3s
# 227:	learn: 0.4874798	total: 3.36s	remaining: 11.4s
# 228:	learn: 0.4871126	total: 3.38s	remaining: 11.4s
# 229:	learn: 0.4867339	total: 3.39s	remaining: 11.4s
# 230:	learn: 0.4863130	total: 3.41s	remaining: 11.3s
# 231:	learn: 0.4858543	total: 3.42s	remaining: 11.3s
# 232:	learn: 0.4855594	total: 3.44s	remaining: 11.3s
# 233:	learn: 0.4852133	total: 3.45s	remaining: 11.3s
# 234:	learn: 0.4845188	total: 3.47s	remaining: 11.3s
# 235:	learn: 0.4841122	total: 3.48s	remaining: 11.3s
# 236:	learn: 0.4837805	total: 3.5s	remaining: 11.3s
# 237:	learn: 0.4835661	total: 3.51s	remaining: 11.2s
# 238:	learn: 0.4830933	total: 3.53s	remaining: 11.2s
# 239:	learn: 0.4826658	total: 3.54s	remaining: 11.2s
# 240:	learn: 0.4821236	total: 3.56s	remaining: 11.2s
# 241:	learn: 0.4818229	total: 3.57s	remaining: 11.2s
# 242:	learn: 0.4813316	total: 3.58s	remaining: 11.2s
# 243:	learn: 0.4809446	total: 3.6s	remaining: 11.1s
# 244:	learn: 0.4803864	total: 3.61s	remaining: 11.1s
# 245:	learn: 0.4799045	total: 3.63s	remaining: 11.1s
# 246:	learn: 0.4794719	total: 3.64s	remaining: 11.1s
# 247:	learn: 0.4791642	total: 3.65s	remaining: 11.1s
# 248:	learn: 0.4786313	total: 3.67s	remaining: 11.1s
# 249:	learn: 0.4780786	total: 3.68s	remaining: 11.1s
# 250:	learn: 0.4777348	total: 3.7s	remaining: 11s
# 251:	learn: 0.4774284	total: 3.71s	remaining: 11s
# 252:	learn: 0.4770834	total: 3.73s	remaining: 11s
# 253:	learn: 0.4767367	total: 3.74s	remaining: 11s
# 254:	learn: 0.4763788	total: 3.75s	remaining: 11s
# 255:	learn: 0.4756067	total: 3.77s	remaining: 11s
# 256:	learn: 0.4752464	total: 3.78s	remaining: 10.9s
# 257:	learn: 0.4748236	total: 3.8s	remaining: 10.9s
# 258:	learn: 0.4745389	total: 3.81s	remaining: 10.9s
# 259:	learn: 0.4742176	total: 3.83s	remaining: 10.9s
# 260:	learn: 0.4739561	total: 3.84s	remaining: 10.9s
# 261:	learn: 0.4737505	total: 3.86s	remaining: 10.9s
# 262:	learn: 0.4734956	total: 3.87s	remaining: 10.8s
# 263:	learn: 0.4731443	total: 3.89s	remaining: 10.8s
# 264:	learn: 0.4727469	total: 3.9s	remaining: 10.8s
# 265:	learn: 0.4722718	total: 3.92s	remaining: 10.8s
# 266:	learn: 0.4719553	total: 3.93s	remaining: 10.8s
# 267:	learn: 0.4713253	total: 3.95s	remaining: 10.8s
# 268:	learn: 0.4710635	total: 3.96s	remaining: 10.8s
# 269:	learn: 0.4708094	total: 3.98s	remaining: 10.7s
# 270:	learn: 0.4704854	total: 3.99s	remaining: 10.7s
# 271:	learn: 0.4700487	total: 4.01s	remaining: 10.7s
# 272:	learn: 0.4697487	total: 4.02s	remaining: 10.7s
# 273:	learn: 0.4694343	total: 4.04s	remaining: 10.7s
# 274:	learn: 0.4692125	total: 4.05s	remaining: 10.7s
# 275:	learn: 0.4689588	total: 4.06s	remaining: 10.7s
# 276:	learn: 0.4686257	total: 4.08s	remaining: 10.6s
# 277:	learn: 0.4683028	total: 4.09s	remaining: 10.6s
# 278:	learn: 0.4679417	total: 4.11s	remaining: 10.6s
# 279:	learn: 0.4676602	total: 4.12s	remaining: 10.6s
# 280:	learn: 0.4672585	total: 4.13s	remaining: 10.6s
# 281:	learn: 0.4670336	total: 4.15s	remaining: 10.6s
# 282:	learn: 0.4665265	total: 4.17s	remaining: 10.6s
# 283:	learn: 0.4662827	total: 4.18s	remaining: 10.5s
# 284:	learn: 0.4660206	total: 4.19s	remaining: 10.5s
# 285:	learn: 0.4657319	total: 4.21s	remaining: 10.5s
# 286:	learn: 0.4653536	total: 4.22s	remaining: 10.5s
# 287:	learn: 0.4649785	total: 4.24s	remaining: 10.5s
# 288:	learn: 0.4645262	total: 4.25s	remaining: 10.5s
# 289:	learn: 0.4641375	total: 4.27s	remaining: 10.5s
# 290:	learn: 0.4639535	total: 4.28s	remaining: 10.4s
# 291:	learn: 0.4636715	total: 4.3s	remaining: 10.4s
# 292:	learn: 0.4634042	total: 4.31s	remaining: 10.4s
# 293:	learn: 0.4631439	total: 4.33s	remaining: 10.4s
# 294:	learn: 0.4624724	total: 4.34s	remaining: 10.4s
# 295:	learn: 0.4622262	total: 4.36s	remaining: 10.4s
# 296:	learn: 0.4620239	total: 4.37s	remaining: 10.3s
# 297:	learn: 0.4617393	total: 4.38s	remaining: 10.3s
# 298:	learn: 0.4614940	total: 4.4s	remaining: 10.3s
# 299:	learn: 0.4611397	total: 4.42s	remaining: 10.3s
# 300:	learn: 0.4608480	total: 4.43s	remaining: 10.3s
# 301:	learn: 0.4606245	total: 4.44s	remaining: 10.3s
# 302:	learn: 0.4603218	total: 4.46s	remaining: 10.3s
# 303:	learn: 0.4600500	total: 4.47s	remaining: 10.2s
# 304:	learn: 0.4597957	total: 4.49s	remaining: 10.2s
# 305:	learn: 0.4594775	total: 4.5s	remaining: 10.2s
# 306:	learn: 0.4590955	total: 4.52s	remaining: 10.2s
# 307:	learn: 0.4587568	total: 4.53s	remaining: 10.2s
# 308:	learn: 0.4584934	total: 4.55s	remaining: 10.2s
# 309:	learn: 0.4582806	total: 4.56s	remaining: 10.2s
# 310:	learn: 0.4580978	total: 4.58s	remaining: 10.1s
# 311:	learn: 0.4578123	total: 4.59s	remaining: 10.1s
# 312:	learn: 0.4575304	total: 4.61s	remaining: 10.1s
# 313:	learn: 0.4573320	total: 4.62s	remaining: 10.1s
# 314:	learn: 0.4570697	total: 4.63s	remaining: 10.1s
# 315:	learn: 0.4566070	total: 4.65s	remaining: 10.1s
# 316:	learn: 0.4563660	total: 4.67s	remaining: 10.1s
# 317:	learn: 0.4560710	total: 4.68s	remaining: 10s
# 318:	learn: 0.4558934	total: 4.69s	remaining: 10s
# 319:	learn: 0.4555960	total: 4.71s	remaining: 10s
# 320:	learn: 0.4550805	total: 4.72s	remaining: 9.99s
# 321:	learn: 0.4549152	total: 4.74s	remaining: 9.97s
# 322:	learn: 0.4546817	total: 4.75s	remaining: 9.96s
# 323:	learn: 0.4545214	total: 4.76s	remaining: 9.94s
# 324:	learn: 0.4542683	total: 4.78s	remaining: 9.93s
# 325:	learn: 0.4541110	total: 4.79s	remaining: 9.91s
# 326:	learn: 0.4538038	total: 4.81s	remaining: 9.89s
# 327:	learn: 0.4536255	total: 4.82s	remaining: 9.88s
# 328:	learn: 0.4533902	total: 4.84s	remaining: 9.87s
# 329:	learn: 0.4531203	total: 4.85s	remaining: 9.85s
# 330:	learn: 0.4528915	total: 4.87s	remaining: 9.84s
# 331:	learn: 0.4526528	total: 4.88s	remaining: 9.82s
# 332:	learn: 0.4522987	total: 4.9s	remaining: 9.81s
# 333:	learn: 0.4519063	total: 4.91s	remaining: 9.79s
# 334:	learn: 0.4517232	total: 4.92s	remaining: 9.78s
# 335:	learn: 0.4514950	total: 4.94s	remaining: 9.76s
# 336:	learn: 0.4512496	total: 4.96s	remaining: 9.75s
# 337:	learn: 0.4509662	total: 4.97s	remaining: 9.74s
# 338:	learn: 0.4507598	total: 4.99s	remaining: 9.72s
# 339:	learn: 0.4502263	total: 5s	remaining: 9.71s
# 340:	learn: 0.4500512	total: 5.01s	remaining: 9.69s
# 341:	learn: 0.4498745	total: 5.03s	remaining: 9.67s
# 342:	learn: 0.4496103	total: 5.04s	remaining: 9.66s
# 343:	learn: 0.4493841	total: 5.06s	remaining: 9.64s
# 344:	learn: 0.4492263	total: 5.07s	remaining: 9.63s
# 345:	learn: 0.4490734	total: 5.08s	remaining: 9.61s
# 346:	learn: 0.4489418	total: 5.1s	remaining: 9.6s
# 347:	learn: 0.4488146	total: 5.11s	remaining: 9.58s
# 348:	learn: 0.4486326	total: 5.13s	remaining: 9.57s
# 349:	learn: 0.4484447	total: 5.14s	remaining: 9.55s
# 350:	learn: 0.4482108	total: 5.16s	remaining: 9.54s
# 351:	learn: 0.4479838	total: 5.17s	remaining: 9.52s
# 352:	learn: 0.4478236	total: 5.19s	remaining: 9.51s
# 353:	learn: 0.4476423	total: 5.2s	remaining: 9.49s
# 354:	learn: 0.4474733	total: 5.22s	remaining: 9.48s
# 355:	learn: 0.4470056	total: 5.23s	remaining: 9.46s
# 356:	learn: 0.4468274	total: 5.25s	remaining: 9.45s
# 357:	learn: 0.4466679	total: 5.26s	remaining: 9.43s
# 358:	learn: 0.4464352	total: 5.28s	remaining: 9.42s
# 359:	learn: 0.4462140	total: 5.29s	remaining: 9.41s
# 360:	learn: 0.4459982	total: 5.31s	remaining: 9.39s
# 361:	learn: 0.4458010	total: 5.32s	remaining: 9.38s
# 362:	learn: 0.4456027	total: 5.34s	remaining: 9.37s
# 363:	learn: 0.4454084	total: 5.35s	remaining: 9.35s
# 364:	learn: 0.4451793	total: 5.37s	remaining: 9.34s
# 365:	learn: 0.4450207	total: 5.38s	remaining: 9.32s
# 366:	learn: 0.4448690	total: 5.39s	remaining: 9.3s
# 367:	learn: 0.4446486	total: 5.41s	remaining: 9.29s
# 368:	learn: 0.4444907	total: 5.42s	remaining: 9.27s
# 369:	learn: 0.4443329	total: 5.43s	remaining: 9.25s
# 370:	learn: 0.4441491	total: 5.45s	remaining: 9.24s
# 371:	learn: 0.4438822	total: 5.46s	remaining: 9.22s
# 372:	learn: 0.4436370	total: 5.48s	remaining: 9.21s
# 373:	learn: 0.4434769	total: 5.49s	remaining: 9.19s
# 374:	learn: 0.4433275	total: 5.51s	remaining: 9.18s
# 375:	learn: 0.4430611	total: 5.52s	remaining: 9.16s
# 376:	learn: 0.4429296	total: 5.53s	remaining: 9.14s
# 377:	learn: 0.4428053	total: 5.55s	remaining: 9.13s
# 378:	learn: 0.4426329	total: 5.56s	remaining: 9.12s
# 379:	learn: 0.4422829	total: 5.58s	remaining: 9.1s
# 380:	learn: 0.4420414	total: 5.59s	remaining: 9.09s
# 381:	learn: 0.4418750	total: 5.61s	remaining: 9.07s
# 382:	learn: 0.4417436	total: 5.62s	remaining: 9.06s
# 383:	learn: 0.4413736	total: 5.64s	remaining: 9.04s
# 384:	learn: 0.4408936	total: 5.65s	remaining: 9.03s
# 385:	learn: 0.4407526	total: 5.67s	remaining: 9.02s
# 386:	learn: 0.4405240	total: 5.68s	remaining: 9s
# 387:	learn: 0.4403551	total: 5.7s	remaining: 8.99s
# 388:	learn: 0.4401564	total: 5.71s	remaining: 8.97s
# 389:	learn: 0.4399949	total: 5.73s	remaining: 8.96s
# 390:	learn: 0.4398075	total: 5.74s	remaining: 8.94s
# 391:	learn: 0.4396129	total: 5.76s	remaining: 8.93s
# 392:	learn: 0.4393875	total: 5.77s	remaining: 8.91s
# 393:	learn: 0.4391528	total: 5.78s	remaining: 8.9s
# 394:	learn: 0.4389439	total: 5.8s	remaining: 8.88s
# 395:	learn: 0.4388011	total: 5.81s	remaining: 8.87s
# 396:	learn: 0.4385926	total: 5.83s	remaining: 8.85s
# 397:	learn: 0.4384594	total: 5.84s	remaining: 8.84s
# 398:	learn: 0.4382070	total: 5.86s	remaining: 8.83s
# 399:	learn: 0.4380193	total: 5.87s	remaining: 8.81s
# 400:	learn: 0.4378554	total: 5.89s	remaining: 8.8s
# 401:	learn: 0.4377229	total: 5.9s	remaining: 8.78s
# 402:	learn: 0.4375516	total: 5.92s	remaining: 8.77s
# 403:	learn: 0.4374069	total: 5.93s	remaining: 8.75s
# 404:	learn: 0.4371601	total: 5.95s	remaining: 8.73s
# 405:	learn: 0.4369794	total: 5.96s	remaining: 8.72s
# 406:	learn: 0.4368225	total: 5.98s	remaining: 8.71s
# 407:	learn: 0.4364508	total: 5.99s	remaining: 8.69s
# 408:	learn: 0.4362489	total: 6s	remaining: 8.68s
# 409:	learn: 0.4359606	total: 6.02s	remaining: 8.66s
# 410:	learn: 0.4357207	total: 6.04s	remaining: 8.65s
# 411:	learn: 0.4355217	total: 6.05s	remaining: 8.63s
# 412:	learn: 0.4353798	total: 6.06s	remaining: 8.62s
# 413:	learn: 0.4352014	total: 6.08s	remaining: 8.61s
# 414:	learn: 0.4350947	total: 6.09s	remaining: 8.59s
# 415:	learn: 0.4349656	total: 6.11s	remaining: 8.57s
# 416:	learn: 0.4348207	total: 6.12s	remaining: 8.56s
# 417:	learn: 0.4346783	total: 6.13s	remaining: 8.54s
# 418:	learn: 0.4345015	total: 6.15s	remaining: 8.53s
# 419:	learn: 0.4343285	total: 6.16s	remaining: 8.51s
# 420:	learn: 0.4341877	total: 6.18s	remaining: 8.5s
# 421:	learn: 0.4340199	total: 6.19s	remaining: 8.48s
# 422:	learn: 0.4338939	total: 6.21s	remaining: 8.47s
# 423:	learn: 0.4337643	total: 6.22s	remaining: 8.45s
# 424:	learn: 0.4335773	total: 6.24s	remaining: 8.44s
# 425:	learn: 0.4333513	total: 6.25s	remaining: 8.42s
# 426:	learn: 0.4331902	total: 6.26s	remaining: 8.41s
# 427:	learn: 0.4330391	total: 6.28s	remaining: 8.39s
# 428:	learn: 0.4328609	total: 6.29s	remaining: 8.38s
# 429:	learn: 0.4325983	total: 6.31s	remaining: 8.37s
# 430:	learn: 0.4324650	total: 6.33s	remaining: 8.35s
# 431:	learn: 0.4321959	total: 6.34s	remaining: 8.34s
# 432:	learn: 0.4319694	total: 6.36s	remaining: 8.32s
# 433:	learn: 0.4318520	total: 6.37s	remaining: 8.31s
# 434:	learn: 0.4317165	total: 6.38s	remaining: 8.29s
# 435:	learn: 0.4315388	total: 6.4s	remaining: 8.28s
# 436:	learn: 0.4312523	total: 6.42s	remaining: 8.27s
# 437:	learn: 0.4310923	total: 6.43s	remaining: 8.25s
# 438:	learn: 0.4308931	total: 6.45s	remaining: 8.24s
# 439:	learn: 0.4306802	total: 6.46s	remaining: 8.22s
# 440:	learn: 0.4304422	total: 6.47s	remaining: 8.21s
# 441:	learn: 0.4301813	total: 6.49s	remaining: 8.19s
# 442:	learn: 0.4300361	total: 6.51s	remaining: 8.18s
# 443:	learn: 0.4299128	total: 6.52s	remaining: 8.16s
# 444:	learn: 0.4297773	total: 6.53s	remaining: 8.15s
# 445:	learn: 0.4295591	total: 6.55s	remaining: 8.13s
# 446:	learn: 0.4293786	total: 6.56s	remaining: 8.12s
# 447:	learn: 0.4292220	total: 6.58s	remaining: 8.1s
# 448:	learn: 0.4290774	total: 6.59s	remaining: 8.09s
# 449:	learn: 0.4288640	total: 6.61s	remaining: 8.08s
# 450:	learn: 0.4287627	total: 6.62s	remaining: 8.06s
# 451:	learn: 0.4286563	total: 6.64s	remaining: 8.04s
# 452:	learn: 0.4285122	total: 6.65s	remaining: 8.03s
# 453:	learn: 0.4284015	total: 6.66s	remaining: 8.01s
# 454:	learn: 0.4282460	total: 6.68s	remaining: 8s
# 455:	learn: 0.4280401	total: 6.69s	remaining: 7.99s
# 456:	learn: 0.4279086	total: 6.71s	remaining: 7.97s
# 457:	learn: 0.4277749	total: 6.72s	remaining: 7.95s
# 458:	learn: 0.4276743	total: 6.73s	remaining: 7.94s
# 459:	learn: 0.4274673	total: 6.75s	remaining: 7.92s
# 460:	learn: 0.4272768	total: 6.76s	remaining: 7.91s
# 461:	learn: 0.4271341	total: 6.78s	remaining: 7.89s
# 462:	learn: 0.4270269	total: 6.79s	remaining: 7.88s
# 463:	learn: 0.4268775	total: 6.81s	remaining: 7.87s
# 464:	learn: 0.4267468	total: 6.83s	remaining: 7.85s
# 465:	learn: 0.4266050	total: 6.84s	remaining: 7.84s
# 466:	learn: 0.4264696	total: 6.85s	remaining: 7.82s
# 467:	learn: 0.4263509	total: 6.87s	remaining: 7.81s
# 468:	learn: 0.4261434	total: 6.88s	remaining: 7.79s
# 469:	learn: 0.4258733	total: 6.9s	remaining: 7.78s
# 470:	learn: 0.4257517	total: 6.92s	remaining: 7.77s
# 471:	learn: 0.4256370	total: 6.93s	remaining: 7.75s
# 472:	learn: 0.4254908	total: 6.94s	remaining: 7.74s
# 473:	learn: 0.4253738	total: 6.96s	remaining: 7.72s
# 474:	learn: 0.4252739	total: 6.97s	remaining: 7.71s
# 475:	learn: 0.4251220	total: 6.99s	remaining: 7.69s
# 476:	learn: 0.4249116	total: 7s	remaining: 7.68s
# 477:	learn: 0.4246930	total: 7.02s	remaining: 7.66s
# 478:	learn: 0.4245423	total: 7.03s	remaining: 7.65s
# 479:	learn: 0.4241881	total: 7.05s	remaining: 7.64s
# 480:	learn: 0.4239861	total: 7.06s	remaining: 7.62s
# 481:	learn: 0.4238490	total: 7.08s	remaining: 7.61s
# 482:	learn: 0.4237387	total: 7.09s	remaining: 7.59s
# 483:	learn: 0.4234925	total: 7.11s	remaining: 7.58s
# 484:	learn: 0.4232446	total: 7.12s	remaining: 7.56s
# 485:	learn: 0.4231005	total: 7.14s	remaining: 7.55s
# 486:	learn: 0.4229487	total: 7.15s	remaining: 7.53s
# 487:	learn: 0.4227225	total: 7.17s	remaining: 7.52s
# 488:	learn: 0.4226297	total: 7.18s	remaining: 7.5s
# 489:	learn: 0.4224791	total: 7.2s	remaining: 7.49s
# 490:	learn: 0.4223913	total: 7.21s	remaining: 7.48s
# 491:	learn: 0.4222806	total: 7.23s	remaining: 7.46s
# 492:	learn: 0.4219979	total: 7.24s	remaining: 7.45s
# 493:	learn: 0.4217126	total: 7.26s	remaining: 7.43s
# 494:	learn: 0.4215976	total: 7.27s	remaining: 7.42s
# 495:	learn: 0.4214783	total: 7.29s	remaining: 7.41s
# 496:	learn: 0.4213447	total: 7.3s	remaining: 7.39s
# 497:	learn: 0.4212109	total: 7.32s	remaining: 7.38s
# 498:	learn: 0.4210637	total: 7.33s	remaining: 7.36s
# 499:	learn: 0.4209767	total: 7.34s	remaining: 7.34s
# 500:	learn: 0.4208533	total: 7.36s	remaining: 7.33s
# 501:	learn: 0.4207536	total: 7.38s	remaining: 7.32s
# 502:	learn: 0.4206152	total: 7.39s	remaining: 7.3s
# 503:	learn: 0.4204909	total: 7.4s	remaining: 7.29s
# 504:	learn: 0.4202923	total: 7.42s	remaining: 7.27s
# 505:	learn: 0.4201869	total: 7.43s	remaining: 7.26s
# 506:	learn: 0.4200601	total: 7.45s	remaining: 7.24s
# 507:	learn: 0.4199354	total: 7.46s	remaining: 7.23s
# 508:	learn: 0.4198229	total: 7.48s	remaining: 7.21s
# 509:	learn: 0.4196897	total: 7.49s	remaining: 7.2s
# 510:	learn: 0.4195405	total: 7.51s	remaining: 7.18s
# 511:	learn: 0.4194826	total: 7.52s	remaining: 7.17s
# 512:	learn: 0.4193575	total: 7.53s	remaining: 7.15s
# 513:	learn: 0.4190308	total: 7.55s	remaining: 7.14s
# 514:	learn: 0.4187823	total: 7.56s	remaining: 7.12s
# 515:	learn: 0.4186489	total: 7.58s	remaining: 7.11s
# 516:	learn: 0.4184560	total: 7.59s	remaining: 7.09s
# 517:	learn: 0.4183511	total: 7.61s	remaining: 7.08s
# 518:	learn: 0.4182225	total: 7.62s	remaining: 7.06s
# 519:	learn: 0.4180995	total: 7.63s	remaining: 7.05s
# 520:	learn: 0.4179445	total: 7.65s	remaining: 7.03s
# 521:	learn: 0.4178559	total: 7.66s	remaining: 7.02s
# 522:	learn: 0.4177728	total: 7.68s	remaining: 7s
# 523:	learn: 0.4176991	total: 7.69s	remaining: 6.99s
# 524:	learn: 0.4176107	total: 7.7s	remaining: 6.97s
# 525:	learn: 0.4174761	total: 7.72s	remaining: 6.96s
# 526:	learn: 0.4173776	total: 7.73s	remaining: 6.94s
# 527:	learn: 0.4172849	total: 7.75s	remaining: 6.92s
# 528:	learn: 0.4172030	total: 7.76s	remaining: 6.91s
# 529:	learn: 0.4170468	total: 7.78s	remaining: 6.9s
# 530:	learn: 0.4169464	total: 7.82s	remaining: 6.91s
# 531:	learn: 0.4168882	total: 7.84s	remaining: 6.9s
# 532:	learn: 0.4167545	total: 7.85s	remaining: 6.88s
# 533:	learn: 0.4166415	total: 7.87s	remaining: 6.87s
# 534:	learn: 0.4165155	total: 7.88s	remaining: 6.85s
# 535:	learn: 0.4164181	total: 7.9s	remaining: 6.84s
# 536:	learn: 0.4160701	total: 7.91s	remaining: 6.82s
# 537:	learn: 0.4159999	total: 7.92s	remaining: 6.8s
# 538:	learn: 0.4158960	total: 7.94s	remaining: 6.79s
# 539:	learn: 0.4158160	total: 7.95s	remaining: 6.77s
# 540:	learn: 0.4157011	total: 7.97s	remaining: 6.76s
# 541:	learn: 0.4155695	total: 7.98s	remaining: 6.75s
# 542:	learn: 0.4154101	total: 8s	remaining: 6.73s
# 543:	learn: 0.4152805	total: 8.01s	remaining: 6.72s
# 544:	learn: 0.4151845	total: 8.03s	remaining: 6.7s
# 545:	learn: 0.4149308	total: 8.04s	remaining: 6.69s
# 546:	learn: 0.4148174	total: 8.06s	remaining: 6.67s
# 547:	learn: 0.4147119	total: 8.07s	remaining: 6.66s
# 548:	learn: 0.4146106	total: 8.09s	remaining: 6.64s
# 549:	learn: 0.4144997	total: 8.1s	remaining: 6.63s
# 550:	learn: 0.4143599	total: 8.12s	remaining: 6.61s
# 551:	learn: 0.4142949	total: 8.13s	remaining: 6.6s
# 552:	learn: 0.4141957	total: 8.14s	remaining: 6.58s
# 553:	learn: 0.4140627	total: 8.16s	remaining: 6.57s
# 554:	learn: 0.4138743	total: 8.17s	remaining: 6.55s
# 555:	learn: 0.4137548	total: 8.19s	remaining: 6.54s
# 556:	learn: 0.4135903	total: 8.21s	remaining: 6.53s
# 557:	learn: 0.4134209	total: 8.22s	remaining: 6.51s
# 558:	learn: 0.4132733	total: 8.24s	remaining: 6.5s
# 559:	learn: 0.4131239	total: 8.25s	remaining: 6.48s
# 560:	learn: 0.4129541	total: 8.27s	remaining: 6.47s
# 561:	learn: 0.4127398	total: 8.28s	remaining: 6.45s
# 562:	learn: 0.4126487	total: 8.3s	remaining: 6.44s
# 563:	learn: 0.4125905	total: 8.31s	remaining: 6.42s
# 564:	learn: 0.4124661	total: 8.33s	remaining: 6.41s
# 565:	learn: 0.4123071	total: 8.34s	remaining: 6.4s
# 566:	learn: 0.4120928	total: 8.36s	remaining: 6.38s
# 567:	learn: 0.4119783	total: 8.37s	remaining: 6.37s
# 568:	learn: 0.4118036	total: 8.39s	remaining: 6.35s
# 569:	learn: 0.4117001	total: 8.4s	remaining: 6.34s
# 570:	learn: 0.4116085	total: 8.42s	remaining: 6.32s
# 571:	learn: 0.4114760	total: 8.43s	remaining: 6.31s
# 572:	learn: 0.4113718	total: 8.44s	remaining: 6.29s
# 573:	learn: 0.4112089	total: 8.46s	remaining: 6.28s
# 574:	learn: 0.4111491	total: 8.47s	remaining: 6.26s
# 575:	learn: 0.4110677	total: 8.49s	remaining: 6.25s
# 576:	learn: 0.4109611	total: 8.5s	remaining: 6.23s
# 577:	learn: 0.4108759	total: 8.52s	remaining: 6.22s
# 578:	learn: 0.4107509	total: 8.53s	remaining: 6.2s
# 579:	learn: 0.4106486	total: 8.55s	remaining: 6.19s
# 580:	learn: 0.4105354	total: 8.56s	remaining: 6.17s
# 581:	learn: 0.4104484	total: 8.58s	remaining: 6.16s
# 582:	learn: 0.4103488	total: 8.59s	remaining: 6.14s
# 583:	learn: 0.4102745	total: 8.6s	remaining: 6.13s
# 584:	learn: 0.4101557	total: 8.62s	remaining: 6.11s
# 585:	learn: 0.4100283	total: 8.63s	remaining: 6.1s
# 586:	learn: 0.4099355	total: 8.65s	remaining: 6.08s
# 587:	learn: 0.4097999	total: 8.66s	remaining: 6.07s
# 588:	learn: 0.4096694	total: 8.68s	remaining: 6.05s
# 589:	learn: 0.4095680	total: 8.69s	remaining: 6.04s
# 590:	learn: 0.4094953	total: 8.71s	remaining: 6.03s
# 591:	learn: 0.4093746	total: 8.72s	remaining: 6.01s
# 592:	learn: 0.4091926	total: 8.74s	remaining: 6s
# 593:	learn: 0.4090717	total: 8.75s	remaining: 5.98s
# 594:	learn: 0.4089852	total: 8.76s	remaining: 5.96s
# 595:	learn: 0.4088946	total: 8.78s	remaining: 5.95s
# 596:	learn: 0.4088010	total: 8.79s	remaining: 5.94s
# 597:	learn: 0.4087205	total: 8.81s	remaining: 5.92s
# 598:	learn: 0.4085866	total: 8.82s	remaining: 5.91s
# 599:	learn: 0.4084058	total: 8.84s	remaining: 5.89s
# 600:	learn: 0.4082793	total: 8.85s	remaining: 5.88s
# 601:	learn: 0.4081529	total: 8.87s	remaining: 5.86s
# 602:	learn: 0.4080674	total: 8.88s	remaining: 5.85s
# 603:	learn: 0.4079889	total: 8.9s	remaining: 5.83s
# 604:	learn: 0.4078962	total: 8.91s	remaining: 5.82s
# 605:	learn: 0.4078035	total: 8.93s	remaining: 5.8s
# 606:	learn: 0.4076634	total: 8.94s	remaining: 5.79s
# 607:	learn: 0.4073867	total: 8.95s	remaining: 5.77s
# 608:	learn: 0.4073219	total: 8.97s	remaining: 5.76s
# 609:	learn: 0.4072007	total: 8.98s	remaining: 5.74s
# 610:	learn: 0.4071244	total: 9s	remaining: 5.73s
# 611:	learn: 0.4070225	total: 9.01s	remaining: 5.71s
# 612:	learn: 0.4069381	total: 9.03s	remaining: 5.7s
# 613:	learn: 0.4068590	total: 9.04s	remaining: 5.68s
# 614:	learn: 0.4067925	total: 9.05s	remaining: 5.67s
# 615:	learn: 0.4067081	total: 9.07s	remaining: 5.65s
# 616:	learn: 0.4066310	total: 9.08s	remaining: 5.64s
# 617:	learn: 0.4065618	total: 9.1s	remaining: 5.62s
# 618:	learn: 0.4064060	total: 9.11s	remaining: 5.61s
# 619:	learn: 0.4063010	total: 9.13s	remaining: 5.59s
# 620:	learn: 0.4061765	total: 9.14s	remaining: 5.58s
# 621:	learn: 0.4060816	total: 9.15s	remaining: 5.56s
# 622:	learn: 0.4059834	total: 9.17s	remaining: 5.55s
# 623:	learn: 0.4059047	total: 9.18s	remaining: 5.53s
# 624:	learn: 0.4057989	total: 9.2s	remaining: 5.52s
# 625:	learn: 0.4056894	total: 9.21s	remaining: 5.5s
# 626:	learn: 0.4056025	total: 9.22s	remaining: 5.49s
# 627:	learn: 0.4055290	total: 9.24s	remaining: 5.47s
# 628:	learn: 0.4054282	total: 9.25s	remaining: 5.46s
# 629:	learn: 0.4053363	total: 9.27s	remaining: 5.44s
# 630:	learn: 0.4052430	total: 9.28s	remaining: 5.43s
# 631:	learn: 0.4051438	total: 9.29s	remaining: 5.41s
# 632:	learn: 0.4050004	total: 9.31s	remaining: 5.4s
# 633:	learn: 0.4048791	total: 9.32s	remaining: 5.38s
# 634:	learn: 0.4048193	total: 9.34s	remaining: 5.37s
# 635:	learn: 0.4047166	total: 9.35s	remaining: 5.35s
# 636:	learn: 0.4046352	total: 9.37s	remaining: 5.34s
# 637:	learn: 0.4045651	total: 9.38s	remaining: 5.32s
# 638:	learn: 0.4044775	total: 9.39s	remaining: 5.31s
# 639:	learn: 0.4043951	total: 9.41s	remaining: 5.29s
# 640:	learn: 0.4042968	total: 9.42s	remaining: 5.28s
# 641:	learn: 0.4041887	total: 9.44s	remaining: 5.26s
# 642:	learn: 0.4041121	total: 9.45s	remaining: 5.25s
# 643:	learn: 0.4039221	total: 9.47s	remaining: 5.23s
# 644:	learn: 0.4038097	total: 9.48s	remaining: 5.22s
# 645:	learn: 0.4037689	total: 9.5s	remaining: 5.2s
# 646:	learn: 0.4037009	total: 9.51s	remaining: 5.19s
# 647:	learn: 0.4035848	total: 9.53s	remaining: 5.17s
# 648:	learn: 0.4035108	total: 9.54s	remaining: 5.16s
# 649:	learn: 0.4034671	total: 9.55s	remaining: 5.14s
# 650:	learn: 0.4033915	total: 9.57s	remaining: 5.13s
# 651:	learn: 0.4033323	total: 9.58s	remaining: 5.11s
# 652:	learn: 0.4032362	total: 9.6s	remaining: 5.1s
# 653:	learn: 0.4031121	total: 9.61s	remaining: 5.09s
# 654:	learn: 0.4030160	total: 9.63s	remaining: 5.07s
# 655:	learn: 0.4029301	total: 9.64s	remaining: 5.06s
# 656:	learn: 0.4028407	total: 9.66s	remaining: 5.04s
# 657:	learn: 0.4027505	total: 9.67s	remaining: 5.03s
# 658:	learn: 0.4026413	total: 9.69s	remaining: 5.01s
# 659:	learn: 0.4025373	total: 9.7s	remaining: 5s
# 660:	learn: 0.4023998	total: 9.72s	remaining: 4.98s
# 661:	learn: 0.4023247	total: 9.73s	remaining: 4.97s
# 662:	learn: 0.4022383	total: 9.75s	remaining: 4.95s
# 663:	learn: 0.4020708	total: 9.76s	remaining: 4.94s
# 664:	learn: 0.4019651	total: 9.78s	remaining: 4.92s
# 665:	learn: 0.4018939	total: 9.79s	remaining: 4.91s
# 666:	learn: 0.4017996	total: 9.81s	remaining: 4.9s
# 667:	learn: 0.4017099	total: 9.82s	remaining: 4.88s
# 668:	learn: 0.4016786	total: 9.84s	remaining: 4.87s
# 669:	learn: 0.4015407	total: 9.85s	remaining: 4.85s
# 670:	learn: 0.4014642	total: 9.87s	remaining: 4.84s
# 671:	learn: 0.4014094	total: 9.88s	remaining: 4.82s
# 672:	learn: 0.4013368	total: 9.89s	remaining: 4.81s
# 673:	learn: 0.4012533	total: 9.91s	remaining: 4.79s
# 674:	learn: 0.4011417	total: 9.92s	remaining: 4.78s
# 675:	learn: 0.4010478	total: 9.94s	remaining: 4.76s
# 676:	learn: 0.4009199	total: 9.95s	remaining: 4.75s
# 677:	learn: 0.4007534	total: 9.97s	remaining: 4.73s
# 678:	learn: 0.4006752	total: 9.98s	remaining: 4.72s
# 679:	learn: 0.4006105	total: 10s	remaining: 4.71s
# 680:	learn: 0.4005308	total: 10s	remaining: 4.69s
# 681:	learn: 0.4004424	total: 10s	remaining: 4.67s
# 682:	learn: 0.4003869	total: 10s	remaining: 4.66s
# 683:	learn: 0.4002965	total: 10.1s	remaining: 4.64s
# 684:	learn: 0.4001755	total: 10.1s	remaining: 4.63s
# 685:	learn: 0.4001367	total: 10.1s	remaining: 4.62s
# 686:	learn: 0.4000590	total: 10.1s	remaining: 4.6s
# 687:	learn: 0.3999805	total: 10.1s	remaining: 4.59s
# 688:	learn: 0.3998899	total: 10.1s	remaining: 4.57s
# 689:	learn: 0.3997896	total: 10.1s	remaining: 4.56s
# 690:	learn: 0.3997325	total: 10.2s	remaining: 4.54s
# 691:	learn: 0.3996906	total: 10.2s	remaining: 4.53s
# 692:	learn: 0.3995927	total: 10.2s	remaining: 4.51s
# 693:	learn: 0.3994992	total: 10.2s	remaining: 4.5s
# 694:	learn: 0.3994218	total: 10.2s	remaining: 4.48s
# 695:	learn: 0.3993097	total: 10.2s	remaining: 4.47s
# 696:	learn: 0.3992067	total: 10.2s	remaining: 4.45s
# 697:	learn: 0.3990899	total: 10.3s	remaining: 4.44s
# 698:	learn: 0.3990065	total: 10.3s	remaining: 4.42s
# 699:	learn: 0.3989424	total: 10.3s	remaining: 4.41s
# 700:	learn: 0.3988903	total: 10.3s	remaining: 4.39s
# 701:	learn: 0.3988273	total: 10.3s	remaining: 4.38s
# 702:	learn: 0.3987552	total: 10.3s	remaining: 4.36s
# 703:	learn: 0.3986996	total: 10.3s	remaining: 4.35s
# 704:	learn: 0.3985996	total: 10.4s	remaining: 4.33s
# 705:	learn: 0.3985443	total: 10.4s	remaining: 4.32s
# 706:	learn: 0.3984492	total: 10.4s	remaining: 4.31s
# 707:	learn: 0.3984145	total: 10.4s	remaining: 4.29s
# 708:	learn: 0.3983418	total: 10.4s	remaining: 4.28s
# 709:	learn: 0.3982798	total: 10.4s	remaining: 4.26s
# 710:	learn: 0.3982117	total: 10.4s	remaining: 4.25s
# 711:	learn: 0.3981344	total: 10.5s	remaining: 4.23s
# 712:	learn: 0.3980616	total: 10.5s	remaining: 4.22s
# 713:	learn: 0.3979780	total: 10.5s	remaining: 4.2s
# 714:	learn: 0.3978549	total: 10.5s	remaining: 4.19s
# 715:	learn: 0.3977544	total: 10.5s	remaining: 4.17s
# 716:	learn: 0.3976709	total: 10.5s	remaining: 4.16s
# 717:	learn: 0.3975961	total: 10.6s	remaining: 4.14s
# 718:	learn: 0.3975173	total: 10.6s	remaining: 4.13s
# 719:	learn: 0.3974795	total: 10.6s	remaining: 4.11s
# 720:	learn: 0.3974249	total: 10.6s	remaining: 4.1s
# 721:	learn: 0.3973817	total: 10.6s	remaining: 4.08s
# 722:	learn: 0.3972750	total: 10.6s	remaining: 4.07s
# 723:	learn: 0.3972241	total: 10.6s	remaining: 4.05s
# 724:	learn: 0.3971803	total: 10.6s	remaining: 4.04s
# 725:	learn: 0.3970773	total: 10.7s	remaining: 4.02s
# 726:	learn: 0.3969885	total: 10.7s	remaining: 4.01s
# 727:	learn: 0.3969194	total: 10.7s	remaining: 3.99s
# 728:	learn: 0.3968519	total: 10.7s	remaining: 3.98s
# 729:	learn: 0.3967392	total: 10.7s	remaining: 3.96s
# 730:	learn: 0.3966461	total: 10.7s	remaining: 3.95s
# 731:	learn: 0.3965837	total: 10.7s	remaining: 3.94s
# 732:	learn: 0.3965325	total: 10.8s	remaining: 3.92s
# 733:	learn: 0.3964347	total: 10.8s	remaining: 3.9s
# 734:	learn: 0.3962380	total: 10.8s	remaining: 3.89s
# 735:	learn: 0.3959148	total: 10.8s	remaining: 3.88s
# 736:	learn: 0.3958619	total: 10.8s	remaining: 3.86s
# 737:	learn: 0.3957896	total: 10.8s	remaining: 3.85s
# 738:	learn: 0.3956840	total: 10.8s	remaining: 3.83s
# 739:	learn: 0.3956180	total: 10.9s	remaining: 3.82s
# 740:	learn: 0.3955539	total: 10.9s	remaining: 3.8s
# 741:	learn: 0.3954782	total: 10.9s	remaining: 3.79s
# 742:	learn: 0.3953957	total: 10.9s	remaining: 3.77s
# 743:	learn: 0.3953083	total: 10.9s	remaining: 3.76s
# 744:	learn: 0.3952741	total: 10.9s	remaining: 3.74s
# 745:	learn: 0.3951982	total: 10.9s	remaining: 3.73s
# 746:	learn: 0.3951270	total: 11s	remaining: 3.71s
# 747:	learn: 0.3949971	total: 11s	remaining: 3.7s
# 748:	learn: 0.3949552	total: 11s	remaining: 3.68s
# 749:	learn: 0.3948746	total: 11s	remaining: 3.67s
# 750:	learn: 0.3947901	total: 11s	remaining: 3.65s
# 751:	learn: 0.3947432	total: 11s	remaining: 3.64s
# 752:	learn: 0.3946892	total: 11s	remaining: 3.62s
# 753:	learn: 0.3946201	total: 11.1s	remaining: 3.61s
# 754:	learn: 0.3945629	total: 11.1s	remaining: 3.59s
# 755:	learn: 0.3944661	total: 11.1s	remaining: 3.58s
# 756:	learn: 0.3943344	total: 11.1s	remaining: 3.56s
# 757:	learn: 0.3942662	total: 11.1s	remaining: 3.55s
# 758:	learn: 0.3941914	total: 11.1s	remaining: 3.54s
# 759:	learn: 0.3939244	total: 11.2s	remaining: 3.52s
# 760:	learn: 0.3938083	total: 11.2s	remaining: 3.51s
# 761:	learn: 0.3937443	total: 11.2s	remaining: 3.49s
# 762:	learn: 0.3937082	total: 11.2s	remaining: 3.48s
# 763:	learn: 0.3936276	total: 11.2s	remaining: 3.46s
# 764:	learn: 0.3935349	total: 11.2s	remaining: 3.45s
# 765:	learn: 0.3934640	total: 11.2s	remaining: 3.43s
# 766:	learn: 0.3934160	total: 11.3s	remaining: 3.42s
# 767:	learn: 0.3933603	total: 11.3s	remaining: 3.4s
# 768:	learn: 0.3932705	total: 11.3s	remaining: 3.39s
# 769:	learn: 0.3932195	total: 11.3s	remaining: 3.37s
# 770:	learn: 0.3931502	total: 11.3s	remaining: 3.36s
# 771:	learn: 0.3930560	total: 11.3s	remaining: 3.35s
# 772:	learn: 0.3929222	total: 11.3s	remaining: 3.33s
# 773:	learn: 0.3928741	total: 11.4s	remaining: 3.32s
# 774:	learn: 0.3928358	total: 11.4s	remaining: 3.3s
# 775:	learn: 0.3927761	total: 11.4s	remaining: 3.29s
# 776:	learn: 0.3927068	total: 11.4s	remaining: 3.27s
# 777:	learn: 0.3926719	total: 11.4s	remaining: 3.26s
# 778:	learn: 0.3926259	total: 11.4s	remaining: 3.24s
# 779:	learn: 0.3925770	total: 11.4s	remaining: 3.23s
# 780:	learn: 0.3925317	total: 11.5s	remaining: 3.21s
# 781:	learn: 0.3924468	total: 11.5s	remaining: 3.2s
# 782:	learn: 0.3923641	total: 11.5s	remaining: 3.18s
# 783:	learn: 0.3923100	total: 11.5s	remaining: 3.17s
# 784:	learn: 0.3922701	total: 11.5s	remaining: 3.15s
# 785:	learn: 0.3922043	total: 11.5s	remaining: 3.14s
# 786:	learn: 0.3921307	total: 11.5s	remaining: 3.12s
# 787:	learn: 0.3920504	total: 11.6s	remaining: 3.11s
# 788:	learn: 0.3920021	total: 11.6s	remaining: 3.1s
# 789:	learn: 0.3919465	total: 11.6s	remaining: 3.08s
# 790:	learn: 0.3918246	total: 11.6s	remaining: 3.06s
# 791:	learn: 0.3917527	total: 11.6s	remaining: 3.05s
# 792:	learn: 0.3916918	total: 11.6s	remaining: 3.04s
# 793:	learn: 0.3916384	total: 11.6s	remaining: 3.02s
# 794:	learn: 0.3915578	total: 11.7s	remaining: 3.01s
# 795:	learn: 0.3915010	total: 11.7s	remaining: 2.99s
# 796:	learn: 0.3914265	total: 11.7s	remaining: 2.98s
# 797:	learn: 0.3913347	total: 11.7s	remaining: 2.96s
# 798:	learn: 0.3912818	total: 11.7s	remaining: 2.95s
# 799:	learn: 0.3912269	total: 11.7s	remaining: 2.93s
# 800:	learn: 0.3911514	total: 11.8s	remaining: 2.92s
# 801:	learn: 0.3910594	total: 11.8s	remaining: 2.9s
# 802:	learn: 0.3910149	total: 11.8s	remaining: 2.89s
# 803:	learn: 0.3909442	total: 11.8s	remaining: 2.88s
# 804:	learn: 0.3907841	total: 11.8s	remaining: 2.86s
# 805:	learn: 0.3907449	total: 11.8s	remaining: 2.85s
# 806:	learn: 0.3906535	total: 11.8s	remaining: 2.83s
# 807:	learn: 0.3906017	total: 11.9s	remaining: 2.82s
# 808:	learn: 0.3905500	total: 11.9s	remaining: 2.8s
# 809:	learn: 0.3905050	total: 11.9s	remaining: 2.79s
# 810:	learn: 0.3904565	total: 11.9s	remaining: 2.77s
# 811:	learn: 0.3903773	total: 11.9s	remaining: 2.76s
# 812:	learn: 0.3903241	total: 11.9s	remaining: 2.75s
# 813:	learn: 0.3902765	total: 12s	remaining: 2.73s
# 814:	learn: 0.3902257	total: 12s	remaining: 2.72s
# 815:	learn: 0.3901941	total: 12s	remaining: 2.71s
# 816:	learn: 0.3901311	total: 12s	remaining: 2.69s
# 817:	learn: 0.3900467	total: 12s	remaining: 2.68s
# 818:	learn: 0.3899623	total: 12s	remaining: 2.66s
# 819:	learn: 0.3898771	total: 12.1s	remaining: 2.65s
# 820:	learn: 0.3898219	total: 12.1s	remaining: 2.63s
# 821:	learn: 0.3897454	total: 12.1s	remaining: 2.62s
# 822:	learn: 0.3897048	total: 12.1s	remaining: 2.6s
# 823:	learn: 0.3896253	total: 12.1s	remaining: 2.59s
# 824:	learn: 0.3895687	total: 12.1s	remaining: 2.57s
# 825:	learn: 0.3895100	total: 12.2s	remaining: 2.56s
# 826:	learn: 0.3894623	total: 12.2s	remaining: 2.54s
# 827:	learn: 0.3894179	total: 12.2s	remaining: 2.53s
# 828:	learn: 0.3893532	total: 12.2s	remaining: 2.52s
# 829:	learn: 0.3892927	total: 12.2s	remaining: 2.5s
# 830:	learn: 0.3892436	total: 12.2s	remaining: 2.49s
# 831:	learn: 0.3891823	total: 12.2s	remaining: 2.47s
# 832:	learn: 0.3891328	total: 12.3s	remaining: 2.46s
# 833:	learn: 0.3890766	total: 12.3s	remaining: 2.44s
# 834:	learn: 0.3890202	total: 12.3s	remaining: 2.43s
# 835:	learn: 0.3889619	total: 12.3s	remaining: 2.41s
# 836:	learn: 0.3889065	total: 12.3s	remaining: 2.4s
# 837:	learn: 0.3888302	total: 12.3s	remaining: 2.38s
# 838:	learn: 0.3887760	total: 12.3s	remaining: 2.37s
# 839:	learn: 0.3886970	total: 12.4s	remaining: 2.35s
# 840:	learn: 0.3886324	total: 12.4s	remaining: 2.34s
# 841:	learn: 0.3886015	total: 12.4s	remaining: 2.32s
# 842:	learn: 0.3885424	total: 12.4s	remaining: 2.31s
# 843:	learn: 0.3884028	total: 12.4s	remaining: 2.29s
# 844:	learn: 0.3883150	total: 12.4s	remaining: 2.28s
# 845:	learn: 0.3882620	total: 12.4s	remaining: 2.26s
# 846:	learn: 0.3882245	total: 12.5s	remaining: 2.25s
# 847:	learn: 0.3881713	total: 12.5s	remaining: 2.23s
# 848:	learn: 0.3880832	total: 12.5s	remaining: 2.22s
# 849:	learn: 0.3880286	total: 12.5s	remaining: 2.21s
# 850:	learn: 0.3880099	total: 12.5s	remaining: 2.19s
# 851:	learn: 0.3879422	total: 12.5s	remaining: 2.18s
# 852:	learn: 0.3878758	total: 12.5s	remaining: 2.16s
# 853:	learn: 0.3878030	total: 12.6s	remaining: 2.15s
# 854:	learn: 0.3877311	total: 12.6s	remaining: 2.13s
# 855:	learn: 0.3876646	total: 12.6s	remaining: 2.12s
# 856:	learn: 0.3876210	total: 12.6s	remaining: 2.1s
# 857:	learn: 0.3875633	total: 12.6s	remaining: 2.09s
# 858:	learn: 0.3875339	total: 12.6s	remaining: 2.07s
# 859:	learn: 0.3874792	total: 12.6s	remaining: 2.06s
# 860:	learn: 0.3874184	total: 12.7s	remaining: 2.04s
# 861:	learn: 0.3873729	total: 12.7s	remaining: 2.03s
# 862:	learn: 0.3873231	total: 12.7s	remaining: 2.01s
# 863:	learn: 0.3872829	total: 12.7s	remaining: 2s
# 864:	learn: 0.3872329	total: 12.7s	remaining: 1.98s
# 865:	learn: 0.3871702	total: 12.7s	remaining: 1.97s
# 866:	learn: 0.3871075	total: 12.7s	remaining: 1.95s
# 867:	learn: 0.3870005	total: 12.8s	remaining: 1.94s
# 868:	learn: 0.3869167	total: 12.8s	remaining: 1.93s
# 869:	learn: 0.3868588	total: 12.8s	remaining: 1.91s
# 870:	learn: 0.3868005	total: 12.8s	remaining: 1.9s
# 871:	learn: 0.3867404	total: 12.8s	remaining: 1.88s
# 872:	learn: 0.3866894	total: 12.8s	remaining: 1.87s
# 873:	learn: 0.3866204	total: 12.8s	remaining: 1.85s
# 874:	learn: 0.3865832	total: 12.9s	remaining: 1.84s
# 875:	learn: 0.3865105	total: 12.9s	remaining: 1.82s
# 876:	learn: 0.3864645	total: 12.9s	remaining: 1.81s
# 877:	learn: 0.3863866	total: 12.9s	remaining: 1.79s
# 878:	learn: 0.3861095	total: 12.9s	remaining: 1.78s
# 879:	learn: 0.3860552	total: 12.9s	remaining: 1.76s
# 880:	learn: 0.3860002	total: 13s	remaining: 1.75s
# 881:	learn: 0.3859534	total: 13s	remaining: 1.73s
# 882:	learn: 0.3858699	total: 13s	remaining: 1.72s
# 883:	learn: 0.3857810	total: 13s	remaining: 1.71s
# 884:	learn: 0.3856886	total: 13s	remaining: 1.69s
# 885:	learn: 0.3856404	total: 13s	remaining: 1.68s
# 886:	learn: 0.3855396	total: 13s	remaining: 1.66s
# 887:	learn: 0.3854723	total: 13.1s	remaining: 1.65s
# 888:	learn: 0.3854312	total: 13.1s	remaining: 1.63s
# 889:	learn: 0.3853689	total: 13.1s	remaining: 1.62s
# 890:	learn: 0.3853185	total: 13.1s	remaining: 1.6s
# 891:	learn: 0.3852782	total: 13.1s	remaining: 1.59s
# 892:	learn: 0.3852038	total: 13.1s	remaining: 1.57s
# 893:	learn: 0.3851236	total: 13.1s	remaining: 1.56s
# 894:	learn: 0.3850925	total: 13.2s	remaining: 1.54s
# 895:	learn: 0.3850324	total: 13.2s	remaining: 1.53s
# 896:	learn: 0.3849909	total: 13.2s	remaining: 1.51s
# 897:	learn: 0.3849253	total: 13.2s	remaining: 1.5s
# 898:	learn: 0.3848679	total: 13.2s	remaining: 1.48s
# 899:	learn: 0.3847926	total: 13.2s	remaining: 1.47s
# 900:	learn: 0.3847294	total: 13.2s	remaining: 1.46s
# 901:	learn: 0.3846998	total: 13.3s	remaining: 1.44s
# 902:	learn: 0.3846613	total: 13.3s	remaining: 1.43s
# 903:	learn: 0.3846157	total: 13.3s	remaining: 1.41s
# 904:	learn: 0.3845536	total: 13.3s	remaining: 1.4s
# 905:	learn: 0.3844977	total: 13.3s	remaining: 1.38s
# 906:	learn: 0.3844632	total: 13.3s	remaining: 1.37s
# 907:	learn: 0.3844044	total: 13.4s	remaining: 1.35s
# 908:	learn: 0.3843613	total: 13.4s	remaining: 1.34s
# 909:	learn: 0.3843233	total: 13.4s	remaining: 1.32s
# 910:	learn: 0.3842775	total: 13.4s	remaining: 1.31s
# 911:	learn: 0.3842340	total: 13.4s	remaining: 1.29s
# 912:	learn: 0.3841663	total: 13.4s	remaining: 1.28s
# 913:	learn: 0.3841179	total: 13.4s	remaining: 1.26s
# 914:	learn: 0.3840928	total: 13.5s	remaining: 1.25s
# 915:	learn: 0.3840423	total: 13.5s	remaining: 1.23s
# 916:	learn: 0.3839985	total: 13.5s	remaining: 1.22s
# 917:	learn: 0.3838794	total: 13.5s	remaining: 1.21s
# 918:	learn: 0.3838279	total: 13.5s	remaining: 1.19s
# 919:	learn: 0.3837650	total: 13.5s	remaining: 1.18s
# 920:	learn: 0.3837071	total: 13.5s	remaining: 1.16s
# 921:	learn: 0.3836635	total: 13.6s	remaining: 1.15s
# 922:	learn: 0.3836334	total: 13.6s	remaining: 1.13s
# 923:	learn: 0.3835425	total: 13.6s	remaining: 1.12s
# 924:	learn: 0.3834225	total: 13.6s	remaining: 1.1s
# 925:	learn: 0.3833795	total: 13.6s	remaining: 1.09s
# 926:	learn: 0.3833180	total: 13.6s	remaining: 1.07s
# 927:	learn: 0.3832887	total: 13.6s	remaining: 1.06s
# ...
# 694:	learn: 0.4014809	total: 9.71s	remaining: 4.26s
# 695:	learn: 0.4014000	total: 9.72s	remaining: 4.25s
# 696:	learn: 0.4013574	total: 9.74s	remaining: 4.23s
# 697:	learn: 0.4012687	total: 9.75s	remaining: 4.22s
# 698:	learn: 0.4012132	total: 9.77s	remaining: 4.21s
# 699:	learn: 0.4011403	total: 9.78s	remaining: 4.19s
# 700:	learn: 0.4010280	total: 9.79s	remaining: 4.18s
# 701:	learn: 0.4009584	total: 9.8s	remaining: 4.16s
# 702:	learn: 0.4008611	total: 9.82s	remaining: 4.15s
# 703:	learn: 0.4008206	total: 9.83s	remaining: 4.13s
# 704:	learn: 0.4007488	total: 9.85s	remaining: 4.12s
# 705:	learn: 0.4006763	total: 9.86s	remaining: 4.11s
# 706:	learn: 0.4006061	total: 9.87s	remaining: 4.09s
# 707:	learn: 0.4004726	total: 9.89s	remaining: 4.08s
# 708:	learn: 0.4003620	total: 9.9s	remaining: 4.07s
# 709:	learn: 0.4003214	total: 9.92s	remaining: 4.05s
# 710:	learn: 0.4002134	total: 9.93s	remaining: 4.04s
# 711:	learn: 0.4001491	total: 9.94s	remaining: 4.02s
# 712:	learn: 0.4000481	total: 9.96s	remaining: 4.01s
# 713:	learn: 0.4000027	total: 9.97s	remaining: 3.99s
# 714:	learn: 0.3998722	total: 9.99s	remaining: 3.98s
# 715:	learn: 0.3997831	total: 10s	remaining: 3.97s
# 716:	learn: 0.3997324	total: 10s	remaining: 3.95s
# 717:	learn: 0.3996608	total: 10s	remaining: 3.94s
# 718:	learn: 0.3994955	total: 10s	remaining: 3.92s
# 719:	learn: 0.3993985	total: 10.1s	remaining: 3.91s
# 720:	learn: 0.3993431	total: 10.1s	remaining: 3.9s
# 721:	learn: 0.3992444	total: 10.1s	remaining: 3.88s
# 722:	learn: 0.3991853	total: 10.1s	remaining: 3.87s
# 723:	learn: 0.3991206	total: 10.1s	remaining: 3.85s
# 724:	learn: 0.3990690	total: 10.1s	remaining: 3.84s
# 725:	learn: 0.3989782	total: 10.1s	remaining: 3.83s
# 726:	learn: 0.3989223	total: 10.2s	remaining: 3.81s
# 727:	learn: 0.3988633	total: 10.2s	remaining: 3.81s
# 728:	learn: 0.3987329	total: 10.2s	remaining: 3.8s
# 729:	learn: 0.3986597	total: 10.2s	remaining: 3.78s
# 730:	learn: 0.3986293	total: 10.2s	remaining: 3.77s
# 731:	learn: 0.3985643	total: 10.3s	remaining: 3.75s
# 732:	learn: 0.3985081	total: 10.3s	remaining: 3.74s
# 733:	learn: 0.3984493	total: 10.3s	remaining: 3.72s
# 734:	learn: 0.3983479	total: 10.3s	remaining: 3.71s
# 735:	learn: 0.3982038	total: 10.3s	remaining: 3.7s
# 736:	learn: 0.3980550	total: 10.3s	remaining: 3.68s
# 737:	learn: 0.3979806	total: 10.3s	remaining: 3.67s
# 738:	learn: 0.3979142	total: 10.4s	remaining: 3.66s
# 739:	learn: 0.3976532	total: 10.4s	remaining: 3.64s
# 740:	learn: 0.3975666	total: 10.4s	remaining: 3.63s
# 741:	learn: 0.3975309	total: 10.4s	remaining: 3.61s
# 742:	learn: 0.3974680	total: 10.4s	remaining: 3.6s
# 743:	learn: 0.3974013	total: 10.4s	remaining: 3.58s
# 744:	learn: 0.3973312	total: 10.4s	remaining: 3.57s
# 745:	learn: 0.3972151	total: 10.4s	remaining: 3.56s
# 746:	learn: 0.3971619	total: 10.5s	remaining: 3.54s
# 747:	learn: 0.3970918	total: 10.5s	remaining: 3.53s
# 748:	learn: 0.3969834	total: 10.5s	remaining: 3.52s
# 749:	learn: 0.3969037	total: 10.5s	remaining: 3.5s
# 750:	learn: 0.3967933	total: 10.5s	remaining: 3.49s
# 751:	learn: 0.3967385	total: 10.5s	remaining: 3.47s
# 752:	learn: 0.3966553	total: 10.5s	remaining: 3.46s
# 753:	learn: 0.3965858	total: 10.6s	remaining: 3.44s
# 754:	learn: 0.3964812	total: 10.6s	remaining: 3.43s
# 755:	learn: 0.3962842	total: 10.6s	remaining: 3.42s
# 756:	learn: 0.3960954	total: 10.6s	remaining: 3.4s
# 757:	learn: 0.3960485	total: 10.6s	remaining: 3.39s
# 758:	learn: 0.3959855	total: 10.6s	remaining: 3.38s
# 759:	learn: 0.3958689	total: 10.6s	remaining: 3.36s
# 760:	learn: 0.3958133	total: 10.7s	remaining: 3.35s
# 761:	learn: 0.3957610	total: 10.7s	remaining: 3.33s
# 762:	learn: 0.3956737	total: 10.7s	remaining: 3.32s
# 763:	learn: 0.3955499	total: 10.7s	remaining: 3.31s
# 764:	learn: 0.3954265	total: 10.7s	remaining: 3.29s
# 765:	learn: 0.3953434	total: 10.7s	remaining: 3.28s
# 766:	learn: 0.3952860	total: 10.7s	remaining: 3.26s
# 767:	learn: 0.3952384	total: 10.8s	remaining: 3.25s
# 768:	learn: 0.3951250	total: 10.8s	remaining: 3.23s
# 769:	learn: 0.3950844	total: 10.8s	remaining: 3.22s
# 770:	learn: 0.3949998	total: 10.8s	remaining: 3.21s
# 771:	learn: 0.3949207	total: 10.8s	remaining: 3.19s
# 772:	learn: 0.3948732	total: 10.8s	remaining: 3.18s
# 773:	learn: 0.3948096	total: 10.8s	remaining: 3.17s
# 774:	learn: 0.3947542	total: 10.9s	remaining: 3.15s
# 775:	learn: 0.3946613	total: 10.9s	remaining: 3.14s
# 776:	learn: 0.3945397	total: 10.9s	remaining: 3.12s
# 777:	learn: 0.3944382	total: 10.9s	remaining: 3.11s
# 778:	learn: 0.3943946	total: 10.9s	remaining: 3.09s
# 779:	learn: 0.3942989	total: 10.9s	remaining: 3.08s
# 780:	learn: 0.3942368	total: 10.9s	remaining: 3.06s
# 781:	learn: 0.3941769	total: 10.9s	remaining: 3.05s
# 782:	learn: 0.3941311	total: 11s	remaining: 3.04s
# 783:	learn: 0.3940463	total: 11s	remaining: 3.02s
# 784:	learn: 0.3939774	total: 11s	remaining: 3.01s
# 785:	learn: 0.3939197	total: 11s	remaining: 3s
# 786:	learn: 0.3938230	total: 11s	remaining: 2.98s
# 787:	learn: 0.3937823	total: 11s	remaining: 2.97s
# 788:	learn: 0.3936883	total: 11s	remaining: 2.95s
# 789:	learn: 0.3936187	total: 11.1s	remaining: 2.94s
# 790:	learn: 0.3935341	total: 11.1s	remaining: 2.93s
# 791:	learn: 0.3934757	total: 11.1s	remaining: 2.91s
# 792:	learn: 0.3934147	total: 11.1s	remaining: 2.9s
# 793:	learn: 0.3933172	total: 11.1s	remaining: 2.88s
# 794:	learn: 0.3932202	total: 11.1s	remaining: 2.87s
# 795:	learn: 0.3931788	total: 11.1s	remaining: 2.86s
# 796:	learn: 0.3931159	total: 11.2s	remaining: 2.84s
# 797:	learn: 0.3930375	total: 11.2s	remaining: 2.83s
# 798:	learn: 0.3929614	total: 11.2s	remaining: 2.81s
# 799:	learn: 0.3929295	total: 11.2s	remaining: 2.8s
# 800:	learn: 0.3928799	total: 11.2s	remaining: 2.79s
# 801:	learn: 0.3928414	total: 11.2s	remaining: 2.77s
# 802:	learn: 0.3927222	total: 11.2s	remaining: 2.76s
# 803:	learn: 0.3926773	total: 11.3s	remaining: 2.74s
# 804:	learn: 0.3925501	total: 11.3s	remaining: 2.73s
# 805:	learn: 0.3924832	total: 11.3s	remaining: 2.72s
# 806:	learn: 0.3924227	total: 11.3s	remaining: 2.7s
# 807:	learn: 0.3923178	total: 11.3s	remaining: 2.69s
# 808:	learn: 0.3922646	total: 11.3s	remaining: 2.67s
# 809:	learn: 0.3921565	total: 11.3s	remaining: 2.66s
# 810:	learn: 0.3920993	total: 11.4s	remaining: 2.65s
# 811:	learn: 0.3920199	total: 11.4s	remaining: 2.63s
# 812:	learn: 0.3919328	total: 11.4s	remaining: 2.62s
# 813:	learn: 0.3918822	total: 11.4s	remaining: 2.6s
# 814:	learn: 0.3918449	total: 11.4s	remaining: 2.59s
# 815:	learn: 0.3918001	total: 11.4s	remaining: 2.58s
# 816:	learn: 0.3917285	total: 11.4s	remaining: 2.56s
# 817:	learn: 0.3916813	total: 11.5s	remaining: 2.55s
# 818:	learn: 0.3916445	total: 11.5s	remaining: 2.53s
# 819:	learn: 0.3915836	total: 11.5s	remaining: 2.52s
# 820:	learn: 0.3915088	total: 11.5s	remaining: 2.5s
# 821:	learn: 0.3914378	total: 11.5s	remaining: 2.49s
# 822:	learn: 0.3913670	total: 11.5s	remaining: 2.48s
# 823:	learn: 0.3912688	total: 11.5s	remaining: 2.46s
# 824:	learn: 0.3911853	total: 11.6s	remaining: 2.45s
# 825:	learn: 0.3911619	total: 11.6s	remaining: 2.44s
# 826:	learn: 0.3910983	total: 11.6s	remaining: 2.42s
# 827:	learn: 0.3910388	total: 11.6s	remaining: 2.41s
# 828:	learn: 0.3909768	total: 11.6s	remaining: 2.4s
# 829:	learn: 0.3908585	total: 11.6s	remaining: 2.38s
# 830:	learn: 0.3907939	total: 11.6s	remaining: 2.37s
# 831:	learn: 0.3907365	total: 11.7s	remaining: 2.35s
# 832:	learn: 0.3906643	total: 11.7s	remaining: 2.34s
# 833:	learn: 0.3905708	total: 11.7s	remaining: 2.33s
# 834:	learn: 0.3904852	total: 11.7s	remaining: 2.31s
# 835:	learn: 0.3904390	total: 11.7s	remaining: 2.3s
# 836:	learn: 0.3903775	total: 11.7s	remaining: 2.28s
# 837:	learn: 0.3903412	total: 11.7s	remaining: 2.27s
# 838:	learn: 0.3902950	total: 11.8s	remaining: 2.26s
# 839:	learn: 0.3902463	total: 11.8s	remaining: 2.24s
# 840:	learn: 0.3900955	total: 11.8s	remaining: 2.23s
# 841:	learn: 0.3900627	total: 11.8s	remaining: 2.21s
# 842:	learn: 0.3900196	total: 11.8s	remaining: 2.2s
# 843:	learn: 0.3899759	total: 11.8s	remaining: 2.19s
# 844:	learn: 0.3898964	total: 11.8s	remaining: 2.17s
# 845:	learn: 0.3898351	total: 11.9s	remaining: 2.16s
# 846:	learn: 0.3897605	total: 11.9s	remaining: 2.14s
# 847:	learn: 0.3896849	total: 11.9s	remaining: 2.13s
# 848:	learn: 0.3895603	total: 11.9s	remaining: 2.12s
# 849:	learn: 0.3895214	total: 11.9s	remaining: 2.1s
# 850:	learn: 0.3894592	total: 11.9s	remaining: 2.09s
# 851:	learn: 0.3894167	total: 11.9s	remaining: 2.07s
# 852:	learn: 0.3893444	total: 12s	remaining: 2.06s
# 853:	learn: 0.3892944	total: 12s	remaining: 2.05s
# 854:	learn: 0.3892296	total: 12s	remaining: 2.03s
# 855:	learn: 0.3891530	total: 12s	remaining: 2.02s
# 856:	learn: 0.3890843	total: 12s	remaining: 2s
# 857:	learn: 0.3890011	total: 12s	remaining: 1.99s
# 858:	learn: 0.3889682	total: 12s	remaining: 1.98s
# 859:	learn: 0.3889284	total: 12.1s	remaining: 1.96s
# 860:	learn: 0.3888044	total: 12.1s	remaining: 1.95s
# 861:	learn: 0.3887282	total: 12.1s	remaining: 1.93s
# 862:	learn: 0.3886705	total: 12.1s	remaining: 1.92s
# 863:	learn: 0.3886210	total: 12.1s	remaining: 1.9s
# 864:	learn: 0.3885887	total: 12.1s	remaining: 1.89s
# 865:	learn: 0.3885627	total: 12.1s	remaining: 1.88s
# 866:	learn: 0.3885291	total: 12.1s	remaining: 1.86s
# 867:	learn: 0.3884692	total: 12.2s	remaining: 1.85s
# 868:	learn: 0.3883850	total: 12.2s	remaining: 1.83s
# 869:	learn: 0.3882892	total: 12.2s	remaining: 1.82s
# 870:	learn: 0.3882280	total: 12.2s	remaining: 1.81s
# 871:	learn: 0.3881558	total: 12.2s	remaining: 1.79s
# 872:	learn: 0.3880941	total: 12.2s	remaining: 1.78s
# 873:	learn: 0.3880334	total: 12.2s	remaining: 1.76s
# 874:	learn: 0.3880072	total: 12.3s	remaining: 1.75s
# 875:	learn: 0.3878797	total: 12.3s	remaining: 1.74s
# 876:	learn: 0.3878341	total: 12.3s	remaining: 1.72s
# 877:	learn: 0.3877799	total: 12.3s	remaining: 1.71s
# 878:	learn: 0.3877415	total: 12.3s	remaining: 1.69s
# 879:	learn: 0.3876930	total: 12.3s	remaining: 1.68s
# 880:	learn: 0.3876258	total: 12.3s	remaining: 1.67s
# 881:	learn: 0.3874920	total: 12.4s	remaining: 1.65s
# 882:	learn: 0.3874074	total: 12.4s	remaining: 1.64s
# 883:	learn: 0.3872924	total: 12.4s	remaining: 1.62s
# 884:	learn: 0.3872370	total: 12.4s	remaining: 1.61s
# 885:	learn: 0.3871773	total: 12.4s	remaining: 1.6s
# 886:	learn: 0.3870883	total: 12.4s	remaining: 1.58s
# 887:	learn: 0.3870075	total: 12.4s	remaining: 1.57s
# 888:	learn: 0.3869211	total: 12.5s	remaining: 1.55s
# 889:	learn: 0.3868828	total: 12.5s	remaining: 1.54s
# 890:	learn: 0.3867943	total: 12.5s	remaining: 1.53s
# 891:	learn: 0.3867308	total: 12.5s	remaining: 1.51s
# 892:	learn: 0.3866856	total: 12.5s	remaining: 1.5s
# 893:	learn: 0.3866130	total: 12.5s	remaining: 1.48s
# 894:	learn: 0.3865285	total: 12.5s	remaining: 1.47s
# 895:	learn: 0.3864800	total: 12.6s	remaining: 1.46s
# 896:	learn: 0.3864362	total: 12.6s	remaining: 1.44s
# 897:	learn: 0.3863847	total: 12.6s	remaining: 1.43s
# 898:	learn: 0.3863425	total: 12.6s	remaining: 1.41s
# 899:	learn: 0.3862865	total: 12.6s	remaining: 1.4s
# 900:	learn: 0.3862476	total: 12.6s	remaining: 1.39s
# 901:	learn: 0.3861993	total: 12.6s	remaining: 1.37s
# 902:	learn: 0.3861779	total: 12.7s	remaining: 1.36s
# 903:	learn: 0.3860892	total: 12.7s	remaining: 1.34s
# 904:	learn: 0.3860531	total: 12.7s	remaining: 1.33s
# 905:	learn: 0.3859968	total: 12.7s	remaining: 1.32s
# 906:	learn: 0.3859661	total: 12.7s	remaining: 1.3s
# 907:	learn: 0.3859066	total: 12.7s	remaining: 1.29s
# 908:	learn: 0.3858523	total: 12.7s	remaining: 1.27s
# 909:	learn: 0.3858242	total: 12.8s	remaining: 1.26s
# 910:	learn: 0.3857793	total: 12.8s	remaining: 1.25s
# 911:	learn: 0.3857215	total: 12.8s	remaining: 1.23s
# 912:	learn: 0.3856866	total: 12.8s	remaining: 1.22s
# 913:	learn: 0.3856442	total: 12.8s	remaining: 1.2s
# 914:	learn: 0.3855890	total: 12.8s	remaining: 1.19s
# 915:	learn: 0.3855098	total: 12.8s	remaining: 1.18s
# 916:	learn: 0.3854507	total: 12.8s	remaining: 1.16s
# 917:	learn: 0.3853967	total: 12.9s	remaining: 1.15s
# 918:	learn: 0.3853530	total: 12.9s	remaining: 1.14s
# 919:	learn: 0.3853154	total: 12.9s	remaining: 1.12s
# 920:	learn: 0.3852260	total: 12.9s	remaining: 1.11s
# 921:	learn: 0.3851908	total: 12.9s	remaining: 1.09s
# 922:	learn: 0.3851673	total: 12.9s	remaining: 1.08s
# 923:	learn: 0.3851345	total: 12.9s	remaining: 1.06s
# 924:	learn: 0.3850842	total: 13s	remaining: 1.05s
# 925:	learn: 0.3850427	total: 13s	remaining: 1.04s
# 926:	learn: 0.3850082	total: 13s	remaining: 1.02s
# 927:	learn: 0.3849450	total: 13s	remaining: 1.01s
# 928:	learn: 0.3849039	total: 13s	remaining: 995ms
# 929:	learn: 0.3847976	total: 13s	remaining: 981ms
# 930:	learn: 0.3847484	total: 13s	remaining: 967ms
# 931:	learn: 0.3846387	total: 13.1s	remaining: 953ms
# 932:	learn: 0.3845894	total: 13.1s	remaining: 939ms
# 933:	learn: 0.3845514	total: 13.1s	remaining: 925ms
# 934:	learn: 0.3845066	total: 13.1s	remaining: 911ms
# 935:	learn: 0.3844659	total: 13.1s	remaining: 897ms
# 936:	learn: 0.3844298	total: 13.1s	remaining: 883ms
# 937:	learn: 0.3843823	total: 13.2s	remaining: 869ms
# 938:	learn: 0.3843199	total: 13.2s	remaining: 855ms
# 939:	learn: 0.3842543	total: 13.2s	remaining: 841ms
# 940:	learn: 0.3841979	total: 13.2s	remaining: 827ms
# 941:	learn: 0.3841533	total: 13.2s	remaining: 813ms
# 942:	learn: 0.3841091	total: 13.2s	remaining: 799ms
# 943:	learn: 0.3840280	total: 13.2s	remaining: 785ms
# 944:	learn: 0.3839464	total: 13.2s	remaining: 771ms
# 945:	learn: 0.3838801	total: 13.3s	remaining: 757ms
# 946:	learn: 0.3838334	total: 13.3s	remaining: 743ms
# 947:	learn: 0.3837302	total: 13.3s	remaining: 729ms
# 948:	learn: 0.3836521	total: 13.3s	remaining: 715ms
# 949:	learn: 0.3836075	total: 13.3s	remaining: 701ms
# 950:	learn: 0.3835078	total: 13.3s	remaining: 687ms
# 951:	learn: 0.3834465	total: 13.3s	remaining: 673ms
# 952:	learn: 0.3834029	total: 13.4s	remaining: 659ms
# 953:	learn: 0.3833473	total: 13.4s	remaining: 645ms
# 954:	learn: 0.3833057	total: 13.4s	remaining: 631ms
# 955:	learn: 0.3832179	total: 13.4s	remaining: 617ms
# 956:	learn: 0.3831852	total: 13.4s	remaining: 603ms
# 957:	learn: 0.3831326	total: 13.4s	remaining: 589ms
# 958:	learn: 0.3830843	total: 13.4s	remaining: 575ms
# 959:	learn: 0.3830287	total: 13.5s	remaining: 561ms
# 960:	learn: 0.3829719	total: 13.5s	remaining: 548ms
# 961:	learn: 0.3829449	total: 13.5s	remaining: 534ms
# 962:	learn: 0.3829094	total: 13.5s	remaining: 520ms
# 963:	learn: 0.3828560	total: 13.5s	remaining: 506ms
# 964:	learn: 0.3828056	total: 13.6s	remaining: 492ms
# 965:	learn: 0.3827289	total: 13.6s	remaining: 478ms
# 966:	learn: 0.3826480	total: 13.6s	remaining: 464ms
# 967:	learn: 0.3826157	total: 13.6s	remaining: 450ms
# 968:	learn: 0.3825474	total: 13.6s	remaining: 436ms
# 969:	learn: 0.3824958	total: 13.6s	remaining: 422ms
# 970:	learn: 0.3824522	total: 13.6s	remaining: 408ms
# 971:	learn: 0.3823922	total: 13.7s	remaining: 394ms
# 972:	learn: 0.3823445	total: 13.7s	remaining: 380ms
# 973:	learn: 0.3822738	total: 13.7s	remaining: 366ms
# 974:	learn: 0.3822495	total: 13.7s	remaining: 352ms
# 975:	learn: 0.3821931	total: 13.7s	remaining: 338ms
# 976:	learn: 0.3821553	total: 13.7s	remaining: 323ms
# 977:	learn: 0.3821133	total: 13.8s	remaining: 309ms
# 978:	learn: 0.3820625	total: 13.8s	remaining: 295ms
# 979:	learn: 0.3819817	total: 13.8s	remaining: 281ms
# 980:	learn: 0.3819254	total: 13.8s	remaining: 267ms
# 981:	learn: 0.3818756	total: 13.8s	remaining: 253ms
# 982:	learn: 0.3818138	total: 13.8s	remaining: 239ms
# 983:	learn: 0.3817838	total: 13.8s	remaining: 225ms
# 984:	learn: 0.3817102	total: 13.9s	remaining: 211ms
# 985:	learn: 0.3816628	total: 13.9s	remaining: 197ms
# 986:	learn: 0.3815815	total: 13.9s	remaining: 183ms
# 987:	learn: 0.3815425	total: 13.9s	remaining: 169ms
# 988:	learn: 0.3815220	total: 13.9s	remaining: 155ms
# 989:	learn: 0.3814883	total: 13.9s	remaining: 141ms
# 990:	learn: 0.3814295	total: 13.9s	remaining: 127ms
# 991:	learn: 0.3813968	total: 14s	remaining: 113ms
# 992:	learn: 0.3813466	total: 14s	remaining: 98.4ms
# 993:	learn: 0.3813032	total: 14s	remaining: 84.4ms
# 994:	learn: 0.3812696	total: 14s	remaining: 70.3ms
# 995:	learn: 0.3812182	total: 14s	remaining: 56.2ms
# 996:	learn: 0.3811499	total: 14s	remaining: 42.2ms
# 997:	learn: 0.3810942	total: 14s	remaining: 28.1ms
# 998:	learn: 0.3810224	total: 14s	remaining: 14.1ms
# 999:	learn: 0.3809808	total: 14.1s	remaining: 0us
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# RMSE:  [-0.72521124 -0.75087104 -0.79526598 -0.88469341 -0.64782455 -0.68346496]
# RMSE (all folds): 0.748 ± 0.0771

# %%
pipe
# Out:
# Pipeline(steps=[('functiontransformer-1',
#                  FunctionTransformer(func=<function _encode_dates at 0x1498ce520>)),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function _closest_transport at 0x1498ce7a0>)),
#                 ('functiontransformer-3',
#                  FunctionTransformer(func=<function _add_weather_data at 0x1498cea20>)),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('dat...sthrough',
#                                                   ['sin_month', 'sin_day',
#                                                    'sin_hour', 'sin_weekyear',
#                                                    'sin_weekday', 'cos_month',
#                                                    'cos_day', 'cos_hour',
#                                                    'cos_weekyear',
#                                                    'cos_weekday']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['counter_id',
#                                                    'closest_metro_distance',
#                                                    'holidays',
#                                                    'france_stay_at_home',
#                                                    'year', 'coco'])])),
#                 ('catboostregressor',
#                  <catboost.core.CatBoostRegressor object at 0x16570a250>)])
