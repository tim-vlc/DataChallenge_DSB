# %%
import matplotlib.pyplot as plt
import pandas
import numpy as np

# %%
arr_CV = np.array([0.657, 0.647, 0.65, 0.646, 0.641, 0.633, 0.64])
arr_Validation = np.array([0.416, 0.411, 0.414, 0.411, 0.414, 0.418, 0.413])
pca_dim = np.arange(2, 9, 1)

# %%
#plt.plot(pca_dim, arr_CV)
plt.plot(pca_dim, arr_Validation, '--')
plt.ylabel("RMSE on Validation Set")
plt.xlabel("Number of components used in the PCA")
plt.savefig('PCA_best_dim.png', dpi=200)
